# %% [markdown]
# ## Imports

# %%
import time
import copy
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import torch
from torch import nn     # All neural network modules, nn.Linear, nn.Conv2d, BatchNorm, Loss function
import torch.optim as optim     # For all Optimization algorithms, SGD, Adam, etc.
import torch.nn.functional as F     # All functions that don't have any parameters
from torch.utils.data import TensorDataset, DataLoader     # Gives easier dataset management and creates mini batchs
import torchvision.transforms as transforms     # Transformations we can perform on our dataset

import warnings
warnings.simplefilter("ignore")

print("PyTorch version " + torch.__version__)
# Out:
# PyTorch version 1.13.1+cu117

# %% [markdown]
# ## Import utility functions

# %%
from helper_train import train_autoencoder_v1
from helper_data import get_dataloaders_mnist
from helper_train import train_vae_v1, train_vae_v2
from helper_utils import set_deterministic, set_all_seeds
from helper_plotting import plot_training_loss
from helper_plotting import plot_accuracy
from helper_plotting import plot_generated_images
from helper_plotting import plot_latent_space_with_labels
from helper_plotting import plot_images_sampled_from_vae

# %%
##########################
### SETTINGS
##########################

# Device
CUDA_DEVICE_NUM = 0
device = torch.device(f'cuda:{CUDA_DEVICE_NUM}' if torch.cuda.is_available() else 'cpu')
print('Device:', device)

# Hyperparameters
RANDOM_SEED = 42
# LEARNING_RATE = 0.0001
BATCH_SIZE = 1704
# NUM_EPOCHS = 100
# Out:
# Device: cuda:0

# %%
set_deterministic
set_all_seeds(RANDOM_SEED)

# %% [markdown]
# ## 1. ETL (Extract, Transform, Load)

# %%
df = pd.read_csv('datasets/selected_2000user_v2.csv')
df
# Out:
#              MeterID            DATE-Time    KWH  user
# 0         6200093839  2021-01-01 00:00:00  0.602     0
# 1         6200093839  2021-01-01 00:15:00  0.589     0
# 2         6200093839  2021-01-01 00:30:00  0.410     0
# 3         6200093839  2021-01-01 00:45:00  0.495     0
# 4         6200093839  2021-01-01 01:00:00  0.450     0
# ...              ...                  ...    ...   ...
# 40181914  6200051044  2021-07-31 22:45:00  0.473  2000
# 40181915  6200051044  2021-07-31 23:00:00  0.461  2000
# 40181916  6200051044  2021-07-31 23:15:00  0.445  2000
# 40181917  6200051044  2021-07-31 23:30:00  0.460  2000
# 40181918  6200051044  2021-07-31 23:45:00  0.426  2000
#
# [40181919 rows x 4 columns]

# %%
cluster_1 = pd.read_csv('datasets/cluster_1.csv')
len(cluster_1)
# Out:
# 477

# %%
df = df[df['user'].isin(cluster_1['Series'])]
print(df['user'].nunique())
df
# Out:
# 477
#              MeterID            DATE-Time    KWH  user
# 0         6200093839  2021-01-01 00:00:00  0.602     0
# 1         6200093839  2021-01-01 00:15:00  0.589     0
# 2         6200093839  2021-01-01 00:30:00  0.410     0
# 3         6200093839  2021-01-01 00:45:00  0.495     0
# 4         6200093839  2021-01-01 01:00:00  0.450     0
# ...              ...                  ...    ...   ...
# 40142906  6200050858  2021-07-31 22:45:00  0.000  1998
# 40142907  6200050858  2021-07-31 23:00:00  0.008  1998
# 40142908  6200050858  2021-07-31 23:15:00  0.024  1998
# 40142909  6200050858  2021-07-31 23:30:00  0.017  1998
# 40142910  6200050858  2021-07-31 23:45:00  0.000  1998
#
# [9585962 rows x 4 columns]

# %% [markdown]
# ## 2. EDA (Exploratory Data Analysis)

# %%
# Updated
def clean_data(df, user_id):
    # Select the data for the specified user
    user_data = df[df['user']==int(user_id)]

    # Drop not useful columns
    user_data['DATE-Time'] = pd.to_datetime(user_data['DATE-Time'], infer_datetime_format=True)
    user_data.drop(columns=["MeterID", "user"], inplace=True)

    # Resample `15min` in order to have completed `"DATE-Time"`
    # I have `'DATE-Time'` 32760 rows (32760/96=341.25 Days)
    # It should be (365day * 96point = 35040 rows)
    # I have to reset index in order to hava 35040 rows
    # Fill the missing value
    user_data = user_data.set_index('DATE-Time').resample("15T").mean()
    
    # Convert the index to a DatetimeIndex object
    user_data.index = pd.to_datetime(user_data.index)

    # Count the number of zero values in each day
    zero_counts = user_data.groupby(user_data.index.floor('D'))['KWH'].apply(lambda x: (x == 0).sum())

    # Get the dates where the number of zero values is less than or equal to 48
    valid_dates = zero_counts[zero_counts <= 48].index

    # Drop the dates where the number of zero values is greater than 48
    user_data = user_data[user_data.index.floor('D').isin(valid_dates)]

    # Drop the days that have NaN values
    # Check which rows have at least one missing value
    missing_days = user_data.isnull().any(axis=1)

    # Get the dates (i.e., indices) of the rows that have missing values
    missing_days_index = missing_days[missing_days].index

    # Get the unique dates that have missing values
    missing_dates = pd.Series(missing_days_index.date).unique().tolist()

    # Drop the entire dates that contain Nan values
    user_data_clean = user_data[~user_data.index.to_series().dt.date.isin(missing_dates)]
    
    if user_data_clean.empty:
        return None

    return user_data_clean

# %%
random.seed(RANDOM_SEED)
# Get the list of unique user IDs in the DataFrame
unique_users = df['user'].unique().tolist()

def clean_multiple_users(df, num_users):

    # Randomly select `num_users` from the list of unique user IDs
    selected_users = random.sample(unique_users, num_users)

    # Call the clean_data() function for each selected user ID and concatenate the results
    all_users_clean = pd.concat([clean_data(df, user_id) for user_id in selected_users], axis=0)

    return all_users_clean, selected_users

# %%
users_clean_10, selected_users = clean_multiple_users(df, 10)

print("List of selected users: ", selected_users)
users_clean_10
# Out:
# List of selected users:  [1493, 257, 53, 1681, 543, 503, 471, 347, 1673, 240]
#                        KWH
# DATE-Time
# 2021-01-01 00:00:00  0.036
# 2021-01-01 00:15:00  0.035
# 2021-01-01 00:30:00  0.024
# 2021-01-01 00:45:00  0.011
# 2021-01-01 01:00:00  0.089
# ...                    ...
# 2021-08-31 22:45:00  0.060
# 2021-08-31 23:00:00  0.102
# 2021-08-31 23:15:00  0.251
# 2021-08-31 23:30:00  0.244
# 2021-08-31 23:45:00  0.229
#
# [181824 rows x 1 columns]

# %%
type(selected_users)
# Out:
# list

# %%
# Saving list of 10 users
users_10 = pd.DataFrame(selected_users ,columns=["user"]).sort_values(by="user").reset_index()
users_10 = users_10.drop(columns=["index"])

# %%
users_10
# Out:
#    user
# 0    53
# 1   240
# 2   257
# 3   347
# 4   471
# 5   503
# 6   543
# 7  1493
# 8  1673
# 9  1681

# %%
# users_10.to_csv('datasets/users_10.csv', index=False)

# %%
# all_users_clean.to_csv('datasets/100_users_clean.csv', index=False)

# %%
# user_6 = clean_data(df, 6)
# user_6

# %%
# plt.figure(figsize=(12,4))
# plt.title('(Energy Consumptions)', size=15)
# plt.ylabel('KWH')
# plt.grid(True)
# plt.autoscale(axis='x',tight=True)
# plt.plot(user_6['KWH'])
# plt.show()

# %% [markdown]
# ## 3. Prepare the data

# %%
def create_windowed_dataset(data, window_size):
    # Calculate the number of windows that fit in the data
    num_windows = len(data) // window_size
    
    # Truncate data to fit into windowed data exactly
    data = data[:num_windows*window_size]
    
    # Reshape the data into a 3D tensor of (num_windows, window_size, num_features)
    # Here we're adding an extra dimension to the data to represent the features, which is 1 in our case
    windowed_data = np.reshape(data, (num_windows, window_size))
    
    return windowed_data

# Example usage
window_size = 96
data = users_clean_10.to_numpy()
windowed_data = create_windowed_dataset(data, window_size)
print(f" Window shape : {windowed_data.shape}")
print(f" Type of Window : {type(windowed_data)}")
# Out:
#  Window shape : (1894, 96)
#  Type of Window : <class 'numpy.ndarray'>

# %% [markdown]
# The shape of the dataset (for selected `User_1`) is `(329, 96)` which means:
# * we have `329` samples `(i.e., 329 non-overlapping windows)`,
# * each window has `96` time steps `(i.e., 96 data points)`,
# * and `1` feature `(i.e., KWH)`.

# %%
# Plot the first 10 windows
fig, axs = plt.subplots(2, 5, figsize=(20, 8))
for i, ax in enumerate(axs.flatten()):
    ax.plot(windowed_data[i])
    ax.set_title(f"Window {i}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Divide the data into train, validation, and test sets

# %% [markdown]
# We'll split the examples into train, validation and test sets:

# %%
# Divide the data into training, validation, and test sets 
train_data, val_data = train_test_split(windowed_data, test_size=0.10, shuffle=True, random_state=RANDOM_SEED)
val_data, test_data = train_test_split(val_data, test_size=0.5, shuffle=True, random_state=RANDOM_SEED)

print(train_data.shape)
print(val_data.shape)
print(test_data.shape)
# Out:
# (1704, 96)
# (95, 96)
# (95, 96)

# %% [markdown]
# We need to convert our examples into tensors, so we can use them to train our Autoencoder. Let's write a helper function for that:

# %%
def create_dataset(df):
    sequences = df.astype(np.float32).tolist()
    dataset = [torch.tensor(s).unsqueeze(1).float() for s in sequences]
    n_seq, seq_len, n_features = torch.stack(dataset).shape
    return dataset, seq_len, n_features

# %% [markdown]
# Each Time Series will be converted to a 2D Tensor in the shape sequence length x number of features (96x1 in our case).
#
# Let's create some datasets:

# %%
train_dataset, seq_len, n_features = create_dataset(train_data)
val_dataset, _, _ = create_dataset(val_data)
test_normal_dataset, _, _ = create_dataset(test_data)

# %% [markdown]
# ### 4. Define the model

# %% [markdown]
# This model takes in a tensor of shape `(batch_size, sequence_length, num_features)` as input and outputs a tensor of the same shape.
#
# We use `Conv1d` layers for the encoder and `ConvTranspose1d` layers for the decoder.
#
# Note that the number of input channels for the first Conv1d layer is 1, because we are using a univariate time series as input.
#
# If you had a multivariate time series, you would set the number of input channels to the number of features in your data.
#
# You can adjust the number of channels and the kernel sizes of the convolutional layers to increase or decrease the complexity of the model.

# %% [markdown]
# The general Autoencoder architecture consists of two components. An Encoder that compresses the input and a Decoder that tries to reconstruct it.
#
# We'll use the LSTM Autoencoder from this GitHub repo with some small tweaks. Our model's job is to reconstruct Time Series data. Let's start with the Encoder:

# %%
class Encoder(nn.Module):

    def __init__(self, seq_len, n_features, embedding_dim=64):
        super(Encoder, self).__init__()

        self.seq_len = seq_len
        self.n_features = n_features
        self.embedding_dim = embedding_dim
        self.hidden_dim = 2 * embedding_dim
        
        self.relu1 = nn.ReLU()

        self.rnn1 = nn.LSTM(
          input_size=n_features,
          hidden_size=self.hidden_dim,
          num_layers=1,
          batch_first=True,
          dropout = 0.2
        )
        
        self.relu2 = nn.ReLU()
    
        self.rnn2 = nn.LSTM(
          input_size=self.hidden_dim,
          hidden_size=embedding_dim,
          num_layers=1,
          batch_first=True,
          dropout = 0.2
        )

    def forward(self, x):
        # print(f"ENCODER============")
        x = x.reshape((1, self.seq_len, self.n_features))
        # print(f"x reshape: {x.shape}")
        
        x = self.relu1(x)
        x, (_, _) = self.rnn1(x)
        # print(f"x of rnn1 : {x.shape}")
        
        x = self.relu2(x)
        x, (hidden_n, _) = self.rnn2(x)
        # print(f"x of rnn2 : {x.shape}")
        # print(f"hidden_n of rnn2 : {hidden_n.reshape((self.n_features, self.embedding_dim)).shape}")

        return hidden_n.reshape((self.n_features, self.embedding_dim))

# %% [markdown]
# The Encoder uses two LSTM layers to compress the Time Series data input.
#
# Next, we'll decode the compressed representation using a Decoder:

# %%
class Decoder(nn.Module):

    def __init__(self, seq_len, input_dim=128, n_features=1):
        super(Decoder, self).__init__()

        self.seq_len = seq_len
        self.input_dim = input_dim
        self.hidden_dim = 2 * input_dim
        self.n_features = n_features
        
        self.linear = nn.Linear(128, 128)
        
        self.relu1 = nn.ReLU()

        self.rnn1 = nn.LSTM(
          input_size=input_dim,
          hidden_size=input_dim,
          num_layers=1,
          batch_first=True,
          dropout = 0.2
        )
        
        self.relu2 = nn.ReLU()

        self.rnn2 = nn.LSTM(
          input_size=input_dim,
          hidden_size=self.hidden_dim,
          num_layers=1,
          batch_first=True,
          dropout = 0.2
        )

        self.output_layer = nn.Linear(self.hidden_dim, n_features)

    def forward(self, x):
        # print(f"DECODER============")
        x = x.repeat(self.seq_len, self.n_features)
        # print(f"x repeat : {x.shape}")
        
        x = x.reshape((self.n_features, self.seq_len, 128))
        # print(f"x reshape : {x.shape}")
        
        x = self.linear(x)
        # print(f"x linear reshape : {x.shape}")
        
        x = self.relu1(x)
        x, (hidden_n, cell_n) = self.rnn1(x)
        # print(f"x of rnn1 : {x.shape}")
        # print(f"hidden_n of rnn1 : {hidden_n.shape}")
        
        x = self.relu2(x)
        x, (hidden_n, cell_n) = self.rnn2(x)
        # print(f"x of rnn2 : {x.shape}")
        # print(f"hidden_n of rnn2 : {hidden_n.shape}")
        
        x = x.reshape((self.seq_len, self.hidden_dim))
        # print(f"x reshape : {x.shape}")

        return self.output_layer(x)

# %% [markdown]
# Our Decoder contains two LSTM layers and an output layer that gives the final reconstruction.
#
# Time to wrap everything into an easy to use module:

# %%
class VAE_LSTM(nn.Module):

    def __init__(self, seq_len, n_features, embedding_dim=128):
        super(VAE_LSTM, self).__init__()

        self.encoder = Encoder(seq_len, n_features, embedding_dim).to(device)
        
        self.z_mean = torch.nn.Linear(128, 128).to(device)
        self.z_log_var = torch.nn.Linear(128, 128).to(device)
        self.softplus = torch.nn.Softplus() # added
        
        self.decoder = Decoder(seq_len, embedding_dim, n_features).to(device)
        
    def reparameterize(self, z_mu, z_log_var):
        eps = torch.randn(z_mu.size(0), z_mu.size(1)).to(z_mu.get_device())
        z = z_mu + eps * torch.exp(z_log_var/2.) 
        return z

    def forward(self, x):
        x = self.encoder(x)
        # print(f"xshape: {x.shape}")
        
        mean, std = self.z_mean(x), self.z_log_var(x)
        # print(f"{mean=}")
        # print(f"{std=}")
        
        #the softplus function to convert the log variance output from the linear layer to a positive value
        std = self.softplus(std)
        
        encoded = self.reparameterize(mean, std)
        # print(encoded.shape)
        
        x = self.decoder(encoded)
        # print(x.shape)

        return x, encoded, mean, std

# %% [markdown]
# The input shape for `Conv1d` should be `(batch_size, num_features, sequence_length)`.
#
# In our case, the batch size is determined by the batch_size argument in the `DataLoader`, the number of features is `1`, and the sequence length is the window size which is `96`.
#
# So, the shape of each input should be `(batch_size, 1, 96)`.
#
# ---

# %% [markdown]
# If we use `Conv2d` instead of `Conv1d`, the input shape should be `(batch_size, 1, window_size, 1)` instead of `(batch_size, window_size, 1)`.
#
# This is because `Conv2d` expects a 4D tensor where the second dimension represents the number of channels.
#
# In our case, we only have one channel, so we set this dimension to `1`. The fourth dimension is set to 1 because we only have one feature.
#
# ---

# %% [markdown]
# If you want to use `Conv1d`, then the shape of the input tensor should be `(batch_size, in_channels, sequence_length)`, where `in_channels` is 1 in your case since you have a single feature.
#
# So for your specific case, the shape of the input tensor should be `(batch_size, 1, window_size)`, where `window_size` is 96.
#
# However, if you decide to use `Conv2d`, then the shape of the input tensor should be `(batch_size, in_channels, height, width)`.
#
# Since you only have one feature, the `in_channels` would still be 1.
#
# You can choose the `height` and `width` of the input tensor based on the window size and how you want to shape the data for the convolutional layers.
#
# For example, you could set `height=1` and `width=window_size`, or you could set `height=window_size` and `width=1`

# %% [markdown]
# ### Define loss and optimization functions

# %% [markdown]
# Our Autoencoder passes the input through the Encoder and Decoder. Let's create an instance of it:

# %%
model = VAE_LSTM(seq_len, n_features, 128)
model = model.to(device)

# %%
model
# Out:
# VAE_LSTM(
#   (encoder): Encoder(
#     (relu1): ReLU()
#     (rnn1): LSTM(1, 256, batch_first=True, dropout=0.2)
#     (relu2): ReLU()
#     (rnn2): LSTM(256, 128, batch_first=True, dropout=0.2)
#   )
#   (z_mean): Linear(in_features=128, out_features=128, bias=True)
#   (z_log_var): Linear(in_features=128, out_features=128, bias=True)
#   (softplus): Softplus(beta=1, threshold=20)
#   (decoder): Decoder(
#     (linear): Linear(in_features=128, out_features=128, bias=True)
#     (relu1): ReLU()
#     (rnn1): LSTM(128, 128, batch_first=True, dropout=0.2)
#     (relu2): ReLU()
#     (rnn2): LSTM(128, 256, batch_first=True, dropout=0.2)
#     (output_layer): Linear(in_features=256, out_features=1, bias=True)
#   )
# )

# %%
## Not use in current Task
# set_all_seeds(RANDOM_SEED)

# model = VAE()
# model.to(DEVICE)

# optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)  

# model

# %%
def count_parameters(model):
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    for item in params:
        print(f'{item:>6}')
    print(f'______\n{sum(params):>6}')
    
count_parameters(model)
# Out:
#   1024
# 262144
#   1024
#   1024
# 131072
#  65536
#    512
#    512
#  16384
#    128
#  16384
#    128
#  16384
#    128
#  65536
#  65536
#    512
#    512
# 131072
# 262144
#   1024
#   1024
#    256
#      1
# ______
# 1040001

# %%
from pynvml import *
gb = pow(1024,3)
nvmlInit()
h = nvmlDeviceGetHandleByIndex(0)
info = nvmlDeviceGetMemoryInfo(h)
print(f'total    : {info.total/gb:.2f} GB')
print(f'free     : {info.free/gb:.2f} GB')
print(f'used     : {info.used/gb:.2f} GB')

h = nvmlDeviceGetHandleByIndex(1)
info = nvmlDeviceGetMemoryInfo(h)
print(f'\ntotal    : {info.total/gb:.2f} GB')
print(f'free     : {info.free/gb:.2f} GB')
print(f'used     : {info.used/gb:.2f} GB')
# Out:
# total    : 47.99 GB
# free     : 14.35 GB
# used     : 33.64 GB
#
# total    : 11.00 GB
# free     : 10.91 GB
# used     : 0.09 GB

# %%
# for seq, y_train in train_data:
#     print(seq)
#     print(y_train)
#     break

# %% [markdown]
# ### Train the model

# %% [markdown]
# Let's write a helper function for our training process:

# %%
import pickle

# Modified VAE train_model function!!!!!!
def train_model(model, train_dataset, val_dataset, n_epochs, patience=30):
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    criterion = nn.L1Loss(reduction='sum').to(device)
    history = dict(train=[],
                   val=[], 
                   reconstruction_loss=[], 
                   kl_loss=[])

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 10000.0
    num_epochs_without_improvement = 0  # initialize early stopping counter
    
    start_time = time.time()
    for epoch in range(1, n_epochs + 1):
        model = model.train()

        train_losses = []
        reconstruction_losses=[]
        kl_losses=[]
        
        for seq_true in train_dataset:
            optimizer.zero_grad()
            
            # FORWARD AND BACK PROP
            seq_true = seq_true.to(device)
            seq_pred, encoded, mean, std = model(seq_true)
            
            # total loss = reconstruction loss + KL divergence
            #kl_divergence = (0.5 * (z_mean**2 + torch.exp(z_log_var) - z_log_var - 1)).sum()
            kl_div = -0.5 * torch.sum(1 + std 
                                      - mean**2 
                                      - torch.exp(std), 
                                      axis=1) # sum over latent dimension

            reconstruction_loss = criterion(seq_pred, seq_true)
            
            loss = (1*reconstruction_loss) + kl_div
            
            loss.backward()
            
            # UPDATE MODEL PARAMETERS
            optimizer.step()
            
            # HISTORY
            train_losses.append(loss.item())
            reconstruction_losses.append(reconstruction_loss.item())
            kl_losses.append(kl_div.item())

        val_losses = []
        model = model.eval()
        with torch.no_grad():
            for seq_true in val_dataset:

                seq_true = seq_true.to(device)
                seq_pred, encoded, mean, std = model(seq_true)

                # total loss = reconstruction loss + KL divergence
                #kl_divergence = (0.5 * (z_mean**2 + torch.exp(z_log_var) - z_log_var - 1)).sum()
                kl_div = -0.5 * torch.sum(1 + std 
                                      - mean**2 
                                      - torch.exp(std), 
                                      axis=1) # sum over latent dimension

                reconstruction_loss = criterion(seq_pred, seq_true)
            
                loss = (1*reconstruction_loss) + kl_div
                val_losses.append(loss.item())

        train_loss = np.mean(train_losses)
        reconstruction_loss = np.mean(reconstruction_losses)
        kl_loss = np.mean(kl_losses)
        val_loss = np.mean(val_losses)
        

        history['train'].append(train_loss)
        history['reconstruction_loss'].append(reconstruction_loss)
        history['kl_loss'].append(kl_loss)
        history['val'].append(val_loss)
        
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            
            #Save model
            MODEL_PATH = 'model/Final_VAE_10u_v3.pth'
            torch.save(model, MODEL_PATH)


            # save dictionary to person_data.pkl file
            with open('history/Final_VAE_10u_v3.pkl', 'wb') as fp:
                pickle.dump(history, fp)
                print('History dictionary saved successfully to file')
            
            num_epochs_without_improvement = 0  # reset early stopping counter
        else:
            num_epochs_without_improvement += 1
            if num_epochs_without_improvement >= patience:
                print(f"No improvement after {patience} epochs, stopping early")
                break
            else:
                print(f'Epoch {epoch}: train loss {train_loss} val loss {val_loss} (no improvement {num_epochs_without_improvement})')
        

        print(f'Epoch {epoch}: train loss {train_loss} val loss {val_loss}')
        
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
    model.load_state_dict(best_model_wts)
    return model.eval(), history

# %% [markdown]
# At each epoch, the training process feeds our model with all training examples and evaluates the performance on the validation set. Note that we're using a batch size of 1 (our model sees only 1 sequence at a time). We also record the training and validation set losses during the process.
#
# Note that we're minimizing the L1Loss, which measures the MAE (mean absolute error). Why? The reconstructions seem to be better than with MSE (mean squared error).
#
# We'll get the version of the model with the smallest validation error. Let's do some training:

# %% [markdown]
# ### Evaluation

# %%
model, history = train_model(
    model, 
    train_dataset, 
    val_dataset, 
    n_epochs=250, 
    patience=250,
)
# Out:
# Time elapsed: 0.41 min
# History dictionary saved successfully to file
# Epoch 1: train loss 11.450899132120778 val loss 10.869073789998104
# Time elapsed: 0.81 min
# History dictionary saved successfully to file
# Epoch 2: train loss 10.500700176881512 val loss 10.759452034297743
# Time elapsed: 1.21 min
# Epoch 3: train loss 10.474989520552013 val loss 10.80237778111508 (no improvement 1)
# Epoch 3: train loss 10.474989520552013 val loss 10.80237778111508
# Time elapsed: 1.61 min
# History dictionary saved successfully to file
# Epoch 4: train loss 10.459349869282592 val loss 10.69617227002194
# Time elapsed: 2.02 min
# History dictionary saved successfully to file
# Epoch 5: train loss 10.450157263749082 val loss 10.692764580877204
# Time elapsed: 2.42 min
# History dictionary saved successfully to file
# Epoch 6: train loss 10.428234809021435 val loss 10.668972406889264
# Time elapsed: 2.82 min
# Epoch 7: train loss 10.405137733744343 val loss 10.694347492017243 (no improvement 1)
# Epoch 7: train loss 10.405137733744343 val loss 10.694347492017243
# Time elapsed: 3.22 min
# History dictionary saved successfully to file
# Epoch 8: train loss 10.38998646719355 val loss 10.641555615475303
# Time elapsed: 3.63 min
# History dictionary saved successfully to file
# Epoch 9: train loss 10.489478384105253 val loss 10.58832456689132
# Time elapsed: 4.03 min
# History dictionary saved successfully to file
# Epoch 10: train loss 10.35935957792779 val loss 10.519337340405112
# Time elapsed: 4.43 min
# History dictionary saved successfully to file
# Epoch 11: train loss 10.27184045258822 val loss 9.92026882171631
# Time elapsed: 4.83 min
# History dictionary saved successfully to file
# Epoch 12: train loss 9.656646964485656 val loss 9.875687752271954
# Time elapsed: 5.24 min
# History dictionary saved successfully to file
# Epoch 13: train loss 9.610686925935074 val loss 9.324914641129343
# Time elapsed: 5.64 min
# Epoch 14: train loss 9.539718281425221 val loss 10.056582026732595 (no improvement 1)
# Epoch 14: train loss 9.539718281425221 val loss 10.056582026732595
# Time elapsed: 6.04 min
# Epoch 15: train loss 9.532476005909588 val loss 9.903569751036795 (no improvement 2)
# Epoch 15: train loss 9.532476005909588 val loss 9.903569751036795
# Time elapsed: 6.44 min
# Epoch 16: train loss 9.50900110035715 val loss 9.440979636342902 (no improvement 3)
# Epoch 16: train loss 9.50900110035715 val loss 9.440979636342902
# Time elapsed: 6.85 min
# Epoch 17: train loss 9.473458906854262 val loss 9.823128392821864 (no improvement 4)
# Epoch 17: train loss 9.473458906854262 val loss 9.823128392821864
# Time elapsed: 7.25 min
# History dictionary saved successfully to file
# Epoch 18: train loss 9.074655390191525 val loss 9.24865860688059
# Time elapsed: 7.65 min
# History dictionary saved successfully to file
# Epoch 19: train loss 8.933855591315618 val loss 9.18525585124367
# Time elapsed: 8.05 min
# Epoch 20: train loss 8.832637526199852 val loss 9.392251802745617 (no improvement 1)
# Epoch 20: train loss 8.832637526199852 val loss 9.392251802745617
# Time elapsed: 8.46 min
# History dictionary saved successfully to file
# Epoch 21: train loss 8.809933298630334 val loss 9.114160291772139
# Time elapsed: 8.86 min
# Epoch 22: train loss 8.667660475546764 val loss 9.374090024044639 (no improvement 1)
# Epoch 22: train loss 8.667660475546764 val loss 9.374090024044639
# Time elapsed: 9.26 min
# Epoch 23: train loss 8.651477387323625 val loss 9.30232888271934 (no improvement 2)
# Epoch 23: train loss 8.651477387323625 val loss 9.30232888271934
# Time elapsed: 9.66 min
# History dictionary saved successfully to file
# Epoch 24: train loss 8.778350115032262 val loss 8.84007558320698
# Time elapsed: 10.07 min
# Epoch 25: train loss 8.666154408049136 val loss 9.026844092419273 (no improvement 1)
# Epoch 25: train loss 8.666154408049136 val loss 9.026844092419273
# Time elapsed: 10.47 min
# History dictionary saved successfully to file
# Epoch 26: train loss 8.769416070739988 val loss 8.678619259282163
# Time elapsed: 10.87 min
# Epoch 27: train loss 8.735726844117115 val loss 9.162120831640143 (no improvement 1)
# Epoch 27: train loss 8.735726844117115 val loss 9.162120831640143
# Time elapsed: 11.27 min
# History dictionary saved successfully to file
# Epoch 28: train loss 8.627885759646343 val loss 8.592855932838038
# Time elapsed: 11.68 min
# Epoch 29: train loss 8.625854239497386 val loss 9.011246954767328 (no improvement 1)
# Epoch 29: train loss 8.625854239497386 val loss 9.011246954767328
# Time elapsed: 12.08 min
# Epoch 30: train loss 8.690555597135159 val loss 8.748581258874191 (no improvement 2)
# Epoch 30: train loss 8.690555597135159 val loss 8.748581258874191
# Time elapsed: 12.48 min
# Epoch 31: train loss 8.689910953733284 val loss 8.85721250333284 (no improvement 3)
# Epoch 31: train loss 8.689910953733284 val loss 8.85721250333284
# Time elapsed: 12.88 min
# Epoch 32: train loss 8.639334085961464 val loss 9.060446189579212 (no improvement 4)
# Epoch 32: train loss 8.639334085961464 val loss 9.060446189579212
# Time elapsed: 13.29 min
# Epoch 33: train loss 8.648061785409707 val loss 8.993570377952175 (no improvement 5)
# Epoch 33: train loss 8.648061785409707 val loss 8.993570377952175
# Time elapsed: 13.69 min
# Epoch 34: train loss 8.538391111532288 val loss 8.918086094605295 (no improvement 6)
# Epoch 34: train loss 8.538391111532288 val loss 8.918086094605295
# Time elapsed: 14.09 min
# History dictionary saved successfully to file
# Epoch 35: train loss 8.625879966597042 val loss 8.583051505841707
# Time elapsed: 14.49 min
# Epoch 36: train loss 8.613072886573317 val loss 8.696344659202977 (no improvement 1)
# Epoch 36: train loss 8.613072886573317 val loss 8.696344659202977
# Time elapsed: 14.89 min
# Epoch 37: train loss 8.594697958636731 val loss 9.08516078999168 (no improvement 2)
# Epoch 37: train loss 8.594697958636731 val loss 9.08516078999168
# Time elapsed: 15.30 min
# Epoch 38: train loss 8.517756909201962 val loss 9.507033501173321 (no improvement 3)
# Epoch 38: train loss 8.517756909201962 val loss 9.507033501173321
# Time elapsed: 15.70 min
# Epoch 39: train loss 8.587850380741374 val loss 9.297363680287411 (no improvement 4)
# Epoch 39: train loss 8.587850380741374 val loss 9.297363680287411
# Time elapsed: 16.10 min
# History dictionary saved successfully to file
# Epoch 40: train loss 8.662785939207659 val loss 8.294509744644165
# Time elapsed: 16.51 min
# Epoch 41: train loss 8.582561680338753 val loss 8.993970303786428 (no improvement 1)
# Epoch 41: train loss 8.582561680338753 val loss 8.993970303786428
# Time elapsed: 16.91 min
# Epoch 42: train loss 8.590769012839022 val loss 8.617225089826082 (no improvement 2)
# Epoch 42: train loss 8.590769012839022 val loss 8.617225089826082
# Time elapsed: 17.31 min
# Epoch 43: train loss 8.57428130416523 val loss 8.906855982228329 (no improvement 3)
# Epoch 43: train loss 8.57428130416523 val loss 8.906855982228329
# Time elapsed: 17.71 min
# Epoch 44: train loss 8.507722701055343 val loss 8.876101782447414 (no improvement 4)
# Epoch 44: train loss 8.507722701055343 val loss 8.876101782447414
# Time elapsed: 18.12 min
# Epoch 45: train loss 8.499213609896914 val loss 9.038763633527253 (no improvement 5)
# Epoch 45: train loss 8.499213609896914 val loss 9.038763633527253
# Time elapsed: 18.52 min
# History dictionary saved successfully to file
# Epoch 46: train loss 8.49494768259391 val loss 8.268137214058324
# Time elapsed: 18.92 min
# Epoch 47: train loss 8.439976576698218 val loss 8.94944557390715 (no improvement 1)
# Epoch 47: train loss 8.439976576698218 val loss 8.94944557390715
# Time elapsed: 19.32 min
# Epoch 48: train loss 8.430339944264698 val loss 8.64693922745554 (no improvement 2)
# Epoch 48: train loss 8.430339944264698 val loss 8.64693922745554
# Time elapsed: 19.73 min
# Epoch 49: train loss 8.51802763307878 val loss 8.667217179348594 (no improvement 3)
# Epoch 49: train loss 8.51802763307878 val loss 8.667217179348594
# Time elapsed: 20.13 min
# Epoch 50: train loss 8.449282922165494 val loss 8.817001726752833 (no improvement 4)
# Epoch 50: train loss 8.449282922165494 val loss 8.817001726752833
# Time elapsed: 20.53 min
# Epoch 51: train loss 8.507475604543664 val loss 8.79168290840952 (no improvement 5)
# Epoch 51: train loss 8.507475604543664 val loss 8.79168290840952
# Time elapsed: 20.93 min
# Epoch 52: train loss 8.365799484818194 val loss 8.439227066541973 (no improvement 6)
# Epoch 52: train loss 8.365799484818194 val loss 8.439227066541973
# Time elapsed: 21.34 min
# Epoch 53: train loss 8.483976534904448 val loss 8.41243899495978 (no improvement 7)
# Epoch 53: train loss 8.483976534904448 val loss 8.41243899495978
# Time elapsed: 21.74 min
# Epoch 54: train loss 8.488800617520798 val loss 8.613466960505436 (no improvement 8)
# Epoch 54: train loss 8.488800617520798 val loss 8.613466960505436
# Time elapsed: 22.14 min
# Epoch 55: train loss 8.492226499137184 val loss 8.803133485191747 (no improvement 9)
# Epoch 55: train loss 8.492226499137184 val loss 8.803133485191747
# Time elapsed: 22.54 min
# Epoch 56: train loss 8.504333384230103 val loss 9.214250298550255 (no improvement 10)
# Epoch 56: train loss 8.504333384230103 val loss 9.214250298550255
# Time elapsed: 22.95 min
# Epoch 57: train loss 8.566444514782775 val loss 8.667181707683362 (no improvement 11)
# Epoch 57: train loss 8.566444514782775 val loss 8.667181707683362
# Time elapsed: 23.35 min
# Epoch 58: train loss 8.413842476309744 val loss 8.42146530653301 (no improvement 12)
# Epoch 58: train loss 8.413842476309744 val loss 8.42146530653301
# Time elapsed: 23.75 min
# Epoch 59: train loss 8.45537763302315 val loss 8.688845744885896 (no improvement 13)
# Epoch 59: train loss 8.45537763302315 val loss 8.688845744885896
# Time elapsed: 24.15 min
# Epoch 60: train loss 8.432421533714438 val loss 8.47014923095703 (no improvement 14)
# Epoch 60: train loss 8.432421533714438 val loss 8.47014923095703
# Time elapsed: 24.56 min
# Epoch 61: train loss 8.564661281419472 val loss 8.685744456241006 (no improvement 15)
# Epoch 61: train loss 8.564661281419472 val loss 8.685744456241006
# Time elapsed: 24.96 min
# Epoch 62: train loss 8.463840757877055 val loss 8.430520406522248 (no improvement 16)
# Epoch 62: train loss 8.463840757877055 val loss 8.430520406522248
# Time elapsed: 25.36 min
# Epoch 63: train loss 8.434156033004953 val loss 8.904948618537501 (no improvement 17)
# Epoch 63: train loss 8.434156033004953 val loss 8.904948618537501
# Time elapsed: 25.76 min
# Epoch 64: train loss 8.44021294990056 val loss 8.648984181253534 (no improvement 18)
# Epoch 64: train loss 8.44021294990056 val loss 8.648984181253534
# Time elapsed: 26.17 min
# Epoch 65: train loss 8.485142676483298 val loss 8.59425903119539 (no improvement 19)
# Epoch 65: train loss 8.485142676483298 val loss 8.59425903119539
# Time elapsed: 26.57 min
# Epoch 66: train loss 8.440994487262108 val loss 8.818118587293123 (no improvement 20)
# Epoch 66: train loss 8.440994487262108 val loss 8.818118587293123
# Time elapsed: 26.97 min
# Epoch 67: train loss 8.495314833983569 val loss 9.305003786087036 (no improvement 21)
# Epoch 67: train loss 8.495314833983569 val loss 9.305003786087036
# Time elapsed: 27.37 min
# Epoch 68: train loss 8.383236131617721 val loss 8.728213465841193 (no improvement 22)
# Epoch 68: train loss 8.383236131617721 val loss 8.728213465841193
# Time elapsed: 27.78 min
# Epoch 69: train loss 8.554461262595485 val loss 8.547190247083964 (no improvement 23)
# Epoch 69: train loss 8.554461262595485 val loss 8.547190247083964
# Time elapsed: 28.18 min
# Epoch 70: train loss 8.498916618560962 val loss 8.536586550662392 (no improvement 24)
# Epoch 70: train loss 8.498916618560962 val loss 8.536586550662392
# Time elapsed: 28.58 min
# Epoch 71: train loss 8.510282860255577 val loss 8.742549104439584 (no improvement 25)
# Epoch 71: train loss 8.510282860255577 val loss 8.742549104439584
# Time elapsed: 28.98 min
# Epoch 72: train loss 8.56248580870774 val loss 8.533666552995381 (no improvement 26)
# Epoch 72: train loss 8.56248580870774 val loss 8.533666552995381
# Time elapsed: 29.39 min
# Epoch 73: train loss 8.336126123725528 val loss 8.834487849787662 (no improvement 27)
# Epoch 73: train loss 8.336126123725528 val loss 8.834487849787662
# Time elapsed: 29.79 min
# Epoch 74: train loss 8.428084716410703 val loss 8.792629570710032 (no improvement 28)
# Epoch 74: train loss 8.428084716410703 val loss 8.792629570710032
# Time elapsed: 30.19 min
# Epoch 75: train loss 8.414401250196175 val loss 8.898756760045101 (no improvement 29)
# Epoch 75: train loss 8.414401250196175 val loss 8.898756760045101
# Time elapsed: 30.60 min
# Epoch 76: train loss 8.329296917212961 val loss 8.470542435897023 (no improvement 30)
# Epoch 76: train loss 8.329296917212961 val loss 8.470542435897023
# Time elapsed: 31.00 min
# Epoch 77: train loss 8.39083648203684 val loss 8.793650842967786 (no improvement 31)
# Epoch 77: train loss 8.39083648203684 val loss 8.793650842967786
# Time elapsed: 31.40 min
# Epoch 78: train loss 8.458622970701382 val loss 8.375037941179777 (no improvement 32)
# Epoch 78: train loss 8.458622970701382 val loss 8.375037941179777
# Time elapsed: 31.80 min
# Epoch 79: train loss 8.421173449063525 val loss 8.710214715254935 (no improvement 33)
# Epoch 79: train loss 8.421173449063525 val loss 8.710214715254935
# Time elapsed: 32.21 min
# History dictionary saved successfully to file
# Epoch 80: train loss 8.41021683455353 val loss 8.136566297631514
# Time elapsed: 32.61 min
# Epoch 81: train loss 8.475122643188692 val loss 9.128727154982718 (no improvement 1)
# Epoch 81: train loss 8.475122643188692 val loss 9.128727154982718
# Time elapsed: 33.01 min
# Epoch 82: train loss 8.430521011562414 val loss 8.834907044862446 (no improvement 2)
# Epoch 82: train loss 8.430521011562414 val loss 8.834907044862446
# Time elapsed: 33.41 min
# Epoch 83: train loss 8.386314178016823 val loss 8.635639178125482 (no improvement 3)
# Epoch 83: train loss 8.386314178016823 val loss 8.635639178125482
# Time elapsed: 33.82 min
# Epoch 84: train loss 8.433261159370202 val loss 8.238035616121794 (no improvement 4)
# Epoch 84: train loss 8.433261159370202 val loss 8.238035616121794
# Time elapsed: 34.22 min
# Epoch 85: train loss 8.382881377714341 val loss 9.385146070781508 (no improvement 5)
# Epoch 85: train loss 8.382881377714341 val loss 9.385146070781508
# Time elapsed: 34.62 min
# Epoch 86: train loss 8.471920559383895 val loss 8.909895490345201 (no improvement 6)
# Epoch 86: train loss 8.471920559383895 val loss 8.909895490345201
# Time elapsed: 35.03 min
# Epoch 87: train loss 8.52516714696873 val loss 8.82452153406645 (no improvement 7)
# Epoch 87: train loss 8.52516714696873 val loss 8.82452153406645
# Time elapsed: 35.43 min
# Epoch 88: train loss 8.456166468665634 val loss 8.343022130665027 (no improvement 8)
# Epoch 88: train loss 8.456166468665634 val loss 8.343022130665027
# Time elapsed: 35.83 min
# Epoch 89: train loss 8.432753140098052 val loss 8.340205232720626 (no improvement 9)
# Epoch 89: train loss 8.432753140098052 val loss 8.340205232720626
# Time elapsed: 36.23 min
# Epoch 90: train loss 8.433154619495633 val loss 8.855209659275255 (no improvement 10)
# Epoch 90: train loss 8.433154619495633 val loss 8.855209659275255
# Time elapsed: 36.64 min
# Epoch 91: train loss 8.333156652433772 val loss 8.589773336209749 (no improvement 11)
# Epoch 91: train loss 8.333156652433772 val loss 8.589773336209749
# Time elapsed: 37.04 min
# Epoch 92: train loss 8.330717429588658 val loss 8.81694715901425 (no improvement 12)
# Epoch 92: train loss 8.330717429588658 val loss 8.81694715901425
# Time elapsed: 37.44 min
# Epoch 93: train loss 8.54525860815261 val loss 8.469512108752602 (no improvement 13)
# Epoch 93: train loss 8.54525860815261 val loss 8.469512108752602
# Time elapsed: 37.84 min
# Epoch 94: train loss 8.47297447905854 val loss 8.797884542063663 (no improvement 14)
# Epoch 94: train loss 8.47297447905854 val loss 8.797884542063663
# Time elapsed: 38.25 min
# History dictionary saved successfully to file
# Epoch 95: train loss 8.499094292031767 val loss 8.024718741366737
# Time elapsed: 38.65 min
# Epoch 96: train loss 8.41414967158311 val loss 8.518306958047967 (no improvement 1)
# Epoch 96: train loss 8.41414967158311 val loss 8.518306958047967
# Time elapsed: 39.05 min
# Epoch 97: train loss 8.353510011109947 val loss 9.022310477808903 (no improvement 2)
# Epoch 97: train loss 8.353510011109947 val loss 9.022310477808903
# Time elapsed: 39.45 min
# Epoch 98: train loss 8.413901131967423 val loss 8.60635693198756 (no improvement 3)
# Epoch 98: train loss 8.413901131967423 val loss 8.60635693198756
# Time elapsed: 39.86 min
# Epoch 99: train loss 8.399839387883043 val loss 8.153588212163825 (no improvement 4)
# Epoch 99: train loss 8.399839387883043 val loss 8.153588212163825
# Time elapsed: 40.26 min
# Epoch 100: train loss 8.266989607486366 val loss 8.973692281622636 (no improvement 5)
# Epoch 100: train loss 8.266989607486366 val loss 8.973692281622636
# Time elapsed: 40.66 min
# Epoch 101: train loss 8.441755245688935 val loss 8.920975599790875 (no improvement 6)
# Epoch 101: train loss 8.441755245688935 val loss 8.920975599790875
# Time elapsed: 41.07 min
# Epoch 102: train loss 8.407180380303535 val loss 8.720483684539795 (no improvement 7)
# Epoch 102: train loss 8.407180380303535 val loss 8.720483684539795
# Time elapsed: 41.47 min
# Epoch 103: train loss 8.497397117771452 val loss 8.715731307079917 (no improvement 8)
# Epoch 103: train loss 8.497397117771452 val loss 8.715731307079917
# Time elapsed: 41.87 min
# Epoch 104: train loss 8.432009234954494 val loss 8.459394861522474 (no improvement 9)
# Epoch 104: train loss 8.432009234954494 val loss 8.459394861522474
# Time elapsed: 42.27 min
# Epoch 105: train loss 8.411409344471677 val loss 8.544496611544961 (no improvement 10)
# Epoch 105: train loss 8.411409344471677 val loss 8.544496611544961
# Time elapsed: 42.68 min
# Epoch 106: train loss 8.379015872945807 val loss 8.596128448687102 (no improvement 11)
# Epoch 106: train loss 8.379015872945807 val loss 8.596128448687102
# Time elapsed: 43.08 min
# Epoch 107: train loss 8.435945761105824 val loss 8.342956501559208 (no improvement 12)
# Epoch 107: train loss 8.435945761105824 val loss 8.342956501559208
# Time elapsed: 43.48 min
# Epoch 108: train loss 8.36076840086722 val loss 9.043497840981734 (no improvement 13)
# Epoch 108: train loss 8.36076840086722 val loss 9.043497840981734
# Time elapsed: 43.88 min
# Epoch 109: train loss 8.402631551586966 val loss 8.331738524687918 (no improvement 14)
# Epoch 109: train loss 8.402631551586966 val loss 8.331738524687918
# Time elapsed: 44.29 min
# Epoch 110: train loss 8.248902710880472 val loss 8.314054905740837 (no improvement 15)
# Epoch 110: train loss 8.248902710880472 val loss 8.314054905740837
# Time elapsed: 44.69 min
# Epoch 111: train loss 8.406750259195135 val loss 8.388517146361501 (no improvement 16)
# Epoch 111: train loss 8.406750259195135 val loss 8.388517146361501
# Time elapsed: 45.09 min
# Epoch 112: train loss 8.388627254906954 val loss 8.848931774340178 (no improvement 17)
# Epoch 112: train loss 8.388627254906954 val loss 8.848931774340178
# Time elapsed: 45.49 min
# Epoch 113: train loss 8.418829228396707 val loss 8.586530595076711 (no improvement 18)
# Epoch 113: train loss 8.418829228396707 val loss 8.586530595076711
# Time elapsed: 45.90 min
# Epoch 114: train loss 8.445648351325675 val loss 8.355264771612067 (no improvement 19)
# Epoch 114: train loss 8.445648351325675 val loss 8.355264771612067
# Time elapsed: 46.30 min
# Epoch 115: train loss 8.380131137063247 val loss 9.087529077027973 (no improvement 20)
# Epoch 115: train loss 8.380131137063247 val loss 9.087529077027973
# Time elapsed: 46.70 min
# Epoch 116: train loss 8.309423006756205 val loss 8.988348782689949 (no improvement 21)
# Epoch 116: train loss 8.309423006756205 val loss 8.988348782689949
# Time elapsed: 47.10 min
# Epoch 117: train loss 8.410907483856443 val loss 9.150854612651624 (no improvement 22)
# Epoch 117: train loss 8.410907483856443 val loss 9.150854612651624
# Time elapsed: 47.51 min
# Epoch 118: train loss 8.246220930221495 val loss 8.469150771592792 (no improvement 23)
# Epoch 118: train loss 8.246220930221495 val loss 8.469150771592792
# Time elapsed: 47.91 min
# Epoch 119: train loss 8.424796579729223 val loss 8.82835847955001 (no improvement 24)
# Epoch 119: train loss 8.424796579729223 val loss 8.82835847955001
# Time elapsed: 48.31 min
# Epoch 120: train loss 8.28873628811657 val loss 8.364731457358912 (no improvement 25)
# Epoch 120: train loss 8.28873628811657 val loss 8.364731457358912
# Time elapsed: 48.71 min
# Epoch 121: train loss 9.220638510836682 val loss 10.031018616023816 (no improvement 26)
# Epoch 121: train loss 9.220638510836682 val loss 10.031018616023816
# Time elapsed: 49.12 min
# Epoch 122: train loss 9.9427779838093 val loss 10.20355783010784 (no improvement 27)
# Epoch 122: train loss 9.9427779838093 val loss 10.20355783010784
# Time elapsed: 49.52 min
# Epoch 123: train loss 9.931168605743999 val loss 10.149633093884116 (no improvement 28)
# Epoch 123: train loss 9.931168605743999 val loss 10.149633093884116
# Time elapsed: 49.78 min
# Epoch 124: train loss 9.32166255940574 val loss 9.284423794244464 (no improvement 29)
# Epoch 124: train loss 9.32166255940574 val loss 9.284423794244464
# Time elapsed: 49.95 min
# Epoch 125: train loss 8.989114622205076 val loss 8.970486211776734 (no improvement 30)
# Epoch 125: train loss 8.989114622205076 val loss 8.970486211776734
# Time elapsed: 50.11 min
# Epoch 126: train loss 8.758821055363041 val loss 9.14889934941342 (no improvement 31)
# Epoch 126: train loss 8.758821055363041 val loss 9.14889934941342
# Time elapsed: 50.27 min
# Epoch 127: train loss 8.813447480120569 val loss 8.980248268027054 (no improvement 32)
# Epoch 127: train loss 8.813447480120569 val loss 8.980248268027054
# Time elapsed: 50.43 min
# Epoch 128: train loss 8.813745344538644 val loss 8.944026458890814 (no improvement 33)
# Epoch 128: train loss 8.813745344538644 val loss 8.944026458890814
# Time elapsed: 50.60 min
# Epoch 129: train loss 8.67217729006295 val loss 8.827695030915109 (no improvement 34)
# Epoch 129: train loss 8.67217729006295 val loss 8.827695030915109
# Time elapsed: 50.76 min
# Epoch 130: train loss 8.57739548909832 val loss 8.876298010976692 (no improvement 35)
# Epoch 130: train loss 8.57739548909832 val loss 8.876298010976692
# Time elapsed: 50.92 min
# Epoch 131: train loss 8.686188711177016 val loss 9.04414526788812 (no improvement 36)
# Epoch 131: train loss 8.686188711177016 val loss 9.04414526788812
# Time elapsed: 51.08 min
# Epoch 132: train loss 8.799368951032418 val loss 9.294373487171374 (no improvement 37)
# Epoch 132: train loss 8.799368951032418 val loss 9.294373487171374
# Time elapsed: 51.24 min
# Epoch 133: train loss 8.722622365249155 val loss 9.323918579754077 (no improvement 38)
# Epoch 133: train loss 8.722622365249155 val loss 9.323918579754077
# Time elapsed: 51.40 min
# Epoch 134: train loss 8.622064663071027 val loss 8.931030120347675 (no improvement 39)
# Epoch 134: train loss 8.622064663071027 val loss 8.931030120347675
# Time elapsed: 51.57 min
# Epoch 135: train loss 8.573028121755716 val loss 8.733231920945016 (no improvement 40)
# Epoch 135: train loss 8.573028121755716 val loss 8.733231920945016
# Time elapsed: 51.73 min
# Epoch 136: train loss 8.52115756818946 val loss 9.126747158954018 (no improvement 41)
# Epoch 136: train loss 8.52115756818946 val loss 9.126747158954018
# Time elapsed: 51.89 min
# Epoch 137: train loss 8.689848719488287 val loss 8.994455269763344 (no improvement 42)
# Epoch 137: train loss 8.689848719488287 val loss 8.994455269763344
# Time elapsed: 52.05 min
# Epoch 138: train loss 8.696915225593697 val loss 8.548141632582013 (no improvement 43)
# Epoch 138: train loss 8.696915225593697 val loss 8.548141632582013
# Time elapsed: 52.22 min
# Epoch 139: train loss 8.629644524953175 val loss 8.489972626535517 (no improvement 44)
# Epoch 139: train loss 8.629644524953175 val loss 8.489972626535517
# Time elapsed: 52.38 min
# Epoch 140: train loss 8.748593957911075 val loss 9.064686599530672 (no improvement 45)
# Epoch 140: train loss 8.748593957911075 val loss 9.064686599530672
# Time elapsed: 52.54 min
# Epoch 141: train loss 8.554564869599723 val loss 8.764934065467433 (no improvement 46)
# Epoch 141: train loss 8.554564869599723 val loss 8.764934065467433
# Time elapsed: 52.70 min
# Epoch 142: train loss 8.91535844461459 val loss 8.125136903712624 (no improvement 47)
# Epoch 142: train loss 8.91535844461459 val loss 8.125136903712624
# Time elapsed: 52.86 min
# Epoch 143: train loss 8.738700287932522 val loss 9.068123558947914 (no improvement 48)
# Epoch 143: train loss 8.738700287932522 val loss 9.068123558947914
# Time elapsed: 53.03 min
# Epoch 144: train loss 8.597723514401297 val loss 8.674106379559166 (no improvement 49)
# Epoch 144: train loss 8.597723514401297 val loss 8.674106379559166
# Time elapsed: 53.19 min
# Epoch 145: train loss 8.605469227047033 val loss 8.892065587796663 (no improvement 50)
# Epoch 145: train loss 8.605469227047033 val loss 8.892065587796663
# Time elapsed: 53.35 min
# Epoch 146: train loss 8.433366429777772 val loss 8.205447169354088 (no improvement 51)
# Epoch 146: train loss 8.433366429777772 val loss 8.205447169354088
# Time elapsed: 53.51 min
# Epoch 147: train loss 8.629017260362845 val loss 8.759322693473415 (no improvement 52)
# Epoch 147: train loss 8.629017260362845 val loss 8.759322693473415
# Time elapsed: 53.67 min
# Epoch 148: train loss 8.593888848950046 val loss 8.813417822436282 (no improvement 53)
# Epoch 148: train loss 8.593888848950046 val loss 8.813417822436282
# Time elapsed: 53.84 min
# Epoch 149: train loss 8.457341590887504 val loss 8.313219572368421 (no improvement 54)
# Epoch 149: train loss 8.457341590887504 val loss 8.313219572368421
# Time elapsed: 54.00 min
# Epoch 150: train loss 8.400156477387522 val loss 8.458626119714035 (no improvement 55)
# Epoch 150: train loss 8.400156477387522 val loss 8.458626119714035
# Time elapsed: 54.16 min
# Epoch 151: train loss 8.366121597832917 val loss 8.286426677201923 (no improvement 56)
# Epoch 151: train loss 8.366121597832917 val loss 8.286426677201923
# Time elapsed: 54.32 min
# Epoch 152: train loss 8.349511195306487 val loss 8.551207735663967 (no improvement 57)
# Epoch 152: train loss 8.349511195306487 val loss 8.551207735663967
# Time elapsed: 54.48 min
# Epoch 153: train loss 8.489013379448457 val loss 8.182180710842735 (no improvement 58)
# Epoch 153: train loss 8.489013379448457 val loss 8.182180710842735
# Time elapsed: 54.64 min
# Epoch 154: train loss 8.429045130949065 val loss 8.495251525075812 (no improvement 59)
# Epoch 154: train loss 8.429045130949065 val loss 8.495251525075812
# Time elapsed: 54.80 min
# Epoch 155: train loss 8.406533866561075 val loss 8.305208811007049 (no improvement 60)
# Epoch 155: train loss 8.406533866561075 val loss 8.305208811007049
# Time elapsed: 54.96 min
# Epoch 156: train loss 8.378004660418895 val loss 8.481504339920846 (no improvement 61)
# Epoch 156: train loss 8.378004660418895 val loss 8.481504339920846
# Time elapsed: 55.13 min
# Epoch 157: train loss 8.498536714295826 val loss 8.776778103175916 (no improvement 62)
# Epoch 157: train loss 8.498536714295826 val loss 8.776778103175916
# Time elapsed: 55.29 min
# Epoch 158: train loss 8.376304896224832 val loss 8.55969579219818 (no improvement 63)
# Epoch 158: train loss 8.376304896224832 val loss 8.55969579219818
# Time elapsed: 55.45 min
# Epoch 159: train loss 8.379388891405343 val loss 8.183527703034251 (no improvement 64)
# Epoch 159: train loss 8.379388891405343 val loss 8.183527703034251
# Time elapsed: 55.61 min
# Epoch 160: train loss 8.291950511890398 val loss 8.699087321130852 (no improvement 65)
# Epoch 160: train loss 8.291950511890398 val loss 8.699087321130852
# Time elapsed: 55.77 min
# Epoch 161: train loss 8.343827460503354 val loss 8.851556946101942 (no improvement 66)
# Epoch 161: train loss 8.343827460503354 val loss 8.851556946101942
# Time elapsed: 55.94 min
# Epoch 162: train loss 8.43050600105608 val loss 8.09848891810367 (no improvement 67)
# Epoch 162: train loss 8.43050600105608 val loss 8.09848891810367
# Time elapsed: 56.10 min
# Epoch 163: train loss 8.249951646291594 val loss 8.382026536841142 (no improvement 68)
# Epoch 163: train loss 8.249951646291594 val loss 8.382026536841142
# Time elapsed: 56.26 min
# Epoch 164: train loss 8.390329345780918 val loss 8.646641289560419 (no improvement 69)
# Epoch 164: train loss 8.390329345780918 val loss 8.646641289560419
# Time elapsed: 56.42 min
# Epoch 165: train loss 8.28083683823196 val loss 8.65826856713546 (no improvement 70)
# Epoch 165: train loss 8.28083683823196 val loss 8.65826856713546
# Time elapsed: 56.58 min
# Epoch 166: train loss 8.475678803775232 val loss 8.553697839536165 (no improvement 71)
# Epoch 166: train loss 8.475678803775232 val loss 8.553697839536165
# Time elapsed: 56.74 min
# Epoch 167: train loss 8.24562422945186 val loss 8.122233395827443 (no improvement 72)
# Epoch 167: train loss 8.24562422945186 val loss 8.122233395827443
# Time elapsed: 56.91 min
# Epoch 168: train loss 8.359087905763461 val loss 8.55101967359844 (no improvement 73)
# Epoch 168: train loss 8.359087905763461 val loss 8.55101967359844
# Time elapsed: 57.07 min
# Epoch 169: train loss 8.269985263266474 val loss 8.702182935413562 (no improvement 74)
# Epoch 169: train loss 8.269985263266474 val loss 8.702182935413562
# Time elapsed: 57.23 min
# Epoch 170: train loss 8.186592265963554 val loss 8.475893866388422 (no improvement 75)
# Epoch 170: train loss 8.186592265963554 val loss 8.475893866388422
# Time elapsed: 57.39 min
# Epoch 171: train loss 8.25243275742016 val loss 8.33530441836307 (no improvement 76)
# Epoch 171: train loss 8.25243275742016 val loss 8.33530441836307
# Time elapsed: 57.55 min
# Epoch 172: train loss 8.368388582283343 val loss 8.570818218431974 (no improvement 77)
# Epoch 172: train loss 8.368388582283343 val loss 8.570818218431974
# Time elapsed: 57.71 min
# Epoch 173: train loss 8.286147604805763 val loss 8.276060819625854 (no improvement 78)
# Epoch 173: train loss 8.286147604805763 val loss 8.276060819625854
# Time elapsed: 57.88 min
# Epoch 174: train loss 8.29560232841073 val loss 8.712122008675022 (no improvement 79)
# Epoch 174: train loss 8.29560232841073 val loss 8.712122008675022
# Time elapsed: 58.04 min
# Epoch 175: train loss 8.342011822221425 val loss 8.164633025621113 (no improvement 80)
# Epoch 175: train loss 8.342011822221425 val loss 8.164633025621113
# Time elapsed: 58.20 min
# Epoch 176: train loss 8.339246902457425 val loss 8.601901547532332 (no improvement 81)
# Epoch 176: train loss 8.339246902457425 val loss 8.601901547532332
# Time elapsed: 58.36 min
# Epoch 177: train loss 8.46138666926975 val loss 8.223380944603369 (no improvement 82)
# Epoch 177: train loss 8.46138666926975 val loss 8.223380944603369
# Time elapsed: 58.52 min
# Epoch 178: train loss 8.256833796070215 val loss 8.38171951896266 (no improvement 83)
# Epoch 178: train loss 8.256833796070215 val loss 8.38171951896266
# Time elapsed: 58.68 min
# Epoch 179: train loss 8.310688915037213 val loss 8.377461124721327 (no improvement 84)
# Epoch 179: train loss 8.310688915037213 val loss 8.377461124721327
# Time elapsed: 58.84 min
# Epoch 180: train loss 8.35630615944034 val loss 8.342319498564068 (no improvement 85)
# Epoch 180: train loss 8.35630615944034 val loss 8.342319498564068
# Time elapsed: 59.01 min
# Epoch 181: train loss 8.426414844085913 val loss 8.371714935804668 (no improvement 86)
# Epoch 181: train loss 8.426414844085913 val loss 8.371714935804668
# Time elapsed: 59.17 min
# Epoch 182: train loss 8.20538037203847 val loss 8.700302214371531 (no improvement 87)
# Epoch 182: train loss 8.20538037203847 val loss 8.700302214371531
# Time elapsed: 59.33 min
# Epoch 183: train loss 8.156038357828145 val loss 8.465587485463995 (no improvement 88)
# Epoch 183: train loss 8.156038357828145 val loss 8.465587485463995
# Time elapsed: 59.49 min
# Epoch 184: train loss 8.335222718161596 val loss 8.525973550896895 (no improvement 89)
# Epoch 184: train loss 8.335222718161596 val loss 8.525973550896895
# Time elapsed: 59.65 min
# Epoch 185: train loss 8.275093669622716 val loss 8.505196839884707 (no improvement 90)
# Epoch 185: train loss 8.275093669622716 val loss 8.505196839884707
# Time elapsed: 59.81 min
# Epoch 186: train loss 8.32029371544229 val loss 8.641721140710931 (no improvement 91)
# Epoch 186: train loss 8.32029371544229 val loss 8.641721140710931
# Time elapsed: 59.98 min
# Epoch 187: train loss 8.471612596455874 val loss 8.252868531879626 (no improvement 92)
# Epoch 187: train loss 8.471612596455874 val loss 8.252868531879626
# Time elapsed: 60.14 min
# Epoch 188: train loss 8.345978823276193 val loss 8.259346778769242 (no improvement 93)
# Epoch 188: train loss 8.345978823276193 val loss 8.259346778769242
# Time elapsed: 60.30 min
# Epoch 189: train loss 8.340658892138464 val loss 8.519213764291061 (no improvement 94)
# Epoch 189: train loss 8.340658892138464 val loss 8.519213764291061
# Time elapsed: 60.46 min
# Epoch 190: train loss 8.168945001534453 val loss 8.63856543992695 (no improvement 95)
# Epoch 190: train loss 8.168945001534453 val loss 8.63856543992695
# Time elapsed: 60.62 min
# Epoch 191: train loss 8.296012868134069 val loss 8.345258725316901 (no improvement 96)
# Epoch 191: train loss 8.296012868134069 val loss 8.345258725316901
# Time elapsed: 60.78 min
# Epoch 192: train loss 8.324608349394351 val loss 8.093799395310251 (no improvement 97)
# Epoch 192: train loss 8.324608349394351 val loss 8.093799395310251
# Time elapsed: 60.94 min
# Epoch 193: train loss 8.273386749793106 val loss 8.683338290766665 (no improvement 98)
# Epoch 193: train loss 8.273386749793106 val loss 8.683338290766665
# Time elapsed: 61.11 min
# History dictionary saved successfully to file
# Epoch 194: train loss 8.441703908320324 val loss 8.020346006594206
# Time elapsed: 61.27 min
# Epoch 195: train loss 8.299525771062699 val loss 8.428788636860094 (no improvement 1)
# Epoch 195: train loss 8.299525771062699 val loss 8.428788636860094
# Time elapsed: 61.43 min
# Epoch 196: train loss 8.266992128650907 val loss 8.335522019235711 (no improvement 2)
# Epoch 196: train loss 8.266992128650907 val loss 8.335522019235711
# Time elapsed: 61.59 min
# Epoch 197: train loss 8.21176134490631 val loss 8.216955947875977 (no improvement 3)
# Epoch 197: train loss 8.21176134490631 val loss 8.216955947875977
# Time elapsed: 61.75 min
# Epoch 198: train loss 8.285227179247448 val loss 8.625777136652093 (no improvement 4)
# Epoch 198: train loss 8.285227179247448 val loss 8.625777136652093
# Time elapsed: 61.91 min
# Epoch 199: train loss 8.226421065383674 val loss 8.277017036237215 (no improvement 5)
# Epoch 199: train loss 8.226421065383674 val loss 8.277017036237215
# Time elapsed: 62.08 min
# Epoch 200: train loss 8.286520404365142 val loss 8.492297418493974 (no improvement 6)
# Epoch 200: train loss 8.286520404365142 val loss 8.492297418493974
# Time elapsed: 62.24 min
# Epoch 201: train loss 8.248908711431172 val loss 8.549573574568097 (no improvement 7)
# Epoch 201: train loss 8.248908711431172 val loss 8.549573574568097
# Time elapsed: 62.40 min
# Epoch 202: train loss 8.345082271406907 val loss 9.031299987592195 (no improvement 8)
# Epoch 202: train loss 8.345082271406907 val loss 9.031299987592195
# Time elapsed: 62.56 min
# Epoch 203: train loss 8.378234693282087 val loss 8.560406996074475 (no improvement 9)
# Epoch 203: train loss 8.378234693282087 val loss 8.560406996074475
# Time elapsed: 62.72 min
# Epoch 204: train loss 8.195833796696483 val loss 8.758698124634591 (no improvement 10)
# Epoch 204: train loss 8.195833796696483 val loss 8.758698124634591
# Time elapsed: 62.88 min
# Epoch 205: train loss 8.256746354936993 val loss 8.438542260621723 (no improvement 11)
# Epoch 205: train loss 8.256746354936993 val loss 8.438542260621723
# Time elapsed: 63.05 min
# Epoch 206: train loss 8.280241966247559 val loss 8.796933924524408 (no improvement 12)
# Epoch 206: train loss 8.280241966247559 val loss 8.796933924524408
# Time elapsed: 63.21 min
# Epoch 207: train loss 8.335120625758954 val loss 8.516076788149382 (no improvement 13)
# Epoch 207: train loss 8.335120625758954 val loss 8.516076788149382
# Time elapsed: 63.37 min
# Epoch 208: train loss 8.299897998711312 val loss 8.528427008578651 (no improvement 14)
# Epoch 208: train loss 8.299897998711312 val loss 8.528427008578651
# Time elapsed: 63.53 min
# Epoch 209: train loss 8.237040557491948 val loss 8.308508049814325 (no improvement 15)
# Epoch 209: train loss 8.237040557491948 val loss 8.308508049814325
# Time elapsed: 64.04 min
# Epoch 210: train loss 8.420066220099937 val loss 8.282642527630454 (no improvement 16)
# Epoch 210: train loss 8.420066220099937 val loss 8.282642527630454
# Time elapsed: 64.20 min
# Epoch 211: train loss 8.281983994542154 val loss 8.358921766281128 (no improvement 17)
# Epoch 211: train loss 8.281983994542154 val loss 8.358921766281128
# Time elapsed: 64.36 min
# Epoch 212: train loss 8.294523949494383 val loss 8.45816125869751 (no improvement 18)
# Epoch 212: train loss 8.294523949494383 val loss 8.45816125869751
# Time elapsed: 64.52 min
# Epoch 213: train loss 8.229210857984047 val loss 8.36157525715075 (no improvement 19)
# Epoch 213: train loss 8.229210857984047 val loss 8.36157525715075
# Time elapsed: 64.68 min
# Epoch 214: train loss 8.232892718253561 val loss 8.676455610676816 (no improvement 20)
# Epoch 214: train loss 8.232892718253561 val loss 8.676455610676816
# Time elapsed: 64.85 min
# Epoch 215: train loss 8.271159928659317 val loss 8.316342567142687 (no improvement 21)
# Epoch 215: train loss 8.271159928659317 val loss 8.316342567142687
# Time elapsed: 65.01 min
# Epoch 216: train loss 8.337249414531838 val loss 8.541385025727122 (no improvement 22)
# Epoch 216: train loss 8.337249414531838 val loss 8.541385025727122
# Time elapsed: 65.17 min
# Epoch 217: train loss 8.359582802849197 val loss 8.431008238541452 (no improvement 23)
# Epoch 217: train loss 8.359582802849197 val loss 8.431008238541452
# Time elapsed: 65.33 min
# Epoch 218: train loss 8.210821514328321 val loss 8.273315841273257 (no improvement 24)
# Epoch 218: train loss 8.210821514328321 val loss 8.273315841273257
# Time elapsed: 65.49 min
# Epoch 219: train loss 8.244384737781516 val loss 8.420144148876792 (no improvement 25)
# Epoch 219: train loss 8.244384737781516 val loss 8.420144148876792
# Time elapsed: 65.65 min
# Epoch 220: train loss 8.299528106557371 val loss 9.014059111946507 (no improvement 26)
# Epoch 220: train loss 8.299528106557371 val loss 9.014059111946507
# Time elapsed: 65.81 min
# Epoch 221: train loss 8.174854955762765 val loss 8.435087384675679 (no improvement 27)
# Epoch 221: train loss 8.174854955762765 val loss 8.435087384675679
# Time elapsed: 65.98 min
# Epoch 222: train loss 8.33915222278783 val loss 8.417415739360608 (no improvement 28)
# Epoch 222: train loss 8.33915222278783 val loss 8.417415739360608
# Time elapsed: 66.14 min
# Epoch 223: train loss 8.38508920161657 val loss 8.598056579891004 (no improvement 29)
# Epoch 223: train loss 8.38508920161657 val loss 8.598056579891004
# Time elapsed: 66.30 min
# History dictionary saved successfully to file
# Epoch 224: train loss 8.277480526499346 val loss 8.010983007832577
# Time elapsed: 66.46 min
# Epoch 225: train loss 8.368031270277331 val loss 8.379032576711554 (no improvement 1)
# Epoch 225: train loss 8.368031270277331 val loss 8.379032576711554
# Time elapsed: 66.62 min
# Epoch 226: train loss 8.242879219038386 val loss 8.411089927271792 (no improvement 2)
# Epoch 226: train loss 8.242879219038386 val loss 8.411089927271792
# Time elapsed: 66.79 min
# Epoch 227: train loss 8.328842429627835 val loss 8.379956702182167 (no improvement 3)
# Epoch 227: train loss 8.328842429627835 val loss 8.379956702182167
# Time elapsed: 66.95 min
# Epoch 228: train loss 8.30920863823152 val loss 8.882681565535696 (no improvement 4)
# Epoch 228: train loss 8.30920863823152 val loss 8.882681565535696
# Time elapsed: 67.11 min
# Epoch 229: train loss 8.251758894450228 val loss 8.509274650874891 (no improvement 5)
# Epoch 229: train loss 8.251758894450228 val loss 8.509274650874891
# Time elapsed: 67.27 min
# Epoch 230: train loss 8.266586634614658 val loss 8.762934431276824 (no improvement 6)
# Epoch 230: train loss 8.266586634614658 val loss 8.762934431276824
# Time elapsed: 67.43 min
# Epoch 231: train loss 8.327424159632043 val loss 8.277538374850625 (no improvement 7)
# Epoch 231: train loss 8.327424159632043 val loss 8.277538374850625
# Time elapsed: 67.59 min
# Epoch 232: train loss 8.26811529122328 val loss 8.257338697031924 (no improvement 8)
# Epoch 232: train loss 8.26811529122328 val loss 8.257338697031924
# Time elapsed: 67.76 min
# Epoch 233: train loss 8.252825219866256 val loss 8.453121923145495 (no improvement 9)
# Epoch 233: train loss 8.252825219866256 val loss 8.453121923145495
# Time elapsed: 67.92 min
# Epoch 234: train loss 8.388704238783026 val loss 8.508762266761378 (no improvement 10)
# Epoch 234: train loss 8.388704238783026 val loss 8.508762266761378
# Time elapsed: 68.08 min
# Epoch 235: train loss 8.30528416921835 val loss 8.31348103222094 (no improvement 11)
# Epoch 235: train loss 8.30528416921835 val loss 8.31348103222094
# Time elapsed: 68.24 min
# Epoch 236: train loss 8.152911140535359 val loss 8.353092371790032 (no improvement 12)
# Epoch 236: train loss 8.152911140535359 val loss 8.353092371790032
# Time elapsed: 68.40 min
# Epoch 237: train loss 8.377487768729528 val loss 8.30522521420529 (no improvement 13)
# Epoch 237: train loss 8.377487768729528 val loss 8.30522521420529
# Time elapsed: 68.56 min
# Epoch 238: train loss 8.191684743398232 val loss 8.335197257995606 (no improvement 14)
# Epoch 238: train loss 8.191684743398232 val loss 8.335197257995606
# Time elapsed: 68.72 min
# Epoch 239: train loss 8.265678289140894 val loss 8.311456062919214 (no improvement 15)
# Epoch 239: train loss 8.265678289140894 val loss 8.311456062919214
# Time elapsed: 68.89 min
# Epoch 240: train loss 8.326964459928549 val loss 8.595155871541877 (no improvement 16)
# Epoch 240: train loss 8.326964459928549 val loss 8.595155871541877
# Time elapsed: 69.05 min
# Epoch 241: train loss 8.277045953371715 val loss 8.61583113921316 (no improvement 17)
# Epoch 241: train loss 8.277045953371715 val loss 8.61583113921316
# Time elapsed: 69.21 min
# Epoch 242: train loss 8.161768642109884 val loss 8.08833674129687 (no improvement 18)
# Epoch 242: train loss 8.161768642109884 val loss 8.08833674129687
# Time elapsed: 69.37 min
# Epoch 243: train loss 8.347713391965543 val loss 8.517976329201145 (no improvement 19)
# Epoch 243: train loss 8.347713391965543 val loss 8.517976329201145
# Time elapsed: 69.54 min
# Epoch 244: train loss 8.167376939399702 val loss 8.098900990737112 (no improvement 20)
# Epoch 244: train loss 8.167376939399702 val loss 8.098900990737112
# Time elapsed: 69.70 min
# Epoch 245: train loss 8.211594204877464 val loss 8.101506996154786 (no improvement 21)
# Epoch 245: train loss 8.211594204877464 val loss 8.101506996154786
# Time elapsed: 69.86 min
# Epoch 246: train loss 8.187056015284968 val loss 8.21114562436154 (no improvement 22)
# Epoch 246: train loss 8.187056015284968 val loss 8.21114562436154
# Time elapsed: 70.02 min
# Epoch 247: train loss 8.20318618521724 val loss 8.454662247707969 (no improvement 23)
# Epoch 247: train loss 8.20318618521724 val loss 8.454662247707969
# Time elapsed: 70.18 min
# Epoch 248: train loss 8.220113016560044 val loss 8.642649705786454 (no improvement 24)
# Epoch 248: train loss 8.220113016560044 val loss 8.642649705786454
# Time elapsed: 70.35 min
# Epoch 249: train loss 8.313431252825987 val loss 8.365865067431802 (no improvement 25)
# Epoch 249: train loss 8.313431252825987 val loss 8.365865067431802
# Time elapsed: 70.51 min
# Epoch 250: train loss 8.302853483969058 val loss 8.450772496273643 (no improvement 26)
# Epoch 250: train loss 8.302853483969058 val loss 8.450772496273643
# Total Training Time: 70.51 min

# %%
ax = plt.figure().gca()

ax.plot(history['train'])
ax.plot(history['val'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'])
plt.title('Loss over training epochs')
plt.show();

# %% [markdown]
# Our model converged quite well. Seems like we might've needed a larger validation set to smoothen the results, but that'll do for now.

# %% [markdown]
# ### Saving the model

# %% [markdown]
# Let's store the model for later use:

# %%
MODEL_PATH = 'model/Final_VAE_10u_v3.pth'

torch.save(model, MODEL_PATH)

# %% [markdown]
# ### Saving a history to file

# %%
import pickle

# save dictionary to person_data.pkl file
with open('history/Final_VAE_10u_v3.pkl', 'wb') as fp:
    pickle.dump(history, fp)
    print('History dictionary saved successfully to file')
# Out:
# History dictionary saved successfully to file

# %% [markdown]
# ### Load Model

# %% [markdown]
# Uncomment the next lines, if you want to download and load the pre-trained model:

# %%
# model = torch.load('model/Final_VAE_10u_v3.pth')
# model = model.to(device)

# %% [markdown]
# ### Load History

# %%
# import pickle

# # Read dictionary pkl file
# with open('history/Final_VAE_10u_v3.pkl', 'rb') as fp:
#     history = pickle.load(fp)
#     print('History dictionary')
#     print(history.keys())
# Out:
# History dictionary
# dict_keys(['train', 'val', 'reconstruction_loss', 'kl_loss'])

# %%
ax = plt.figure().gca()

ax.plot(history['train'])
ax.plot(history['val'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'])
plt.title('Loss over training epochs')
plt.show();

# %%
ax = plt.figure().gca()

ax.plot(history['train'])
ax.plot(history['reconstruction_loss'])
ax.plot(history['kl_loss'])

plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'])
plt.title('Loss over training epochs')
plt.show();

# %% [markdown]
# ### Choosing a threshold

# %% [markdown]
# With our model at hand, we can have a look at the reconstruction error on the training set. Let's start by writing a helper function to get predictions from our model:

# %%
def predict(model, dataset):
    predictions, losses, abs_errs = [], [], []
    criterion = nn.L1Loss(reduction='sum').to(device)
    
    with torch.no_grad():
        model = model.eval()
        for seq_true in dataset:
            seq_true = seq_true.to(device)
            seq_pred, encoded, mean, std = model(seq_true)

            # total loss = reconstruction loss + KL divergence
            #kl_divergence = (0.5 * (z_mean**2 + torch.exp(z_log_var) - z_log_var - 1)).sum()
            kl_div = -0.5 * torch.sum(1 + std 
                                      - mean**2 
                                      - torch.exp(std), 
                                      axis=1) # sum over latent dimension

            reconstruction_loss = criterion(seq_pred, seq_true)
            
            loss = reconstruction_loss + kl_div
            
            abs_err = np.abs((seq_true.detach().cpu().numpy() - seq_pred.detach().cpu().numpy())/seq_pred.detach().cpu().numpy())

            predictions.append(seq_pred.cpu().numpy().flatten())
            losses.append(loss.item())
            abs_errs.append(abs_err.sum())
            
    return predictions, losses, abs_errs, encoded, mean, std

# %% [markdown]
# Our function goes through each example in the dataset and records the predictions and losses. Let's get the losses and have a look at them:

# %%
_, losses, abs_errs, _, mean, std = predict(model, train_dataset)

sns.distplot(losses, bins=50, kde=True);

# %%
mean.mean(), std.mean()
# Out:
# (tensor(0.0017, device='cuda:0'), tensor(6.2971e-06, device='cuda:0'))

# %%
sns.distplot(abs_errs, bins=50, kde=True);

# %%
THRESHOLD_losses = 15
THRESHOLD_abs_errs = 150

# %% [markdown]
# ## Predict Test datasets

# %%
predictions, pred_losses, pred_abs_errs, _, pred_mean, pred_std = predict(model, test_normal_dataset)
sns.distplot(pred_losses, bins=50, kde=True);

# %%
sns.distplot(pred_abs_errs, bins=50, kde=True);

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Using the threshold, we can turn the problem into a simple binary classification task:
#
# * If `the reconstruction loss` for an example is below the threshold, we'll classify it as a normal usesages
# * Alternatively, if the loss is higher than the threshold, we'll classify it as an anomaly
#
# * If `the absolute errors` for an example is below the threshold, we'll classify it as a normal usesages
# * Alternatively, if the loss is higher than the threshold, we'll classify it as an anomaly

# %% [markdown]
# ### Normal energy consumption

# %% [markdown]
# Let's check how well our model does on normal datasets. We'll use the normal datasets from the test set (our model haven't seen those):

# %% [markdown]
# We'll count the correct predictions:

# %%
correct = sum(l <= THRESHOLD_losses for l in pred_losses)
print(f'Correct normal predictions: {correct}/{len(test_normal_dataset)}')
# Out:
# Correct normal predictions: 84/95

# %%
correct_errs = sum(l <= THRESHOLD_abs_errs for l in pred_abs_errs)
print(f'Correct normal predictions: {correct_errs}/{len(test_normal_dataset)}')
# Out:
# Correct normal predictions: 83/95

# %% [markdown]
# ### Anomalies

# %% [markdown]
# We'll do the same with the anomaly examples, but their number is much higher. We'll get a subset that has the same size as the normal datasets:

# %% [markdown]
# We can add this type of theif attacks

# %%
# anomaly_dataset = test_anomaly_dataset[:len(test_normal_dataset)]

# %% [markdown]
# Now we can take the predictions of our model for the subset of anomalies:

# %%
# predictions, pred_losses = predict(model, anomaly_dataset)
# sns.distplot(pred_losses, bins=50, kde=True);

# %% [markdown]
# Finally, we can count the number of examples above the threshold (considered as anomalies):

# %% [markdown]
# We have very good results. In the real world, you can tweak the threshold depending on what kind of errors you want to tolerate. In this case, you might want to have more false positives (normal heartbeats considered as anomalies) than false negatives (anomalies considered as normal).

# %% [markdown]
# ### Looking at Examples

# %% [markdown]
# We can overlay the real and reconstructed Time Series values to see how close they are. We'll do it for some normal and anomaly cases:

# %%
def plot_prediction(data, model, title, ax, random_state=None):
    predictions, pred_losses, pred_abs_errs,_, pred_mean, pred_std = predict(model, [data])

    ax.plot(data, label='true')
    ax.plot(predictions[0], label='reconstructed')
    ax.set_title(f'{title} (Relative Error: {np.round(pred_abs_errs[0], 2):.2f})')
    ax.grid(True)
    ax.set_xlim(0, len(test_normal_dataset[1])-1)
    
    ax.legend()

# %%
def plot_mse(data, model, ax, random_state=None):
    predictions, pred_losses, pred_abs_errs,_, pred_mean, pred_std = predict(model, [data])
    
    mses = np.abs(data.T[0] - predictions[0])
    # print(mses.shape)         #-> torch.Size([96])
    ax.imshow(np.atleast_2d(mses), aspect=4, cmap='Reds')
    ax.set_title(f'Relative Error')
    ax.set_xticks([])
    ax.set_yticks([])

# %%
def plot_reconstructed_probability(data, model, ax, random_state=None):
    predictions, _, _, _, pred_mean, pred_std = predict(model, [data])
    
    mean = pred_mean.mean().cpu().numpy()
    std = pred_std.mean().cpu().numpy()
    log_prob = -0.5 * ((data.T[0] - mean) / std) ** 2 - np.log(std) - 0.5 * np.log(2 * np.pi)
    # print(log_prob.shape)     #-> torch.Size([96])
    ax.imshow(np.atleast_2d(log_prob), aspect=4, cmap='Reds_r')
    ax.set_title(f'Reconstructed Probability')
    ax.set_xticks([])
    ax.set_yticks([])

# %%
# Looking at ONE sample
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(12, 8))
fig.subplots_adjust(top=0.6)

data = test_normal_dataset[14]

plot_prediction(data, model, title='Normal', ax=axs[0], random_state=42)
plot_mse(data, model, ax=axs[1], random_state=42)
plot_reconstructed_probability(data, model, ax=axs[2], random_state=42)

# %%
# Looking at MANY samples
numberofloop = 4

fig, axs = plt.subplots(nrows=3*numberofloop, ncols=3, figsize=(22, 20))
fig.subplots_adjust(hspace=0.0) # set the vertical space between subplots
fig.subplots_adjust(wspace=0.1) # set the horizontal space between subplots

for i, data in enumerate(train_dataset[0:3]):
    plot_prediction(data, model, title='Normal', ax=axs[0, i], random_state=42)
    plot_mse(data, model, ax=axs[1, i], random_state=42)
    plot_reconstructed_probability(data, model, ax=axs[2, i], random_state=42)
    
for i, data in enumerate(train_dataset[3:6]):
    plot_prediction(data, model, title='Normal', ax=axs[3, i], random_state=42)
    plot_mse(data, model, ax=axs[4, i], random_state=42)
    plot_reconstructed_probability(data, model, ax=axs[5, i], random_state=42)
    
for i, data in enumerate(train_dataset[7:10]):
    plot_prediction(data, model, title='Normal', ax=axs[6, i], random_state=42)
    plot_mse(data, model, ax=axs[7, i], random_state=42)
    plot_reconstructed_probability(data, model, ax=axs[8, i], random_state=42)
    
for i, data in enumerate(train_dataset[11:14]):
    plot_prediction(data, model, title='Normal', ax=axs[9, i], random_state=42)
    plot_mse(data, model, ax=axs[10, i], random_state=42)
    plot_reconstructed_probability(data, model, ax=axs[11, i], random_state=42)

# %% [markdown]
# ### Testing

# %%
# In Testing
numberofloop = 4

fig, axs = plt.subplots(nrows=2*numberofloop, ncols=3, figsize=(22, 20))
fig.subplots_adjust(hspace=0.0) # set the vertical space between subplots
fig.subplots_adjust(wspace=0.1) # set the horizontal space between subplots

for i, data in enumerate(test_normal_dataset[0:3]):
    plot_prediction(data, model, title='Normal', ax=axs[0, i], random_state=42)
    plot_mse(data, model, ax=axs[1, i], random_state=42)
    
for i, data in enumerate(test_normal_dataset[3:6]):
    plot_prediction(data, model, title='Normal', ax=axs[2, i], random_state=42)
    plot_mse(data, model, ax=axs[3, i], random_state=42)
    
for i, data in enumerate(test_normal_dataset[7:10]):
    plot_prediction(data, model, title='Normal', ax=axs[4, i], random_state=42)
    plot_mse(data, model, ax=axs[5, i], random_state=42)
    
for i, data in enumerate(test_normal_dataset[11:14]):
    plot_prediction(data, model, title='Normal', ax=axs[6, i], random_state=42)
    plot_mse(data, model, ax=axs[7, i], random_state=42)

plt.tight_layout()

# %% [markdown]
# ### Test

# %% [markdown]
# ## 5. Evaluate the model using the test set

# %% [markdown]
# # Task
#
# ### VAE autocoder
# * https://www.google.com/search?q=variational+autoencoder+based+anomaly+detection+using+reconstruction+probability+github&rlz=1C5CHFA_enTH999TH999&oq=Variational+Autoencoder+based+Anomaly+Detection+using+Reconstruction+Probability+&aqs=chrome.1.69i57j0i512j69i60.3070j0j7&sourceid=chrome&ie=UTF-8
# * https://github.com/Michedev/VAE_anomaly_detection
# * https://github.com/smile-yan/vae-anomaly-detection
# * https://github.com/tarekmuallim/Anomaly-Detection-using-Variational-Autoencoders/blob/master/anomaly_detection_using_vae.py
#
#
# ### CNN
# * https://github.com/khanmhmdi/Cifar-Image-Reconstruction-using-Autoencoder-Models/blob/main/Image_reconstruction.ipynb
# * https://github.com/ebrahimpichka/conv-autoencoder (test on this now!!)

# %% [markdown]
# ### Test with Cluster 2

# %%
df = pd.read_csv('datasets/selected_2000user_v2.csv')
df
# Out:
#              MeterID            DATE-Time    KWH  user
# 0         6200093839  2021-01-01 00:00:00  0.602     0
# 1         6200093839  2021-01-01 00:15:00  0.589     0
# 2         6200093839  2021-01-01 00:30:00  0.410     0
# 3         6200093839  2021-01-01 00:45:00  0.495     0
# 4         6200093839  2021-01-01 01:00:00  0.450     0
# ...              ...                  ...    ...   ...
# 40181914  6200051044  2021-07-31 22:45:00  0.473  2000
# 40181915  6200051044  2021-07-31 23:00:00  0.461  2000
# 40181916  6200051044  2021-07-31 23:15:00  0.445  2000
# 40181917  6200051044  2021-07-31 23:30:00  0.460  2000
# 40181918  6200051044  2021-07-31 23:45:00  0.426  2000
#
# [40181919 rows x 4 columns]

# %%
cluster_2 = pd.read_csv('datasets/cluster_2.csv')
len(cluster_2)
# Out:
# 340

# %%
df = df[df['user'].isin(cluster_2['Series'])]
print(df['user'].nunique())
df
# Out:
# 340
#              MeterID            DATE-Time    KWH  user
# 21048     6200093048  2021-01-01 00:00:00  0.022     1
# 21049     6200093048  2021-01-01 00:15:00  0.028     1
# 21050     6200093048  2021-01-01 00:30:00  0.047     1
# 21051     6200093048  2021-01-01 00:45:00  0.046     1
# 21052     6200093048  2021-01-01 01:00:00  0.043     1
# ...              ...                  ...    ...   ...
# 40162378  6200051042  2021-07-31 22:45:00  0.113  1999
# 40162379  6200051042  2021-07-31 23:00:00  0.103  1999
# 40162380  6200051042  2021-07-31 23:15:00  0.097  1999
# 40162381  6200051042  2021-07-31 23:30:00  0.118  1999
# 40162382  6200051042  2021-07-31 23:45:00  0.120  1999
#
# [6865482 rows x 4 columns]

# %%
selected_users_cluster2 = clean_data(df, 2)
selected_users_cluster2
# Out:
#                        KWH
# DATE-Time
# 2021-01-01 00:00:00  0.037
# 2021-01-01 00:15:00  0.038
# 2021-01-01 00:30:00  0.038
# 2021-01-01 00:45:00  0.038
# 2021-01-01 01:00:00  0.038
# ...                    ...
# 2021-08-31 22:45:00  0.140
# 2021-08-31 23:00:00  0.132
# 2021-08-31 23:15:00  0.136
# 2021-08-31 23:30:00  0.121
# 2021-08-31 23:45:00  0.129
#
# [20736 rows x 1 columns]

# %%
data_cluter2 = selected_users_cluster2.to_numpy()
windowed_data_cluster2 = create_windowed_dataset(data_cluter2, window_size)
print(f" Window shape : {windowed_data_cluster2.shape}")
print(f" Type of Window : {type(windowed_data_cluster2)}")
# Out:
#  Window shape : (216, 96)
#  Type of Window : <class 'numpy.ndarray'>

# %%
cluster2_dataset, _, _ = create_dataset(windowed_data_cluster2)

# %%
# In Testing Cluster2
fig, axs = plt.subplots(
  nrows=4,
  ncols=3,
  # sharey=True,
  # sharex=True,
  figsize=(22, 8)
)

for i, data in enumerate(cluster2_dataset[0:3]):
    plot_prediction(data, model, title='Normal', ax=axs[0, i])
    
for i, data in enumerate(cluster2_dataset[3:6]):
    plot_prediction(data, model, title='Normal', ax=axs[1, i])
    
for i, data in enumerate(cluster2_dataset[6:9]):
    plot_prediction(data, model, title='Normal', ax=axs[2, i])
    
for i, data in enumerate(cluster2_dataset[9:12]):
    plot_prediction(data, model, title='Normal', ax=axs[3, i])

plt.tight_layout()

# %%
predictions, pred_losses, _, _, _ = predict(model, cluster2_dataset)
sns.distplot(pred_losses, bins=50, kde=True);

# %%
fig, ax = plt.subplots(
  nrows=2,
  ncols=1,
  # sharey=True,
  # sharex=True,
  figsize=(15, 6)
)

predictions, pred_losses, _,_,_ = predict(model, [cluster2_dataset[1]])

mse = np.abs((cluster2_dataset[1].T[0] - predictions[0])/predictions[0])

ax[0].plot(cluster2_dataset[1], label='true')
ax[0].plot(predictions[0], label='reconstructed')
ax[0].grid(True)
ax[0].legend()
ax[0].set_xlim(0, len(cluster2_dataset[1])-1)

cmap = LinearSegmentedColormap.from_list('RedGreenRed', ['lime', 'crimson'])
# ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Wistia', vmin=0, vmax=0.1)
ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Reds')
ax[1].set_xticks([])
ax[1].set_yticks([])

# ax[2].imshow(np.atleast_2d(prop.cpu()), aspect=5, cmap='Reds')

# plt.savefig('figure/first_sunlight.jpeg')
# print("Save Figure sucessfully")

# plt.tight_layout();

# %%
prop = reconstructed_probability(cluster2_dataset[1])
prop
# Out:
# tensor([ 0.5619,  0.4522,  0.5619,  0.3619,  0.5619,  0.4522,  0.4522,  0.4522,
#          0.5619,  0.6943,  0.6943,  0.5619,  0.6943,  0.4522,  0.4522,  0.4522,
#          0.4522,  0.4522,  0.4522,  0.5619,  0.4522,  0.5619,  0.4522,  0.8533,
#          0.8533,  0.8533,  0.5619,  0.5619,  0.5619,  0.4522, 21.4252, 21.4252,
#         22.7680, 22.7680, 24.0517, 25.2574, 25.2574, 24.0517, 21.4252, 22.7680,
#         21.4252, 22.7680,  0.6943,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0652,
#         22.7680, 22.7680, 21.4252, 22.7680, 21.4252, 22.7680, 21.4252, 22.7680,
#         21.4252, 22.7680,  3.6231,  0.6943,  0.8533,  0.8533,  0.8533,  1.0427,
#          0.8533,  0.8533,  0.8533,  0.6943,  0.6943,  0.5619,  0.5619,  0.6943,
#          0.5619,  0.5619,  0.6943,  0.5619,  0.5619,  0.6943,  0.6943,  1.0427],
#        device='cuda:0')

# %%
mse.sum()
# Out:
# tensor(290.7134)

# %% [markdown]
# ### test by percentage

# %%
def predict_test(model, dataset):
    predictions, losses, abs_errs = [], [], []
    criterion = nn.L1Loss(reduction='sum').to(device)
    
    with torch.no_grad():
        model = model.eval()
        for seq_true in dataset:
            seq_true = seq_true.to(device)
            seq_pred, encoded, mean, std = model(seq_true)

            # total loss = reconstruction loss + KL divergence
            #kl_divergence = (0.5 * (z_mean**2 + torch.exp(z_log_var) - z_log_var - 1)).sum()
            kl_div = -0.5 * torch.sum(1 + std 
                                      - mean**2 
                                      - torch.exp(std), 
                                      axis=1) # sum over latent dimension

            reconstruction_loss = criterion(seq_pred, seq_true)
            
            loss = reconstruction_loss + kl_div
            
            abs_err = np.abs((seq_true.detach().cpu().numpy() - seq_pred.detach().cpu().numpy())/seq_pred.detach().cpu().numpy())

            predictions.append(seq_pred.cpu().numpy().flatten())
            losses.append(loss.item())
            abs_errs.append(abs_err.sum())
            
    return predictions, losses, abs_errs, encoded, mean, std

# %%
from torch.distributions import Normal

def reconstructed_probability(x):
        """
        Computes the probability density of the input samples under the learned
        distribution of reconstructed data.
        Args:
            x: Input data tensor of shape (batch_size, num_features).
        Returns:
            A tensor of shape (batch_size,) containing the probability densities of
            the input samples under the learned distribution of reconstructed data.
        """
        with torch.no_grad():
            x = x.to(device)
            predictions, losses, mses, encoded, mean, std = predict_test(model, [x])
        recon_dist = Normal(mean, torch.abs(std).mean())  # use torch.abs(std).mean() to make std a scalar
        x = x.unsqueeze(0)
        p = recon_dist.log_prob(x).exp().mean(dim=0).mean(dim=-1)  # vector of shape [batch_size]
        return p

# %%
std
# Out:
# tensor([[ 2.6551e-03,  6.4750e-04, -6.2314e-03, -5.1870e-03, -2.0155e-03,
#          -2.5064e-05, -5.8226e-03,  2.0992e-03,  3.3239e-03, -7.2661e-04,
#          -3.2365e-03, -3.8858e-03, -9.5770e-03, -1.9938e-03, -3.6909e-03,
#          -6.9099e-03, -1.5382e+00,  9.3005e-04,  2.2136e-03,  9.1382e-03,
#           7.1134e-03,  1.5038e-03, -3.6050e-03, -1.6475e-03,  4.6711e-03,
#           1.4995e-03, -1.7400e-03,  7.4278e-03, -2.1330e-03, -4.8048e-03,
#          -3.0250e-03, -2.3908e-03, -4.4076e-03, -3.1294e-03, -6.9145e-03,
#           1.2864e-03, -1.5757e-03,  4.6644e-03, -7.5578e-03, -9.7720e-04,
#           6.1716e-04,  5.4211e-03, -3.9898e-04,  6.9109e-03,  1.3632e-03,
#          -1.0985e-03, -2.9191e-03, -8.1681e-03,  3.2514e-04, -5.7859e-04,
#          -8.0825e-03, -1.0846e-02, -2.7406e-03,  5.7802e-03, -4.5688e-04,
#           7.1824e-03,  2.1538e-04,  7.6395e-04, -6.0743e-03, -4.8485e-04,
#          -4.6176e-03, -5.6684e-03,  2.1363e-03,  1.0998e-03, -4.8193e-03,
#           2.6329e-03, -2.3010e-03,  7.9473e-03,  2.4422e-03, -2.0266e-05,
#          -3.2526e-05,  9.3979e-04,  2.0770e-03, -9.3113e-03,  7.8818e-03,
#          -1.6886e-03,  1.4567e-02, -1.6082e-03,  6.9326e-03, -3.0682e-03,
#           9.8429e-04, -1.8972e-03, -3.1726e-03, -2.2282e-03,  3.3693e-03,
#          -2.9440e-04,  2.7600e-03, -3.1004e-03, -3.0937e-04,  1.3501e-03,
#          -6.5756e-03,  4.3949e-04,  1.9285e-03,  1.8485e-03, -7.1630e-03,
#          -3.4340e-03, -1.3442e-03, -2.1585e-03,  7.8064e-04, -2.7225e-03,
#          -2.8127e-03, -3.7231e-03, -4.1104e-03, -3.5330e-03,  1.0718e-02,
#          -2.4788e-04,  7.1181e-03,  2.9696e-03,  6.8190e-03,  6.2024e-03,
#          -2.8718e-04,  3.4077e-03, -1.0874e-02,  4.3747e-03, -4.4458e-03,
#           3.5316e-04, -4.2213e-04,  5.3067e-03,  3.3395e-03, -9.9301e-03,
#           1.7594e-04, -1.2083e-02,  2.2891e-04, -1.0508e-02, -2.8186e-04,
#          -3.1001e-03, -5.8612e-03, -4.9823e-03]], device='cuda:0')

# %%
_, _,mse1, _, mean, std = predict_test(model, train_dataset)

sns.distplot(mse1, bins=50, kde=True);

# %%
np.mean(mse), np.std(mse)
# Out:
# (1.3790387, 2.5682132)

# %%
predictions, pred_losses, mse2, _, _, _ = predict_test(model, cluster2_dataset)
sns.distplot(mse2, bins=50, kde=True);

# %%
np.mean(mse), np.std(mse)
# Out:
# (1.3790387, 2.5682132)

# %%
sns.distplot(mse1, bins=50, kde=True)
sns.distplot(mse2, bins=50, kde=True);

# %% [markdown]
# # =============

# %%
model
# Out:
# VAE_LSTM(
#   (encoder): Encoder(
#     (rnn1): LSTM(1, 256, batch_first=True)
#     (rnn2): LSTM(256, 128, batch_first=True)
#   )
#   (z_mean): Linear(in_features=128, out_features=128, bias=True)
#   (z_log_var): Linear(in_features=128, out_features=128, bias=True)
#   (decoder): Decoder(
#     (linear): Linear(in_features=128, out_features=128, bias=True)
#     (rnn1): LSTM(128, 128, batch_first=True)
#     (rnn2): LSTM(128, 256, batch_first=True)
#     (output_layer): Linear(in_features=256, out_features=1, bias=True)
#   )
# )

# %%
with torch.no_grad():
        model = model.train()
        for seq_true in train_dataset:
            seq_true = seq_true.to(device)
            seq_pred, encoded, mean, std = model(seq_true)
            break

# %%
std
# Out:
# tensor([[ 1.5200e-03, -1.6688e-03, -4.8611e-03, -3.2665e-03,  2.2281e-05,
#          -1.8460e-03, -2.9268e-03,  2.8192e-03, -1.5426e-05, -4.8234e-04,
#           8.3820e-04,  6.6859e-04, -5.3550e-03,  1.4338e-03, -3.9333e-03,
#          -3.4924e-03, -1.1860e+00,  3.8121e-03,  3.6495e-03,  3.0647e-04,
#           1.7868e-04, -8.1664e-04, -3.2397e-03,  4.0853e-04,  4.1988e-03,
#          -3.0455e-03,  8.1403e-05, -3.9189e-03, -1.4461e-03, -2.6995e-03,
#           3.2350e-03,  2.8010e-03, -7.1748e-03, -4.7361e-03,  1.4370e-04,
#          -6.5135e-03, -3.2722e-03, -3.1949e-03, -3.6640e-03,  1.2221e-04,
#           8.6151e-05,  3.0528e-03, -2.2457e-03, -2.5693e-03, -1.3554e-03,
#          -6.9479e-04,  3.0644e-03,  2.2284e-03, -1.2965e-03, -1.5750e-04,
#          -4.4727e-03,  7.5736e-04, -8.2472e-04, -6.8996e-05, -2.7770e-03,
#          -1.1792e-03,  1.3717e-04, -1.2782e-03, -4.1482e-03, -2.3609e-03,
#          -5.3784e-04, -6.8099e-04,  1.5231e-03,  2.8402e-03, -4.4412e-03,
#           9.0774e-04, -5.2762e-04,  1.1079e-02, -2.5221e-04,  2.9077e-03,
#           6.5900e-03,  2.2829e-03,  4.8511e-03, -3.6540e-03,  3.0717e-03,
#           3.4674e-03,  1.0778e-02, -7.5149e-04,  7.6158e-03, -6.0800e-03,
#           8.0136e-04, -1.8877e-03, -1.0381e-03,  2.0804e-04, -1.0536e-03,
#          -2.5009e-03,  1.7344e-03, -2.4544e-03, -2.4648e-03,  3.4563e-03,
#          -2.8292e-03, -3.5764e-03, -1.7787e-03, -4.1698e-03, -4.6511e-03,
#           1.2621e-05, -4.0584e-03, -2.4769e-03,  3.0454e-04, -2.4518e-03,
#           4.3827e-03, -4.5153e-03,  3.3986e-04, -1.1938e-03,  1.4018e-03,
#           1.4981e-03,  1.7965e-03, -2.0365e-03, -1.0659e-03,  6.4154e-03,
#          -7.2695e-04, -5.8386e-04, -4.8582e-04,  1.9097e-03, -1.6870e-03,
#           1.7615e-03, -1.9424e-03,  3.5083e-03,  4.3406e-03, -7.0066e-03,
#          -1.0922e-03, -3.8613e-03, -1.2597e-03, -3.5125e-04, -1.4224e-03,
#           1.3853e-04, -4.2994e-03, -1.8566e-03]], device='cuda:0')
