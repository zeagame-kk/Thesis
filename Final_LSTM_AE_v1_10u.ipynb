# %% [markdown]
# ## Imports

# %%
import time
import copy
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import torch
from torch import nn     # All neural network modules, nn.Linear, nn.Conv2d, BatchNorm, Loss function
import torch.optim as optim     # For all Optimization algorithms, SGD, Adam, etc.
import torch.nn.functional as F     # All functions that don't have any parameters
from torch.utils.data import TensorDataset, DataLoader     # Gives easier dataset management and creates mini batchs
import torchvision.transforms as transforms     # Transformations we can perform on our dataset

import warnings
warnings.simplefilter("ignore")

print("PyTorch version " + torch.__version__)
# Out:
# PyTorch version 1.13.1+cu117

# %% [markdown]
# ## Import utility functions

# %%
from helper_train import train_autoencoder_v1
from helper_data import get_dataloaders_mnist
from helper_train import train_vae_v1, train_vae_v2
from helper_utils import set_deterministic, set_all_seeds
from helper_plotting import plot_training_loss
from helper_plotting import plot_accuracy
from helper_plotting import plot_generated_images
from helper_plotting import plot_latent_space_with_labels
from helper_plotting import plot_images_sampled_from_vae

# %%
##########################
### SETTINGS
##########################

# Device
CUDA_DEVICE_NUM = 0
device = torch.device(f'cuda:{CUDA_DEVICE_NUM}' if torch.cuda.is_available() else 'cpu')
print('Device:', device)

# Hyperparameters
RANDOM_SEED = 42
LEARNING_RATE = 0.0001
BATCH_SIZE = 64
NUM_EPOCHS = 100
# Out:
# Device: cuda:0

# %%
set_deterministic
set_all_seeds(RANDOM_SEED)

# %% [markdown]
# ## 1. ETL (Extract, Transform, Load)

# %%
df = pd.read_csv('datasets/selected_2000user_v2.csv')
df
# Out:
#              MeterID            DATE-Time    KWH  user
# 0         6200093839  2021-01-01 00:00:00  0.602     0
# 1         6200093839  2021-01-01 00:15:00  0.589     0
# 2         6200093839  2021-01-01 00:30:00  0.410     0
# 3         6200093839  2021-01-01 00:45:00  0.495     0
# 4         6200093839  2021-01-01 01:00:00  0.450     0
# ...              ...                  ...    ...   ...
# 40181914  6200051044  2021-07-31 22:45:00  0.473  2000
# 40181915  6200051044  2021-07-31 23:00:00  0.461  2000
# 40181916  6200051044  2021-07-31 23:15:00  0.445  2000
# 40181917  6200051044  2021-07-31 23:30:00  0.460  2000
# 40181918  6200051044  2021-07-31 23:45:00  0.426  2000
#
# [40181919 rows x 4 columns]

# %%
users_10 = pd.read_csv('datasets/users_10.csv')
users_10
# Out:
#    user
# 0    53
# 1   240
# 2   257
# 3   347
# 4   471
# 5   503
# 6   543
# 7  1493
# 8  1673
# 9  1681

# %%
df = df[df['user'].isin(users_10['user'])]
print(df['user'].nunique())
df
# Out:
# 10
#              MeterID            DATE-Time    KWH  user
# 1197604   6200064876  2021-01-01 00:00:00  0.189    53
# 1197605   6200064876  2021-01-01 00:15:00  0.179    53
# 1197606   6200064876  2021-01-01 00:30:00  0.189    53
# 1197607   6200064876  2021-01-01 00:45:00  0.263    53
# 1197608   6200064876  2021-01-01 01:00:00  0.338    53
# ...              ...                  ...    ...   ...
# 33857287  6200102125  2021-07-31 22:45:00  0.367  1681
# 33857288  6200102125  2021-07-31 23:00:00  0.314  1681
# 33857289  6200102125  2021-07-31 23:15:00  0.383  1681
# 33857290  6200102125  2021-07-31 23:30:00  0.374  1681
# 33857291  6200102125  2021-07-31 23:45:00  0.348  1681
#
# [202993 rows x 4 columns]

# %% [markdown]
# ## 2. EDA (Exploratory Data Analysis)

# %%
# Updated
def clean_data(df, user_id):
    # Select the data for the specified user
    user_data = df[df['user']==int(user_id)]

    # Drop not useful columns
    user_data['DATE-Time'] = pd.to_datetime(user_data['DATE-Time'], infer_datetime_format=True)
    user_data.drop(columns=["MeterID", "user"], inplace=True)

    # Resample `15min` in order to have completed `"DATE-Time"`
    # I have `'DATE-Time'` 32760 rows (32760/96=341.25 Days)
    # It should be (365day * 96point = 35040 rows)
    # I have to reset index in order to hava 35040 rows
    # Fill the missing value
    user_data = user_data.set_index('DATE-Time').resample("15T").mean()
    
    # Convert the index to a DatetimeIndex object
    user_data.index = pd.to_datetime(user_data.index)

    # Count the number of zero values in each day
    zero_counts = user_data.groupby(user_data.index.floor('D'))['KWH'].apply(lambda x: (x == 0).sum())

    # Get the dates where the number of zero values is less than or equal to 48
    valid_dates = zero_counts[zero_counts <= 48].index

    # Drop the dates where the number of zero values is greater than 48
    user_data = user_data[user_data.index.floor('D').isin(valid_dates)]

    # Drop the days that have NaN values
    # Check which rows have at least one missing value
    missing_days = user_data.isnull().any(axis=1)

    # Get the dates (i.e., indices) of the rows that have missing values
    missing_days_index = missing_days[missing_days].index

    # Get the unique dates that have missing values
    missing_dates = pd.Series(missing_days_index.date).unique().tolist()

    # Drop the entire dates that contain Nan values
    user_data_clean = user_data[~user_data.index.to_series().dt.date.isin(missing_dates)]
    
    if user_data_clean.empty:
        return None

    return user_data_clean

# %%
selected_users = df['user'].unique()

def clean_multiple_users(df, num_users):

    # Randomly select `num_users` from the list of unique user IDs
    # selected_users = random.sample(unique_users, num_users)

    # Call the clean_data() function for each selected user ID and concatenate the results
    all_users_clean = pd.concat([clean_data(df, user_id) for user_id in selected_users], axis=0)

    return all_users_clean

# %%
users_clean_10 = clean_multiple_users(df, 10)

print("List of selected users: ", selected_users)
users_clean_10
# Out:
# List of selected users:  [  53  240  257  347  471  503  543 1493 1673 1681]
#                        KWH
# DATE-Time
# 2021-01-01 00:00:00  0.189
# 2021-01-01 00:15:00  0.179
# 2021-01-01 00:30:00  0.189
# 2021-01-01 00:45:00  0.263
# 2021-01-01 01:00:00  0.338
# ...                    ...
# 2021-07-31 22:45:00  0.367
# 2021-07-31 23:00:00  0.314
# 2021-07-31 23:15:00  0.383
# 2021-07-31 23:30:00  0.374
# 2021-07-31 23:45:00  0.348
#
# [181824 rows x 1 columns]

# %%
# user_6 = clean_data(df, 6)
# user_6

# %%
# plt.figure(figsize=(12,4))
# plt.title('(Energy Consumptions)', size=15)
# plt.ylabel('KWH')
# plt.grid(True)
# plt.autoscale(axis='x',tight=True)
# plt.plot(user_6['KWH'])
# plt.show()

# %% [markdown]
# ## 3. Prepare the data

# %%
def create_windowed_dataset(data, window_size):
    # Calculate the number of windows that fit in the data
    num_windows = len(data) // window_size
    
    # Truncate data to fit into windowed data exactly
    data = data[:num_windows*window_size]
    
    # Reshape the data into a 3D tensor of (num_windows, window_size, num_features)
    # Here we're adding an extra dimension to the data to represent the features, which is 1 in our case
    windowed_data = np.reshape(data, (num_windows, window_size))
    
    return windowed_data

# Example usage
window_size = 96
data = users_clean_10.to_numpy()
windowed_data = create_windowed_dataset(data, window_size)
print(f" Window shape : {windowed_data.shape}")
print(f" Type of Window : {type(windowed_data)}")
# Out:
#  Window shape : (1894, 96)
#  Type of Window : <class 'numpy.ndarray'>

# %% [markdown]
# The shape of the dataset (for selected `User_1`) is `(329, 96)` which means:
# * we have `329` samples `(i.e., 329 non-overlapping windows)`,
# * each window has `96` time steps `(i.e., 96 data points)`,
# * and `1` feature `(i.e., KWH)`.

# %%
# Plot the first 10 windows
fig, axs = plt.subplots(2, 5, figsize=(20, 8))
for i, ax in enumerate(axs.flatten()):
    ax.plot(windowed_data[i])
    ax.set_title(f"Window {i}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Divide the data into train, validation, and test sets

# %% [markdown]
# `train_data_tensor[:-1]` and `train_data_tensor[1:]` are indexing operations on the `train_data_tensor` PyTorch tensor.
#
# `train_data_tensor[:-1]` means all elements of `train_data_tensor` except for the last one.
# * This is because in the context of the autoencoder model, we will be predicting the next time step based on the current time step, so the last element of train_data_tensor cannot be used as a predictor.
#
# `train_data_tensor[1:]` means all elements of `train_data_tensor` except for the first one.
# * This is because in the context of the autoencoder model, we will be training the model to predict the next time step given the current time step, so the first element of train_data_tensor cannot be used as a prediction target.
#
# In summary, `train_dataset` contains tuples of `input` and `target` data, where the input data is `train_data_tensor[:-1]` and the target data is `train_data_tensor[1:]`.

# %% [markdown]
# We'll split the examples into train, validation and test sets:

# %%
# Divide the data into training, validation, and test sets 
train_data, val_data = train_test_split(windowed_data, test_size=0.10, shuffle=True, random_state=RANDOM_SEED)
val_data, test_data = train_test_split(val_data, test_size=0.5, shuffle=True, random_state=RANDOM_SEED)

print(train_data.shape)
print(val_data.shape)
print(test_data.shape)
# Out:
# (1704, 96)
# (95, 96)
# (95, 96)

# %% [markdown]
# We need to convert our examples into tensors, so we can use them to train our Autoencoder. Let's write a helper function for that:

# %%
def create_dataset(df):
    sequences = df.astype(np.float32).tolist()
    dataset = [torch.tensor(s).unsqueeze(1).float() for s in sequences]
    n_seq, seq_len, n_features = torch.stack(dataset).shape
    return dataset, seq_len, n_features

# %% [markdown]
# Each Time Series will be converted to a 2D Tensor in the shape sequence length x number of features (96x1 in our case).
#
# Let's create some datasets:

# %%
train_dataset, seq_len, n_features = create_dataset(train_data)
val_dataset, _, _ = create_dataset(val_data)
test_normal_dataset, _, _ = create_dataset(test_data)

# %% [markdown]
# ### 4. Define the model

# %% [markdown]
# This model takes in a tensor of shape `(batch_size, sequence_length, num_features)` as input and outputs a tensor of the same shape.
#
# We use `Conv1d` layers for the encoder and `ConvTranspose1d` layers for the decoder.
#
# Note that the number of input channels for the first Conv1d layer is 1, because we are using a univariate time series as input.
#
# If you had a multivariate time series, you would set the number of input channels to the number of features in your data.
#
# You can adjust the number of channels and the kernel sizes of the convolutional layers to increase or decrease the complexity of the model.

# %% [markdown]
# The general Autoencoder architecture consists of two components. An Encoder that compresses the input and a Decoder that tries to reconstruct it.
#
# We'll use the LSTM Autoencoder from this GitHub repo with some small tweaks. Our model's job is to reconstruct Time Series data. Let's start with the Encoder:

# %%
class Encoder(nn.Module):

    def __init__(self, seq_len, n_features, embedding_dim=64):
        super(Encoder, self).__init__()

        self.seq_len, self.n_features = seq_len, n_features
        self.embedding_dim, self.hidden_dim = embedding_dim, 2 * embedding_dim

        self.rnn1 = nn.LSTM(
          input_size=n_features,
          hidden_size=self.hidden_dim,
          num_layers=1,
          batch_first=True
        )
    
        self.rnn2 = nn.LSTM(
          input_size=self.hidden_dim,
          hidden_size=embedding_dim,
          num_layers=1,
          batch_first=True
        )

    def forward(self, x):
        x = x.reshape((1, self.seq_len, self.n_features))

        x, (_, _) = self.rnn1(x)
        x, (hidden_n, _) = self.rnn2(x)

        return hidden_n.reshape((self.n_features, self.embedding_dim))

# %% [markdown]
# The Encoder uses two LSTM layers to compress the Time Series data input.
#
# Next, we'll decode the compressed representation using a Decoder:

# %%
class Decoder(nn.Module):

    def __init__(self, seq_len, input_dim=64, n_features=1):
        super(Decoder, self).__init__()

        self.seq_len, self.input_dim = seq_len, input_dim
        self.hidden_dim, self.n_features = 2 * input_dim, n_features

        self.rnn1 = nn.LSTM(
          input_size=input_dim,
          hidden_size=input_dim,
          num_layers=1,
          batch_first=True
        )

        self.rnn2 = nn.LSTM(
          input_size=input_dim,
          hidden_size=self.hidden_dim,
          num_layers=1,
          batch_first=True
        )

        self.output_layer = nn.Linear(self.hidden_dim, n_features)

    def forward(self, x):
        x = x.repeat(self.seq_len, self.n_features)
        x = x.reshape((self.n_features, self.seq_len, self.input_dim))

        x, (hidden_n, cell_n) = self.rnn1(x)
        x, (hidden_n, cell_n) = self.rnn2(x)
        x = x.reshape((self.seq_len, self.hidden_dim))

        return self.output_layer(x)

# %% [markdown]
# Our Decoder contains two LSTM layers and an output layer that gives the final reconstruction.
#
# Time to wrap everything into an easy to use module:

# %%
class AE_LSTM(nn.Module):

    def __init__(self, seq_len, n_features, embedding_dim=64):
        super(AE_LSTM, self).__init__()

        self.encoder = Encoder(seq_len, n_features, embedding_dim).to(device)
        self.decoder = Decoder(seq_len, embedding_dim, n_features).to(device)

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)

        return x

# %% [markdown]
# ### Define loss and optimization functions

# %% [markdown]
# Our Autoencoder passes the input through the Encoder and Decoder. Let's create an instance of it:

# %%
model = AE_LSTM(seq_len, n_features, 128)
model = model.to(device)

# %%
model
# Out:
# AE_LSTM(
#   (encoder): Encoder(
#     (rnn1): LSTM(1, 256, batch_first=True)
#     (rnn2): LSTM(256, 128, batch_first=True)
#   )
#   (decoder): Decoder(
#     (rnn1): LSTM(128, 128, batch_first=True)
#     (rnn2): LSTM(128, 256, batch_first=True)
#     (output_layer): Linear(in_features=256, out_features=1, bias=True)
#   )
# )

# %%
## Not use in current Task
# set_all_seeds(RANDOM_SEED)

# model = VAE()
# model.to(DEVICE)

# optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)  

# model

# %%
def count_parameters(model):
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    for item in params:
        print(f'{item:>6}')
    print(f'______\n{sum(params):>6}')
    
count_parameters(model)
# Out:
#   1024
# 262144
#   1024
#   1024
# 131072
#  65536
#    512
#    512
#  65536
#  65536
#    512
#    512
# 131072
# 262144
#   1024
#   1024
#    256
#      1
# ______
# 990465

# %%
from pynvml import *
gb = pow(1024,3)
nvmlInit()
h = nvmlDeviceGetHandleByIndex(0)
info = nvmlDeviceGetMemoryInfo(h)
print(f'total    : {info.total/gb:.2f} GB')
print(f'free     : {info.free/gb:.2f} GB')
print(f'used     : {info.used/gb:.2f} GB')

h = nvmlDeviceGetHandleByIndex(1)
info = nvmlDeviceGetMemoryInfo(h)
print(f'\ntotal    : {info.total/gb:.2f} GB')
print(f'free     : {info.free/gb:.2f} GB')
print(f'used     : {info.used/gb:.2f} GB')
# Out:
# total    : 47.99 GB
# free     : 15.06 GB
# used     : 32.93 GB
#
# total    : 11.00 GB
# free     : 7.05 GB
# used     : 3.95 GB

# %%
# for seq, y_train in train_data:
#     print(seq)
#     print(y_train)
#     break

# %% [markdown]
# ### Train the model

# %% [markdown]
# Let's write a helper function for our training process:

# %%
# Modified AE train_model function!!!!!!
def train_model(model, train_dataset, val_dataset, n_epochs, patience=30):
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    criterion = nn.L1Loss(reduction='sum').to(device)
    history = dict(train=[], val=[])

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 10000.0
    num_epochs_without_improvement = 0  # initialize early stopping counter
    
    start_time = time.time()
    for epoch in range(1, n_epochs + 1):
        model = model.train()

        train_losses = []
        for seq_true in train_dataset:
            optimizer.zero_grad()
            
            # FORWARD AND BACK PROP
            seq_true = seq_true.to(device)
            seq_pred = model(seq_true)

            loss = criterion(seq_pred, seq_true)
            loss.backward()
            
            # UPDATE MODEL PARAMETERS
            optimizer.step()
            
            # HISTORY
            train_losses.append(loss.item())

        val_losses = []
        model = model.eval()
        with torch.no_grad():
            for seq_true in val_dataset:

                seq_true = seq_true.to(device)
                seq_pred = model(seq_true)

                loss = criterion(seq_pred, seq_true)
                val_losses.append(loss.item())

        train_loss = np.mean(train_losses)
        val_loss = np.mean(val_losses)

        history['train'].append(train_loss)
        history['val'].append(val_loss)
        
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            num_epochs_without_improvement = 0  # reset early stopping counter
        else:
            num_epochs_without_improvement += 1
            if num_epochs_without_improvement >= patience:
                print(f"No improvement after {patience} epochs, stopping early")
                break
            else:
                print(f'Epoch {epoch}: train loss {train_loss} val loss {val_loss} (no improvement {num_epochs_without_improvement})')
     

        print(f'Epoch {epoch}: train loss {train_loss} val loss {val_loss}')
        
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
    model.load_state_dict(best_model_wts)
    return model.eval(), history

# %% [markdown]
# At each epoch, the training process feeds our model with all training examples and evaluates the performance on the validation set. Note that we're using a batch size of 1 (our model sees only 1 sequence at a time). We also record the training and validation set losses during the process.
#
# Note that we're minimizing the L1Loss, which measures the MAE (mean absolute error). Why? The reconstructions seem to be better than with MSE (mean squared error).
#
# We'll get the version of the model with the smallest validation error. Let's do some training:

# %% [markdown]
# ### Evaluation

# %%
model, history = train_model(
  model, 
  train_dataset, 
  val_dataset, 
  n_epochs=250
)
# Out:
# Time elapsed: 0.13 min
# Epoch 1: train loss 8.371574357501778 val loss 6.8073575383738465
# Time elapsed: 0.26 min
# Epoch 2: train loss 7.73719743020098 val loss 6.897320885407297 (no improvement 1)
# Epoch 2: train loss 7.73719743020098 val loss 6.897320885407297
# Time elapsed: 0.39 min
# Epoch 3: train loss 7.699775659982028 val loss 7.525643285952117 (no improvement 2)
# Epoch 3: train loss 7.699775659982028 val loss 7.525643285952117
# Time elapsed: 0.51 min
# Epoch 4: train loss 7.571642783536038 val loss 7.2278266153837505 (no improvement 3)
# Epoch 4: train loss 7.571642783536038 val loss 7.2278266153837505
# Time elapsed: 0.64 min
# Epoch 5: train loss 7.556838595408929 val loss 7.143620209944876 (no improvement 4)
# Epoch 5: train loss 7.556838595408929 val loss 7.143620209944876
# Time elapsed: 0.77 min
# Epoch 6: train loss 7.4636907594654485 val loss 7.1308615483735736 (no improvement 5)
# Epoch 6: train loss 7.4636907594654485 val loss 7.1308615483735736
# Time elapsed: 0.90 min
# Epoch 7: train loss 6.429703063248469 val loss 5.264423357812982
# Time elapsed: 1.02 min
# Epoch 8: train loss 5.78727957305494 val loss 5.256693038814946
# Time elapsed: 1.15 min
# Epoch 9: train loss 5.637574573497817 val loss 5.195697539103659
# Time elapsed: 1.28 min
# Epoch 10: train loss 5.561072405655059 val loss 5.320588557343734 (no improvement 1)
# Epoch 10: train loss 5.561072405655059 val loss 5.320588557343734
# Time elapsed: 1.41 min
# Epoch 11: train loss 5.619383655208657 val loss 5.227003724951493 (no improvement 2)
# Epoch 11: train loss 5.619383655208657 val loss 5.227003724951493
# Time elapsed: 1.54 min
# Epoch 12: train loss 5.447699177013317 val loss 4.8826190935937985
# Time elapsed: 1.66 min
# Epoch 13: train loss 5.35787230296314 val loss 4.922750693873355 (no improvement 1)
# Epoch 13: train loss 5.35787230296314 val loss 4.922750693873355
# Time elapsed: 1.79 min
# Epoch 14: train loss 5.327729190529232 val loss 4.976637884190208 (no improvement 2)
# Epoch 14: train loss 5.327729190529232 val loss 4.976637884190208
# Time elapsed: 1.92 min
# Epoch 15: train loss 5.265948597254328 val loss 4.781557245003549
# Time elapsed: 2.05 min
# Epoch 16: train loss 5.170670492723234 val loss 4.78983351180428 (no improvement 1)
# Epoch 16: train loss 5.170670492723234 val loss 4.78983351180428
# Time elapsed: 2.18 min
# Epoch 17: train loss 5.158418253169093 val loss 4.764649645905745
# Time elapsed: 2.31 min
# Epoch 18: train loss 5.074932729344413 val loss 4.831721682297556 (no improvement 1)
# Epoch 18: train loss 5.074932729344413 val loss 4.831721682297556
# Time elapsed: 2.44 min
# Epoch 19: train loss 5.053118454038817 val loss 4.591851970396544
# Time elapsed: 2.57 min
# Epoch 20: train loss 4.979797492039875 val loss 4.507618394650911
# Time elapsed: 2.70 min
# Epoch 21: train loss 4.9360984875842435 val loss 4.614523883242356 (no improvement 1)
# Epoch 21: train loss 4.9360984875842435 val loss 4.614523883242356
# Time elapsed: 2.83 min
# Epoch 22: train loss 4.914032570755397 val loss 4.537662371836211 (no improvement 2)
# Epoch 22: train loss 4.914032570755397 val loss 4.537662371836211
# Time elapsed: 2.96 min
# Epoch 23: train loss 4.8926037532133115 val loss 4.3781105882243105
# Time elapsed: 3.09 min
# Epoch 24: train loss 4.8327062505476635 val loss 4.441412702987068 (no improvement 1)
# Epoch 24: train loss 4.8327062505476635 val loss 4.441412702987068
# Time elapsed: 3.22 min
# Epoch 25: train loss 4.798177319075999 val loss 4.4565782559545415 (no improvement 2)
# Epoch 25: train loss 4.798177319075999 val loss 4.4565782559545415
# Time elapsed: 3.35 min
# Epoch 26: train loss 4.743090834048852 val loss 4.221826774195621
# Time elapsed: 3.48 min
# Epoch 27: train loss 4.6922276691301885 val loss 4.391280595879806 (no improvement 1)
# Epoch 27: train loss 4.6922276691301885 val loss 4.391280595879806
# Time elapsed: 3.61 min
# Epoch 28: train loss 4.656811907677583 val loss 4.217022322980982
# Time elapsed: 3.74 min
# Epoch 29: train loss 4.680302716616733 val loss 4.161819956804576
# Time elapsed: 3.87 min
# Epoch 30: train loss 4.623540960567098 val loss 4.153770975690139
# Time elapsed: 4.00 min
# Epoch 31: train loss 4.549365857379957 val loss 4.181057912424991 (no improvement 1)
# Epoch 31: train loss 4.549365857379957 val loss 4.181057912424991
# Time elapsed: 4.13 min
# Epoch 32: train loss 4.603169273803702 val loss 4.225182048897994 (no improvement 2)
# Epoch 32: train loss 4.603169273803702 val loss 4.225182048897994
# Time elapsed: 4.26 min
# Epoch 33: train loss 4.521093857540211 val loss 4.197124056439651 (no improvement 3)
# Epoch 33: train loss 4.521093857540211 val loss 4.197124056439651
# Time elapsed: 4.39 min
# Epoch 34: train loss 4.511484750909425 val loss 4.124881208256672
# Time elapsed: 4.52 min
# Epoch 35: train loss 4.454461747500608 val loss 4.198192128382231 (no improvement 1)
# Epoch 35: train loss 4.454461747500608 val loss 4.198192128382231
# Time elapsed: 4.65 min
# Epoch 36: train loss 4.4989851274890515 val loss 4.349650284491087 (no improvement 2)
# Epoch 36: train loss 4.4989851274890515 val loss 4.349650284491087
# Time elapsed: 4.78 min
# Epoch 37: train loss 4.431666836536056 val loss 4.092987753215589
# Time elapsed: 4.91 min
# Epoch 38: train loss 4.388934021649506 val loss 4.313142709983023 (no improvement 1)
# Epoch 38: train loss 4.388934021649506 val loss 4.313142709983023
# Time elapsed: 5.04 min
# Epoch 39: train loss 4.422051382832614 val loss 4.066621619149259
# Time elapsed: 5.17 min
# Epoch 40: train loss 4.385586766132587 val loss 3.998631363479715
# Time elapsed: 5.30 min
# Epoch 41: train loss 4.29418355492359 val loss 3.9573272303531044
# Time elapsed: 5.43 min
# Epoch 42: train loss 4.273897265372667 val loss 3.8349865424005607
# Time elapsed: 5.56 min
# Epoch 43: train loss 4.220422382243503 val loss 3.8898032985235513 (no improvement 1)
# Epoch 43: train loss 4.220422382243503 val loss 3.8898032985235513
# Time elapsed: 5.69 min
# Epoch 44: train loss 4.2153372407799035 val loss 3.9374977249848215 (no improvement 2)
# Epoch 44: train loss 4.2153372407799035 val loss 3.9374977249848215
# Time elapsed: 5.82 min
# Epoch 45: train loss 4.15145688395545 val loss 3.849486514141685 (no improvement 3)
# Epoch 45: train loss 4.15145688395545 val loss 3.849486514141685
# Time elapsed: 5.95 min
# Epoch 46: train loss 4.2354131990807575 val loss 3.804315069474672
# Time elapsed: 6.08 min
# Epoch 47: train loss 4.127173915750264 val loss 3.8085119642709433 (no improvement 1)
# Epoch 47: train loss 4.127173915750264 val loss 3.8085119642709433
# Time elapsed: 6.21 min
# Epoch 48: train loss 4.09368059313703 val loss 3.893195232592131 (no improvement 2)
# Epoch 48: train loss 4.09368059313703 val loss 3.893195232592131
# Time elapsed: 6.34 min
# Epoch 49: train loss 4.091084698696092 val loss 3.7554679299655715
# Time elapsed: 6.47 min
# Epoch 50: train loss 4.041964751340344 val loss 3.931530048972682 (no improvement 1)
# Epoch 50: train loss 4.041964751340344 val loss 3.931530048972682
# Time elapsed: 6.60 min
# Epoch 51: train loss 4.402628139098625 val loss 3.905338812501807 (no improvement 2)
# Epoch 51: train loss 4.402628139098625 val loss 3.905338812501807
# Time elapsed: 6.73 min
# Epoch 52: train loss 4.151009328680839 val loss 3.819936051180488 (no improvement 3)
# Epoch 52: train loss 4.151009328680839 val loss 3.819936051180488
# Time elapsed: 6.86 min
# Epoch 53: train loss 4.004539767621269 val loss 3.7489548087120057
# Time elapsed: 6.99 min
# Epoch 54: train loss 4.0718594671450035 val loss 3.7337451031333524
# Time elapsed: 7.12 min
# Epoch 55: train loss 4.027484449352457 val loss 3.7161548238051565
# Time elapsed: 7.25 min
# Epoch 56: train loss 3.9533922922023583 val loss 3.808945316389987 (no improvement 1)
# Epoch 56: train loss 3.9533922922023583 val loss 3.808945316389987
# Time elapsed: 7.38 min
# Epoch 57: train loss 4.047950357985749 val loss 3.7616786652489713 (no improvement 2)
# Epoch 57: train loss 4.047950357985749 val loss 3.7616786652489713
# Time elapsed: 7.51 min
# Epoch 58: train loss 3.977539786238206 val loss 3.7096871548577357
# Time elapsed: 7.64 min
# Epoch 59: train loss 3.899350804132475 val loss 3.683321070043664
# Time elapsed: 7.77 min
# Epoch 60: train loss 3.884589910104941 val loss 3.731376985186025 (no improvement 1)
# Epoch 60: train loss 3.884589910104941 val loss 3.731376985186025
# Time elapsed: 7.90 min
# Epoch 61: train loss 3.889344546699048 val loss 3.708364755228946 (no improvement 2)
# Epoch 61: train loss 3.889344546699048 val loss 3.708364755228946
# Time elapsed: 8.03 min
# Epoch 62: train loss 3.8544266474184017 val loss 3.6810694136117634
# Time elapsed: 8.16 min
# Epoch 63: train loss 3.8603181916818095 val loss 3.7157034861414058 (no improvement 1)
# Epoch 63: train loss 3.8603181916818095 val loss 3.7157034861414058
# Time elapsed: 8.29 min
# Epoch 64: train loss 3.8440576629109784 val loss 3.700113971923527 (no improvement 2)
# Epoch 64: train loss 3.8440576629109784 val loss 3.700113971923527
# Time elapsed: 8.42 min
# Epoch 65: train loss 3.8906757279426 val loss 3.956399333790729 (no improvement 3)
# Epoch 65: train loss 3.8906757279426 val loss 3.956399333790729
# Time elapsed: 8.55 min
# Epoch 66: train loss 3.913302177921847 val loss 3.6890290185024863 (no improvement 4)
# Epoch 66: train loss 3.913302177921847 val loss 3.6890290185024863
# Time elapsed: 8.69 min
# Epoch 67: train loss 3.799116936805243 val loss 3.55772499097021
# Time elapsed: 8.83 min
# Epoch 68: train loss 3.770467546676666 val loss 3.6123128094171224 (no improvement 1)
# Epoch 68: train loss 3.770467546676666 val loss 3.6123128094171224
# Time elapsed: 8.97 min
# Epoch 69: train loss 3.7662044433535824 val loss 3.5728680227932177 (no improvement 2)
# Epoch 69: train loss 3.7662044433535824 val loss 3.5728680227932177
# Time elapsed: 9.10 min
# Epoch 70: train loss 3.767886351164378 val loss 3.649264736865696 (no improvement 3)
# Epoch 70: train loss 3.767886351164378 val loss 3.649264736865696
# Time elapsed: 9.23 min
# Epoch 71: train loss 3.7383873872371485 val loss 3.6520118383984816 (no improvement 4)
# Epoch 71: train loss 3.7383873872371485 val loss 3.6520118383984816
# Time elapsed: 9.36 min
# Epoch 72: train loss 3.724699875750872 val loss 3.594165244071107 (no improvement 5)
# Epoch 72: train loss 3.724699875750872 val loss 3.594165244071107
# Time elapsed: 9.50 min
# Epoch 73: train loss 3.706768865430369 val loss 3.489670622976203
# Time elapsed: 9.63 min
# Epoch 74: train loss 3.684876771215262 val loss 3.5627938124694323 (no improvement 1)
# Epoch 74: train loss 3.684876771215262 val loss 3.5627938124694323
# Time elapsed: 9.76 min
# Epoch 75: train loss 3.6865142347037514 val loss 3.558041088204635 (no improvement 2)
# Epoch 75: train loss 3.6865142347037514 val loss 3.558041088204635
# Time elapsed: 9.89 min
# Epoch 76: train loss 3.682551567377129 val loss 3.759506238761701 (no improvement 3)
# Epoch 76: train loss 3.682551567377129 val loss 3.759506238761701
# Time elapsed: 10.02 min
# Epoch 77: train loss 3.670291764775352 val loss 3.4748152381495427
# Time elapsed: 10.15 min
# Epoch 78: train loss 3.662234340370261 val loss 3.4784447877030624 (no improvement 1)
# Epoch 78: train loss 3.662234340370261 val loss 3.4784447877030624
# Time elapsed: 10.28 min
# Epoch 79: train loss 3.6527165935807666 val loss 3.582990528094141 (no improvement 2)
# Epoch 79: train loss 3.6527165935807666 val loss 3.582990528094141
# Time elapsed: 10.41 min
# Epoch 80: train loss 3.6408258479595745 val loss 3.60725955210234 (no improvement 3)
# Epoch 80: train loss 3.6408258479595745 val loss 3.60725955210234
# Time elapsed: 10.54 min
# Epoch 81: train loss 3.701790082849947 val loss 3.668455425689095 (no improvement 4)
# Epoch 81: train loss 3.701790082849947 val loss 3.668455425689095
# Time elapsed: 10.67 min
# Epoch 82: train loss 3.6225877096920227 val loss 3.6514689392165134 (no improvement 5)
# Epoch 82: train loss 3.6225877096920227 val loss 3.6514689392165134
# Time elapsed: 10.80 min
# Epoch 83: train loss 3.855884191138504 val loss 3.472906970977783
# Time elapsed: 10.93 min
# Epoch 84: train loss 3.669062490247085 val loss 3.574136642405861 (no improvement 1)
# Epoch 84: train loss 3.669062490247085 val loss 3.574136642405861
# Time elapsed: 11.06 min
# Epoch 85: train loss 3.6185900230275494 val loss 3.4348292529582976
# Time elapsed: 11.19 min
# Epoch 86: train loss 3.6659308978019745 val loss 3.6418048833545886 (no improvement 1)
# Epoch 86: train loss 3.6659308978019745 val loss 3.6418048833545886
# Time elapsed: 11.32 min
# Epoch 87: train loss 3.594481379283426 val loss 3.38759269588872
# Time elapsed: 11.45 min
# Epoch 88: train loss 3.5703618571581974 val loss 3.5181745736222516 (no improvement 1)
# Epoch 88: train loss 3.5703618571581974 val loss 3.5181745736222516
# Time elapsed: 11.58 min
# Epoch 89: train loss 3.5674236141355107 val loss 3.4064641544693393 (no improvement 2)
# Epoch 89: train loss 3.5674236141355107 val loss 3.4064641544693393
# Time elapsed: 11.71 min
# Epoch 90: train loss 3.6077245787450685 val loss 3.530627172557931 (no improvement 3)
# Epoch 90: train loss 3.6077245787450685 val loss 3.530627172557931
# Time elapsed: 11.84 min
# Epoch 91: train loss 3.4892490878876106 val loss 3.4673467080844076 (no improvement 4)
# Epoch 91: train loss 3.4892490878876106 val loss 3.4673467080844076
# Time elapsed: 11.97 min
# Epoch 92: train loss 3.5066167213145136 val loss 3.4445585213209453 (no improvement 5)
# Epoch 92: train loss 3.5066167213145136 val loss 3.4445585213209453
# Time elapsed: 12.10 min
# Epoch 93: train loss 3.4951223919754018 val loss 3.4841241431863685 (no improvement 6)
# Epoch 93: train loss 3.4951223919754018 val loss 3.4841241431863685
# Time elapsed: 12.23 min
# Epoch 94: train loss 3.498435608447997 val loss 3.3743375307635257
# Time elapsed: 12.36 min
# Epoch 95: train loss 3.4800379976910043 val loss 3.5315497931681183 (no improvement 1)
# Epoch 95: train loss 3.4800379976910043 val loss 3.5315497931681183
# Time elapsed: 12.49 min
# Epoch 96: train loss 3.467202996389127 val loss 3.4879045458216416 (no improvement 2)
# Epoch 96: train loss 3.467202996389127 val loss 3.4879045458216416
# Time elapsed: 12.62 min
# Epoch 97: train loss 3.432836098893777 val loss 3.392435220040773 (no improvement 3)
# Epoch 97: train loss 3.432836098893777 val loss 3.392435220040773
# Time elapsed: 12.75 min
# Epoch 98: train loss 3.4899574478152493 val loss 3.3938367683636517 (no improvement 4)
# Epoch 98: train loss 3.4899574478152493 val loss 3.3938367683636517
# Time elapsed: 12.88 min
# Epoch 99: train loss 3.4107039089493907 val loss 3.4631540787847417 (no improvement 5)
# Epoch 99: train loss 3.4107039089493907 val loss 3.4631540787847417
# Time elapsed: 13.01 min
# Epoch 100: train loss 3.4016932018381048 val loss 3.3983787818958886 (no improvement 6)
# Epoch 100: train loss 3.4016932018381048 val loss 3.3983787818958886
# Time elapsed: 13.14 min
# Epoch 101: train loss 3.455504420672504 val loss 3.4885106745519137 (no improvement 7)
# Epoch 101: train loss 3.455504420672504 val loss 3.4885106745519137
# Time elapsed: 13.27 min
# Epoch 102: train loss 3.378656851530005 val loss 3.4162836859100745 (no improvement 8)
# Epoch 102: train loss 3.378656851530005 val loss 3.4162836859100745
# Time elapsed: 13.40 min
# Epoch 103: train loss 3.3758466651339627 val loss 3.4164928944487323 (no improvement 9)
# Epoch 103: train loss 3.3758466651339627 val loss 3.4164928944487323
# Time elapsed: 13.53 min
# Epoch 104: train loss 3.370138535477186 val loss 3.3055708728338544
# Time elapsed: 13.66 min
# Epoch 105: train loss 3.3734475501196486 val loss 3.421627704720748 (no improvement 1)
# Epoch 105: train loss 3.3734475501196486 val loss 3.421627704720748
# Time elapsed: 13.79 min
# Epoch 106: train loss 3.3496728680695584 val loss 3.3227152931062798 (no improvement 2)
# Epoch 106: train loss 3.3496728680695584 val loss 3.3227152931062798
# Time elapsed: 13.92 min
# Epoch 107: train loss 3.3583301970376653 val loss 3.3151563622449576 (no improvement 3)
# Epoch 107: train loss 3.3583301970376653 val loss 3.3151563622449576
# Time elapsed: 14.05 min
# Epoch 108: train loss 3.348949408989417 val loss 3.3855504013990103 (no improvement 4)
# Epoch 108: train loss 3.348949408989417 val loss 3.3855504013990103
# Time elapsed: 14.19 min
# Epoch 109: train loss 3.3130616313240058 val loss 3.3737656452153857 (no improvement 5)
# Epoch 109: train loss 3.3130616313240058 val loss 3.3737656452153857
# Time elapsed: 14.32 min
# Epoch 110: train loss 3.3353472637983277 val loss 3.2302583352515573
# Time elapsed: 14.45 min
# Epoch 111: train loss 3.3267440089667346 val loss 3.2449747010281214 (no improvement 1)
# Epoch 111: train loss 3.3267440089667346 val loss 3.2449747010281214
# Time elapsed: 14.58 min
# Epoch 112: train loss 3.296201509296754 val loss 3.324812934273168 (no improvement 2)
# Epoch 112: train loss 3.296201509296754 val loss 3.324812934273168
# Time elapsed: 14.71 min
# Epoch 113: train loss 3.282080367819664 val loss 3.3182760724895877 (no improvement 3)
# Epoch 113: train loss 3.282080367819664 val loss 3.3182760724895877
# Time elapsed: 14.84 min
# Epoch 114: train loss 3.2964850956215543 val loss 3.2208951830863954
# Time elapsed: 14.97 min
# Epoch 115: train loss 3.2602216858032023 val loss 3.2544302984287863 (no improvement 1)
# Epoch 115: train loss 3.2602216858032023 val loss 3.2544302984287863
# Time elapsed: 15.10 min
# Epoch 116: train loss 3.3128282617725118 val loss 3.3587573948659393 (no improvement 2)
# Epoch 116: train loss 3.3128282617725118 val loss 3.3587573948659393
# Time elapsed: 15.23 min
# Epoch 117: train loss 3.3248454016838833 val loss 3.210689629379072
# Time elapsed: 15.36 min
# Epoch 118: train loss 3.2489604924416318 val loss 3.2307117678617177 (no improvement 1)
# Epoch 118: train loss 3.2489604924416318 val loss 3.2307117678617177
# Time elapsed: 15.49 min
# Epoch 119: train loss 3.3495868586108717 val loss 3.247057897166202 (no improvement 2)
# Epoch 119: train loss 3.3495868586108717 val loss 3.247057897166202
# Time elapsed: 15.62 min
# Epoch 120: train loss 3.2072479299011643 val loss 3.3498976343556452 (no improvement 3)
# Epoch 120: train loss 3.2072479299011643 val loss 3.3498976343556452
# Time elapsed: 15.75 min
# Epoch 121: train loss 3.252981515102823 val loss 3.3533204875494302 (no improvement 4)
# Epoch 121: train loss 3.252981515102823 val loss 3.3533204875494302
# Time elapsed: 15.88 min
# Epoch 122: train loss 3.213306863193221 val loss 3.187501645088196
# Time elapsed: 16.01 min
# Epoch 123: train loss 3.210076810171207 val loss 3.1977943247870395 (no improvement 1)
# Epoch 123: train loss 3.210076810171207 val loss 3.1977943247870395
# Time elapsed: 16.14 min
# Epoch 124: train loss 3.248586119445557 val loss 3.1707507781292263
# Time elapsed: 16.27 min
# Epoch 125: train loss 3.177939689495194 val loss 3.3266353362484984 (no improvement 1)
# Epoch 125: train loss 3.177939689495194 val loss 3.3266353362484984
# Time elapsed: 16.40 min
# Epoch 126: train loss 3.206643926985387 val loss 3.2120170709333924 (no improvement 2)
# Epoch 126: train loss 3.206643926985387 val loss 3.2120170709333924
# Time elapsed: 16.53 min
# Epoch 127: train loss 3.176428680889693 val loss 3.3311093819768804 (no improvement 3)
# Epoch 127: train loss 3.176428680889693 val loss 3.3311093819768804
# Time elapsed: 16.66 min
# Epoch 128: train loss 3.176725891589279 val loss 3.195173651607413 (no improvement 4)
# Epoch 128: train loss 3.176725891589279 val loss 3.195173651607413
# Time elapsed: 16.79 min
# Epoch 129: train loss 3.147228780591712 val loss 3.1990775196175827 (no improvement 5)
# Epoch 129: train loss 3.147228780591712 val loss 3.1990775196175827
# Time elapsed: 16.92 min
# Epoch 130: train loss 3.1550650982439796 val loss 3.1785878626923814 (no improvement 6)
# Epoch 130: train loss 3.1550650982439796 val loss 3.1785878626923814
# Time elapsed: 17.05 min
# Epoch 131: train loss 3.159286500169008 val loss 3.274282039466657 (no improvement 7)
# Epoch 131: train loss 3.159286500169008 val loss 3.274282039466657
# Time elapsed: 17.18 min
# Epoch 132: train loss 3.1413241259823663 val loss 3.277030623900263 (no improvement 8)
# Epoch 132: train loss 3.1413241259823663 val loss 3.277030623900263
# Time elapsed: 17.32 min
# Epoch 133: train loss 3.1477121800499064 val loss 3.3456426149920415 (no improvement 9)
# Epoch 133: train loss 3.1477121800499064 val loss 3.3456426149920415
# Time elapsed: 17.45 min
# Epoch 134: train loss 3.119075489908177 val loss 3.260385478797712 (no improvement 10)
# Epoch 134: train loss 3.119075489908177 val loss 3.260385478797712
# Time elapsed: 17.58 min
# Epoch 135: train loss 3.11115930155969 val loss 3.194626884083999 (no improvement 11)
# Epoch 135: train loss 3.11115930155969 val loss 3.194626884083999
# Time elapsed: 17.71 min
# Epoch 136: train loss 3.102113805413946 val loss 3.2049026257113407 (no improvement 12)
# Epoch 136: train loss 3.102113805413946 val loss 3.2049026257113407
# Time elapsed: 17.84 min
# Epoch 137: train loss 3.1195230177503097 val loss 3.1918865177192184 (no improvement 13)
# Epoch 137: train loss 3.1195230177503097 val loss 3.1918865177192184
# Time elapsed: 17.97 min
# Epoch 138: train loss 3.11208211342004 val loss 3.256960645474886 (no improvement 14)
# Epoch 138: train loss 3.11208211342004 val loss 3.256960645474886
# Time elapsed: 18.10 min
# Epoch 139: train loss 3.082829475297894 val loss 3.2482791975924843 (no improvement 15)
# Epoch 139: train loss 3.082829475297894 val loss 3.2482791975924843
# Time elapsed: 18.23 min
# Epoch 140: train loss 3.083138441597002 val loss 3.234994896775798 (no improvement 16)
# Epoch 140: train loss 3.083138441597002 val loss 3.234994896775798
# Time elapsed: 18.36 min
# Epoch 141: train loss 3.1002215237614696 val loss 3.178088836920889 (no improvement 17)
# Epoch 141: train loss 3.1002215237614696 val loss 3.178088836920889
# Time elapsed: 18.49 min
# Epoch 142: train loss 3.0782068354632934 val loss 3.226351799149262 (no improvement 18)
# Epoch 142: train loss 3.0782068354632934 val loss 3.226351799149262
# Time elapsed: 18.62 min
# Epoch 143: train loss 3.0564606122917413 val loss 3.212278414713709 (no improvement 19)
# Epoch 143: train loss 3.0564606122917413 val loss 3.212278414713709
# Time elapsed: 18.75 min
# Epoch 144: train loss 3.0712942518468753 val loss 3.2473526502910413 (no improvement 20)
# Epoch 144: train loss 3.0712942518468753 val loss 3.2473526502910413
# Time elapsed: 18.88 min
# Epoch 145: train loss 3.046818852651987 val loss 3.200151101225301 (no improvement 21)
# Epoch 145: train loss 3.046818852651987 val loss 3.200151101225301
# Time elapsed: 19.01 min
# Epoch 146: train loss 3.058424996535683 val loss 3.112705909264715
# Time elapsed: 19.14 min
# Epoch 147: train loss 3.0327904826738465 val loss 3.1819959314245927 (no improvement 1)
# Epoch 147: train loss 3.0327904826738465 val loss 3.1819959314245927
# Time elapsed: 19.27 min
# Epoch 148: train loss 3.0480601750314236 val loss 3.1508982984643232 (no improvement 2)
# Epoch 148: train loss 3.0480601750314236 val loss 3.1508982984643232
# Time elapsed: 19.40 min
# Epoch 149: train loss 3.02592711183002 val loss 3.2588428440846893 (no improvement 3)
# Epoch 149: train loss 3.02592711183002 val loss 3.2588428440846893
# Time elapsed: 19.53 min
# Epoch 150: train loss 3.0188390937996723 val loss 3.0991505497380305
# Time elapsed: 19.66 min
# Epoch 151: train loss 3.009660517053565 val loss 3.0867706236086394
# Time elapsed: 19.79 min
# Epoch 152: train loss 3.0114416463624143 val loss 3.1520786903406446 (no improvement 1)
# Epoch 152: train loss 3.0114416463624143 val loss 3.1520786903406446
# Time elapsed: 19.92 min
# Epoch 153: train loss 3.012717479516363 val loss 3.2109748388591566 (no improvement 2)
# Epoch 153: train loss 3.012717479516363 val loss 3.2109748388591566
# Time elapsed: 20.05 min
# Epoch 154: train loss 2.9899097925725395 val loss 3.0982012438146693 (no improvement 3)
# Epoch 154: train loss 2.9899097925725395 val loss 3.0982012438146693
# Time elapsed: 20.18 min
# Epoch 155: train loss 3.0000957388238447 val loss 3.255474994370812 (no improvement 4)
# Epoch 155: train loss 3.0000957388238447 val loss 3.255474994370812
# Time elapsed: 20.31 min
# Epoch 156: train loss 2.994159546781314 val loss 3.120477156890066 (no improvement 5)
# Epoch 156: train loss 2.994159546781314 val loss 3.120477156890066
# Time elapsed: 20.45 min
# Epoch 157: train loss 2.980569534091183 val loss 3.1821873376243994 (no improvement 6)
# Epoch 157: train loss 2.980569534091183 val loss 3.1821873376243994
# Time elapsed: 20.58 min
# Epoch 158: train loss 2.9862537880738578 val loss 3.2403869133246572 (no improvement 7)
# Epoch 158: train loss 2.9862537880738578 val loss 3.2403869133246572
# Time elapsed: 20.71 min
# Epoch 159: train loss 2.9626856192316806 val loss 3.182434757916551 (no improvement 8)
# Epoch 159: train loss 2.9626856192316806 val loss 3.182434757916551
# Time elapsed: 20.84 min
# Epoch 160: train loss 2.956063250735612 val loss 3.0895582641425885 (no improvement 9)
# Epoch 160: train loss 2.956063250735612 val loss 3.0895582641425885
# Time elapsed: 20.97 min
# Epoch 161: train loss 2.9617632605800046 val loss 3.1051485990223133 (no improvement 10)
# Epoch 161: train loss 2.9617632605800046 val loss 3.1051485990223133
# Time elapsed: 21.10 min
# Epoch 162: train loss 2.9527107061459703 val loss 3.171449832226101 (no improvement 11)
# Epoch 162: train loss 2.9527107061459703 val loss 3.171449832226101
# Time elapsed: 21.23 min
# Epoch 163: train loss 2.978834814326444 val loss 3.134045096761302 (no improvement 12)
# Epoch 163: train loss 2.978834814326444 val loss 3.134045096761302
# Time elapsed: 21.36 min
# Epoch 164: train loss 2.939212532163086 val loss 3.2011837087179487 (no improvement 13)
# Epoch 164: train loss 2.939212532163086 val loss 3.2011837087179487
# Time elapsed: 21.49 min
# Epoch 165: train loss 2.93405445833896 val loss 3.171401889073221 (no improvement 14)
# Epoch 165: train loss 2.93405445833896 val loss 3.171401889073221
# Time elapsed: 21.62 min
# Epoch 166: train loss 2.945109540019447 val loss 3.127559089033227 (no improvement 15)
# Epoch 166: train loss 2.945109540019447 val loss 3.127559089033227
# Time elapsed: 21.75 min
# Epoch 167: train loss 2.9232832656674823 val loss 3.1868065601901003 (no improvement 16)
# Epoch 167: train loss 2.9232832656674823 val loss 3.1868065601901003
# Time elapsed: 21.88 min
# Epoch 168: train loss 2.911534480654368 val loss 3.0959014142814434 (no improvement 17)
# Epoch 168: train loss 2.911534480654368 val loss 3.0959014142814434
# Time elapsed: 22.01 min
# Epoch 169: train loss 2.9131517026118687 val loss 3.153570648243553 (no improvement 18)
# Epoch 169: train loss 2.9131517026118687 val loss 3.153570648243553
# Time elapsed: 22.14 min
# Epoch 170: train loss 2.907894583760013 val loss 3.107917818897649 (no improvement 19)
# Epoch 170: train loss 2.907894583760013 val loss 3.107917818897649
# Time elapsed: 22.27 min
# Epoch 171: train loss 2.968692078268234 val loss 3.247209021919652 (no improvement 20)
# Epoch 171: train loss 2.968692078268234 val loss 3.247209021919652
# Time elapsed: 22.40 min
# Epoch 172: train loss 2.892632608594889 val loss 3.152958209734214 (no improvement 21)
# Epoch 172: train loss 2.892632608594889 val loss 3.152958209734214
# Time elapsed: 22.53 min
# Epoch 173: train loss 2.8772261009284867 val loss 3.0951871821754855 (no improvement 22)
# Epoch 173: train loss 2.8772261009284867 val loss 3.0951871821754855
# Time elapsed: 22.66 min
# Epoch 174: train loss 2.8957181062566844 val loss 3.1200083873773874 (no improvement 23)
# Epoch 174: train loss 2.8957181062566844 val loss 3.1200083873773874
# Time elapsed: 22.79 min
# Epoch 175: train loss 2.8977630294142336 val loss 3.0837773815581673
# Time elapsed: 22.92 min
# Epoch 176: train loss 2.872789487741153 val loss 3.206576747957029 (no improvement 1)
# Epoch 176: train loss 2.872789487741153 val loss 3.206576747957029
# Time elapsed: 23.05 min
# Epoch 177: train loss 2.867696335661649 val loss 3.0938632485113646 (no improvement 2)
# Epoch 177: train loss 2.867696335661649 val loss 3.0938632485113646
# Time elapsed: 23.18 min
# Epoch 178: train loss 2.876197294353949 val loss 3.1340852004917044 (no improvement 3)
# Epoch 178: train loss 2.876197294353949 val loss 3.1340852004917044
# Time elapsed: 23.31 min
# Epoch 179: train loss 2.867856863606284 val loss 3.156098657532742 (no improvement 4)
# Epoch 179: train loss 2.867856863606284 val loss 3.156098657532742
# Time elapsed: 23.45 min
# Epoch 180: train loss 2.8631314705322746 val loss 3.0416741650355488
# Time elapsed: 23.58 min
# Epoch 181: train loss 2.8620711935141907 val loss 3.2996095152277696 (no improvement 1)
# Epoch 181: train loss 2.8620711935141907 val loss 3.2996095152277696
# Time elapsed: 23.71 min
# Epoch 182: train loss 2.85470137042059 val loss 3.142803451262022 (no improvement 2)
# Epoch 182: train loss 2.85470137042059 val loss 3.142803451262022
# Time elapsed: 23.84 min
# Epoch 183: train loss 2.844550205018599 val loss 3.115187511632317 (no improvement 3)
# Epoch 183: train loss 2.844550205018599 val loss 3.115187511632317
# Time elapsed: 23.97 min
# Epoch 184: train loss 2.8498907124824786 val loss 3.0936098726172196 (no improvement 4)
# Epoch 184: train loss 2.8498907124824786 val loss 3.0936098726172196
# Time elapsed: 24.10 min
# Epoch 185: train loss 2.848350022198029 val loss 3.113644163859518 (no improvement 5)
# Epoch 185: train loss 2.848350022198029 val loss 3.113644163859518
# Time elapsed: 24.23 min
# Epoch 186: train loss 2.873997299262965 val loss 3.1364923125819155 (no improvement 6)
# Epoch 186: train loss 2.873997299262965 val loss 3.1364923125819155
# Time elapsed: 24.36 min
# Epoch 187: train loss 2.8121078347463704 val loss 3.0688719071839987 (no improvement 7)
# Epoch 187: train loss 2.8121078347463704 val loss 3.0688719071839987
# Time elapsed: 24.49 min
# Epoch 188: train loss 2.8445339958782485 val loss 3.1235549098566957 (no improvement 8)
# Epoch 188: train loss 2.8445339958782485 val loss 3.1235549098566957
# Time elapsed: 24.62 min
# Epoch 189: train loss 2.8104502322860587 val loss 3.088621877369128 (no improvement 9)
# Epoch 189: train loss 2.8104502322860587 val loss 3.088621877369128
# Time elapsed: 24.75 min
# Epoch 190: train loss 2.8267105096784975 val loss 3.161259783569135 (no improvement 10)
# Epoch 190: train loss 2.8267105096784975 val loss 3.161259783569135
# Time elapsed: 24.88 min
# Epoch 191: train loss 2.807089222577606 val loss 3.1042240582014387 (no improvement 11)
# Epoch 191: train loss 2.807089222577606 val loss 3.1042240582014387
# Time elapsed: 25.01 min
# Epoch 192: train loss 2.8171062695098597 val loss 3.0884060922421908 (no improvement 12)
# Epoch 192: train loss 2.8171062695098597 val loss 3.0884060922421908
# Time elapsed: 25.14 min
# Epoch 193: train loss 2.8590802801466886 val loss 3.1164983175302807 (no improvement 13)
# Epoch 193: train loss 2.8590802801466886 val loss 3.1164983175302807
# Time elapsed: 25.27 min
# Epoch 194: train loss 2.7931883719360604 val loss 3.233207568996831 (no improvement 14)
# Epoch 194: train loss 2.7931883719360604 val loss 3.233207568996831
# Time elapsed: 25.40 min
# Epoch 195: train loss 2.7884560860693455 val loss 3.151755806646849 (no improvement 15)
# Epoch 195: train loss 2.7884560860693455 val loss 3.151755806646849
# Time elapsed: 25.53 min
# Epoch 196: train loss 2.784247541354156 val loss 3.19639564689837 (no improvement 16)
# Epoch 196: train loss 2.784247541354156 val loss 3.19639564689837
# Time elapsed: 25.66 min
# Epoch 197: train loss 2.802533938991072 val loss 3.0864259214777694 (no improvement 17)
# Epoch 197: train loss 2.802533938991072 val loss 3.0864259214777694
# Time elapsed: 25.79 min
# Epoch 198: train loss 2.7814574086942443 val loss 3.099287560739015 (no improvement 18)
# Epoch 198: train loss 2.7814574086942443 val loss 3.099287560739015
# Time elapsed: 25.92 min
# Epoch 199: train loss 2.7810632279186462 val loss 3.135213962824721 (no improvement 19)
# Epoch 199: train loss 2.7810632279186462 val loss 3.135213962824721
# Time elapsed: 26.05 min
# Epoch 200: train loss 2.773959104339002 val loss 3.138176151325828 (no improvement 20)
# Epoch 200: train loss 2.773959104339002 val loss 3.138176151325828
# Time elapsed: 26.18 min
# Epoch 201: train loss 2.7531336783190987 val loss 3.0868300715559407 (no improvement 21)
# Epoch 201: train loss 2.7531336783190987 val loss 3.0868300715559407
# Time elapsed: 26.31 min
# Epoch 202: train loss 2.7824868380306333 val loss 3.078383531068501 (no improvement 22)
# Epoch 202: train loss 2.7824868380306333 val loss 3.078383531068501
# Time elapsed: 26.45 min
# Epoch 203: train loss 2.759987091881708 val loss 3.145202021536074 (no improvement 23)
# Epoch 203: train loss 2.759987091881708 val loss 3.145202021536074
# Time elapsed: 26.58 min
# Epoch 204: train loss 2.747390539109917 val loss 3.114095299494894 (no improvement 24)
# Epoch 204: train loss 2.747390539109917 val loss 3.114095299494894
# Time elapsed: 26.71 min
# Epoch 205: train loss 2.7906648562127994 val loss 3.1280579196779352 (no improvement 25)
# Epoch 205: train loss 2.7906648562127994 val loss 3.1280579196779352
# Time elapsed: 26.84 min
# Epoch 206: train loss 2.747483536216295 val loss 3.120500025623723 (no improvement 26)
# Epoch 206: train loss 2.747483536216295 val loss 3.120500025623723
# Time elapsed: 26.97 min
# Epoch 207: train loss 2.7564292499367062 val loss 3.2194376562771043 (no improvement 27)
# Epoch 207: train loss 2.7564292499367062 val loss 3.2194376562771043
# Time elapsed: 27.10 min
# Epoch 208: train loss 2.7431809272564633 val loss 3.119978298482142 (no improvement 28)
# Epoch 208: train loss 2.7431809272564633 val loss 3.119978298482142
# Time elapsed: 27.23 min
# Epoch 209: train loss 2.7434865001134328 val loss 3.1144353240728377 (no improvement 29)
# Epoch 209: train loss 2.7434865001134328 val loss 3.1144353240728377
# Time elapsed: 27.36 min
# No improvement after 30 epochs, stopping early
# Total Training Time: 27.36 min

# %%
ax = plt.figure().gca()

ax.plot(history['train'])
ax.plot(history['val'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'])
plt.title('Loss over training epochs')
plt.show();

# %% [markdown]
# Our model converged quite well. Seems like we might've needed a larger validation set to smoothen the results, but that'll do for now.

# %% [markdown]
# ### Saving the model

# %% [markdown]
# Let's store the model for later use:

# %%
# MODEL_PATH = 'model/Final_AE_10u_v1.pth'

# torch.save(model, MODEL_PATH)

# %% [markdown]
# ### Saving a history to file

# %%
# import pickle

# # save dictionary to person_data.pkl file
# with open('history/Final_AE_10u_v1.pkl', 'wb') as fp:
#     pickle.dump(history, fp)
#     print('History dictionary saved successfully to file')

# %% [markdown]
# ### Load Model

# %% [markdown]
# Uncomment the next lines, if you want to download and load the pre-trained model:

# %%
model = torch.load('model/Final_AE_10u_v1.pth')
model = model.to(device)

# %% [markdown]
# ### Load History

# %%
import pickle

# Read dictionary pkl file
with open('history/Final_AE_10u_v1.pkl', 'rb') as fp:
    history = pickle.load(fp)
    print('History dictionary')
    print(history.keys())
# Out:
# History dictionary
# dict_keys(['train', 'val'])

# %%
ax = plt.figure().gca()

ax.plot(history['train'])
ax.plot(history['val'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'])
plt.title('Loss over training epochs')
plt.show();

# %% [markdown]
# ### Choosing a threshold

# %%
def predict(model, dataset):
    predictions, losses, abs_errs = [], [], []
    criterion = nn.L1Loss(reduction='sum').to(device)
    with torch.no_grad():
        model = model.eval()
        for seq_true in dataset:
            seq_true = seq_true.to(device)
            seq_pred = model(seq_true)

            loss = criterion(seq_pred, seq_true)
            
            abs_err = np.abs((seq_true.detach().cpu().numpy() - seq_pred.detach().cpu().numpy())/seq_pred.detach().cpu().numpy())

            predictions.append(seq_pred.cpu().numpy().flatten())
            losses.append(loss.item())
            abs_errs.append(abs_err.sum())
    return predictions, losses, abs_errs

# %%
_, losses, abs_errs = predict(model, train_dataset)

sns.distplot(losses, bins=50, kde=True);

# %%
sns.distplot(abs_errs, bins=50, kde=True);

# %%
THRESHOLD = 4

# %%
predictions, pred_losses, abs_errs = predict(model, test_normal_dataset)
sns.distplot(pred_losses, bins=50, kde=True);

# %%
correct = sum(l <= THRESHOLD for l in pred_losses)
print(f'Correct normal predictions: {correct}/{len(test_normal_dataset)}')
# Out:
# Correct normal predictions: 75/95

# %% [markdown]
# ### Looking at Examples

# %%
def plot_prediction(data, model, title, ax, random_state=None):
    predictions, pred_losses, _ = predict(model, [data])

    ax.plot(data, label='true')
    ax.plot(predictions[0], label='reconstructed')
    ax.set_title(f'{title} (loss: {np.around(pred_losses[0], 2)})')
    ax.set_xlim(0, len(test_normal_dataset[1])-1)
    ax.legend()

# %%
# In Training
fig, axs = plt.subplots(
  nrows=4,
  ncols=3,
  # sharey=True,
  # sharex=True,
  figsize=(22, 8)
)

for i, data in enumerate(train_dataset[0:3]):
    plot_prediction(data, model, title='Normal', ax=axs[0, i])
    
for i, data in enumerate(train_dataset[3:6]):
    plot_prediction(data, model, title='Normal', ax=axs[1, i])
    
for i, data in enumerate(train_dataset[6:9]):
    plot_prediction(data, model, title='Normal', ax=axs[2, i])
    
for i, data in enumerate(train_dataset[9:12]):
    plot_prediction(data, model, title='Normal', ax=axs[3, i])

plt.tight_layout()

# %%
def plot_prediction(data, model, title, ax, random_state=None):
    predictions, pred_losses, pred_abs_errs = predict(model, [data])

    ax.plot(data, label='true')
    ax.plot(predictions[0], label='reconstructed')
    ax.set_title(f'{title} (Relative Error: {np.round(pred_abs_errs[0], 2):.2f})')
    ax.grid(True)
    ax.set_xlim(0, len(test_normal_dataset[1])-1)
    
    ax.legend()

# %%
# In Training
fig, axs = plt.subplots(
  nrows=4,
  ncols=3,
  # sharey=True,
  # sharex=True,
  figsize=(22, 8)
)

for i, data in enumerate(train_dataset[0:3]):
    plot_prediction(data, model, title='Normal', ax=axs[0, i])
    
for i, data in enumerate(train_dataset[3:6]):
    plot_prediction(data, model, title='Normal', ax=axs[1, i])
    
for i, data in enumerate(train_dataset[6:9]):
    plot_prediction(data, model, title='Normal', ax=axs[2, i])
    
for i, data in enumerate(train_dataset[9:12]):
    plot_prediction(data, model, title='Normal', ax=axs[3, i])

plt.tight_layout()

# %%
def plot_mse(data, model, ax, random_state=None):
    predictions, pred_losses, pred_abs_errs = predict(model, [data])
    
    mses = np.abs(data.T[0] - predictions[0])
    # print(mses.shape)         #-> torch.Size([96])
    ax.imshow(np.atleast_2d(mses), aspect=4, cmap='Reds')
    ax.set_title(f'Relative Error')
    ax.set_xticks([])
    ax.set_yticks([])

# %%
# Looking at ONE sample
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(12, 8))
fig.subplots_adjust(top=0.6)

data = test_normal_dataset[9]

plot_prediction(data, model, title='Normal', ax=axs[0], random_state=42)
plot_mse(data, model, ax=axs[1], random_state=42)

# %% [markdown]
# ### Testing

# %%
# Looking at MANY samples
numberofloop = 4

fig, axs = plt.subplots(nrows=2*numberofloop, ncols=3, figsize=(22, 20))
fig.subplots_adjust(hspace=0.0) # set the vertical space between subplots
fig.subplots_adjust(wspace=0.1) # set the horizontal space between subplots

for i, data in enumerate(train_dataset[0:3]):
    plot_prediction(data, model, title='Normal', ax=axs[0, i], random_state=42)
    plot_mse(data, model, ax=axs[1, i], random_state=42)
    
for i, data in enumerate(train_dataset[3:6]):
    plot_prediction(data, model, title='Normal', ax=axs[2, i], random_state=42)
    plot_mse(data, model, ax=axs[3, i], random_state=42)
    
for i, data in enumerate(train_dataset[7:10]):
    plot_prediction(data, model, title='Normal', ax=axs[4, i], random_state=42)
    plot_mse(data, model, ax=axs[5, i], random_state=42)
    
for i, data in enumerate(train_dataset[11:14]):
    plot_prediction(data, model, title='Normal', ax=axs[6, i], random_state=42)
    plot_mse(data, model, ax=axs[7, i], random_state=42)

# %%
from sklearn.metrics import mean_absolute_error
from matplotlib.colors import LinearSegmentedColormap

fig, ax = plt.subplots(
  nrows=2,
  ncols=1,
  # sharey=True,
  # sharex=True,
  figsize=(15, 6)
)

predictions, pred_losses = predict(model, [test_normal_dataset[1]])

mse = np.abs(test_normal_dataset[1].T[0] - predictions[0])

ax[0].plot(test_normal_dataset[1], label='true')
ax[0].plot(predictions[0], label='reconstructed')
ax[0].grid(True)
ax[0].legend()
ax[0].set_xlim(0, len(test_normal_dataset[1])-1)

cmap = LinearSegmentedColormap.from_list('RedGreenRed', ['lime', 'crimson'])
# ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Wistia', vmin=0, vmax=0.1)
ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Reds', vmin=0, vmax=0.3)
ax[1].set_xticks([])
ax[1].set_yticks([])

# plt.tight_layout();
# Out:
# []

# %% [markdown]
# ## Generate Attack Type

# %%
# Generate artificial samples for attack type 1: Consumption profile modification
def generate_attack_type_1(data):
    data_copy = data.copy()
    alpha = np.random.uniform(0.1, 0.8)
    return data_copy * alpha

# Generate artificial samples for attack type 2: Meter data modification
def generate_attack_type_2(data):
    data_copy = data.copy()
    gamma = np.random.uniform(0.2, 0.8, size=data_copy.shape)
    return data_copy * gamma


# Generate artificial samples for attack type 3: Meter tampering detection evasion
def generate_attack_type_3(data):
    start_time = np.random.randint(0, 96 - 6)
    duration = np.random.randint(6, 96)
    end_time = start_time + duration
    attack = data.copy()
    attack[start_time:end_time] = 0
    return attack

# Generate artificial samples for attack type 4: Magnetic field detection evasion
def generate_attack_type_4(data):
    data_copy = data.copy()
    mean_value = np.mean(data_copy)
    mean_value = np.full(data_copy.shape[0], mean_value)
    gamma = np.random.uniform(0.2, 0.8, size=data_copy.shape)
    return gamma * mean_value

# Generate artificial samples for attack type 5: Jamming attack
def generate_attack_type_5(data):
    data_copy = data.copy()
    mean_value = np.mean(data_copy)
    return np.full(data_copy.shape[0], mean_value)

# Generate artificial samples for attack type 6: False data injection
def generate_attack_type_6(data):
    data_copy = data.copy()
    inverted_data = data_copy[::-1]
    return inverted_data

# %%
# Seleted user
user_6 = clean_data(df, 6)
user_6
# Out:
#                        KWH
# DATE-Time
# 2021-01-01 00:00:00  0.154
# 2021-01-01 00:15:00  0.143
# 2021-01-01 00:30:00  0.157
# 2021-01-01 00:45:00  0.128
# 2021-01-01 01:00:00  0.115
# ...                    ...
# 2021-08-31 22:45:00  0.325
# 2021-08-31 23:00:00  0.279
# 2021-08-31 23:15:00  0.292
# 2021-08-31 23:30:00  0.236
# 2021-08-31 23:45:00  0.227
#
# [22944 rows x 1 columns]

# %%
# Example usage
window_size = 96
user_6 = user_6.to_numpy()
windowed_data_user_6 = create_windowed_dataset(user_6, window_size)
print(f" Window shape : {windowed_data_user_6.shape}")
print(f" Type of Window : {type(windowed_data_user_6)}")
# Out:
#  Window shape : (239, 96)
#  Type of Window : <class 'numpy.ndarray'>

# %%
user_6_normal_dataset, _, _ = create_dataset(windowed_data_user_6)   # We got list of tensor

# %% [markdown]
# 1. torch.Tensor().numpy()
# 2. torch.Tensor().cpu().data.numpy()
# 3. torch.Tensor().cpu().detach().numpy()

# %%
# Convert each tensor to numpy array and append to a new list
numpy_list = []
for tensor in user_6_normal_dataset:
    numpy_list.append(tensor.numpy())

# Convert list of numpy arrays to a 3D numpy array
user_6_normal_dataset = np.array(numpy_list)

# %%
day = 0
windowed_data_test = user_6_normal_dataset.copy()
attack_type_1 = generate_attack_type_1(windowed_data_test[day])
attack_type_2 = generate_attack_type_2(windowed_data_test[day])
attack_type_3 = generate_attack_type_3(windowed_data_test[day])
attack_type_4 = generate_attack_type_4(windowed_data_test[day])
attack_type_5 = generate_attack_type_5(windowed_data_test[day])
attack_type_6 = generate_attack_type_6(windowed_data_test[day])
# Plot the original data and the modified data
plt.plot(user_6_normal_dataset[day])
plt.plot(attack_type_1)
plt.plot(attack_type_2)
plt.plot(attack_type_3)
plt.plot(attack_type_4)
plt.plot(attack_type_5)
plt.plot(attack_type_6)
plt.title("Original & Attack Types: Consumption Profile")
plt.xlabel("Time (hours)")
plt.ylabel("Energy Consumption (KWH)")
plt.legend(["Original Data", "Type_1", "Type_2", "Type_3", "Type_4", "Type_5", "Type_6"])
plt.show()

# %% [markdown]
# ### Choosing a threshold

# %% [markdown]
# With our model at hand, we can have a look at the reconstruction error on the training set. Let's start by writing a helper function to get predictions from our model:

# %%
def predict(model, dataset):
    predictions, losses = [], []
    criterion = nn.L1Loss(reduction='sum').to(device)
    with torch.no_grad():
        model = model.eval()
        for seq_true in dataset:
            seq_true = seq_true.to(device)
            seq_pred = model(seq_true)

            loss = criterion(seq_pred, seq_true)

            predictions.append(seq_pred.cpu().numpy().flatten())
            losses.append(loss.item())
    return predictions, losses

# %% [markdown]
# Our function goes through each example in the dataset and records the predictions and losses. Let's get the losses and have a look at them:

# %%
_, losses = predict(model, train_dataset)

sns.distplot(losses, bins=50, kde=True);

# %%
THRESHOLD = 4

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Using the threshold, we can turn the problem into a simple binary classification task:
#
# * If the reconstruction loss for an example is below the threshold, we'll classify it as a normal heartbeat
# * Alternatively, if the loss is higher than the threshold, we'll classify it as an anomaly

# %% [markdown]
# ### Normal energy consumption

# %% [markdown]
# Let's check how well our model does on normal datasets. We'll use the normal datasets from the test set (our model haven't seen those):

# %%
predictions, pred_losses = predict(model, test_normal_dataset)
sns.distplot(pred_losses, bins=50, kde=True);

# %% [markdown]
# We'll count the correct predictions:

# %%
correct = sum(l <= THRESHOLD for l in pred_losses)
print(f'Correct normal predictions: {correct}/{len(test_normal_dataset)}')
# Out:
# Correct normal predictions: 847/874

# %% [markdown]
# ### Anomalies

# %% [markdown]
# We'll do the same with the anomaly examples, but their number is much higher. We'll get a subset that has the same size as the normal datasets:

# %% [markdown]
# We can add this type of theif attacks

# %%
type(test_normal_dataset[0])
# Out:
# torch.Tensor

# %%
attack_type_3 = generate_attack_type_3(windowed_data_test[day])  #It has the shape (96, 1)

# %%
attack_type_3 = create_windowed_dataset(attack_type_3, 96)     #Reshape, it should has shape (1, 96)

# %%
attack_type_3, _, _ = create_dataset(attack_type_3)            #List of Tensor

# %%
day = 0
windowed_data_test = user_6_normal_dataset.copy()

# %%
windowed_data_test = create_windowed_dataset(windowed_data_test[day], 96)
windowed_data_test, _, _ = create_dataset(windowed_data_test)

# %%
# anomaly_dataset = test_anomaly_dataset[:len(test_normal_dataset)]

# %% [markdown]
# Now we can take the predictions of our model for the subset of anomalies:

# %%
predictions, pred_losses = predict(model, attack_type_3)
sns.distplot(pred_losses, bins=50, kde=True);

# %% [markdown]
# Finally, we can count the number of examples above the threshold (considered as anomalies):

# %% [markdown]
# We have very good results. In the real world, you can tweak the threshold depending on what kind of errors you want to tolerate. In this case, you might want to have more false positives (normal heartbeats considered as anomalies) than false negatives (anomalies considered as normal).

# %% [markdown]
# ### Looking at Examples

# %% [markdown]
# We can overlay the real and reconstructed Time Series values to see how close they are. We'll do it for some normal and anomaly cases:

# %%
predictions, pred_losses = predict(model, [test_normal_dataset[21]])

# %%
print(len(test_normal_dataset[21]))
# Out:
# 96

# %%
mse = np.abs(test_normal_dataset[21] - predictions[0])
mse.shape
# Out:
# torch.Size([96, 96])

# %%
test_normal_dataset[21].T[0].shape
# Out:
# torch.Size([96])

# %%
mse = np.abs(test_normal_dataset[21].T[0] - predictions[0])
mse.shape
# Out:
# torch.Size([96])

# %%
def reconstructed_probability(self, x: torch.Tensor) -> torch.Tensor:
        """
        Computes the probability density of the input samples under the learned
        distribution of reconstructed data.
        Args:
            x: Input data tensor of shape (batch_size, num_features).
        Returns:
            A tensor of shape (batch_size,) containing the probability densities of
            the input samples under the learned distribution of reconstructed data.
        """
        with torch.no_grad():
            pred = self.predict(x)
        recon_dist = Normal(pred['recon_mu'], pred['recon_sigma'])
        x = x.unsqueeze(0)
        p = recon_dist.log_prob(x).exp().mean(dim=0).mean(dim=-1)  # vector of shape [batch_size]
        return p

# %%
from scipy.stats import norm
# Fit a normal distribution to the data:
mu, std = norm.fit(test_normal_dataset[21].T[0])

# %%
print(mu)
print(std)
# Out:
# 0.15803124
# 0.08255976

# %% [markdown]
# https://github.com/hupili/python-for-data-and-media-communication-gitbook/issues/118

# %% [markdown]
# ### Probability Reconstruction Loss
# https://github.com/Michedev/VAE_anomaly_detection/blob/master/model/VAE.py

# %%
from sklearn.metrics import mean_absolute_error
from matplotlib.colors import LinearSegmentedColormap

fig, ax = plt.subplots(
  nrows=2,
  ncols=1,
  # sharey=True,
  # sharex=True,
  figsize=(15, 8)
)

predictions, pred_losses = predict(model, [windowed_data_test[0]])

mse = np.abs(windowed_data_test[0].T[0] - predictions[0])

ax[0].plot(windowed_data_test[0], label='true')
ax[0].plot(predictions[0], label='reconstructed')
ax[0].grid(True)
ax[0].legend()
ax[0].set_xlim(0, len(windowed_data_test[0])-1)

cmap = LinearSegmentedColormap.from_list('RedGreenRed', ['lime', 'crimson'])
# ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Wistia', vmin=0, vmax=0.1)
ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Reds', vmin=0, vmax=0.3)
ax[1].set_xticks([])
ax[1].set_yticks([])

# plt.tight_layout();
# Out:
# []

# %%
from sklearn.metrics import mean_absolute_error
from matplotlib.colors import LinearSegmentedColormap

fig, ax = plt.subplots(
  nrows=2,
  ncols=1,
  # sharey=True,
  # sharex=True,
  figsize=(15, 8)
)

predictions, pred_losses = predict(model, [attack_type_3[0]])

mse = np.abs(attack_type_3[0].T[0] - predictions[0])

ax[0].plot(attack_type_3[0], label='true')
ax[0].plot(predictions[0], label='reconstructed')
ax[0].grid(True)
ax[0].legend()
ax[0].set_xlim(0, len(attack_type_3[0])-1)

cmap = LinearSegmentedColormap.from_list('RedGreenRed', ['lime', 'crimson'])
# ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Wistia', vmin=0, vmax=0.1)
ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Reds', vmin=0, vmax=0.3)
ax[1].set_xticks([])
ax[1].set_yticks([])

# plt.tight_layout();
# Out:
# []

# %%
attack_type_1[0][:5]
# Out:
# tensor([[0.0363],
#         [0.0337],
#         [0.0370],
#         [0.0302],
#         [0.0271]])

# %%
test_normal_dataset[21][:5]
# Out:
# tensor([[0.1570],
#         [0.0900],
#         [0.0880],
#         [0.1270],
#         [0.1230]])

# %%
from sklearn.metrics import mean_absolute_error
from matplotlib.colors import LinearSegmentedColormap

fig, ax = plt.subplots(
  nrows=2,
  ncols=1,
  # sharey=True,
  # sharex=True,
  figsize=(22, 8)
)

predictions, pred_losses = predict(model, [test_normal_dataset[21]])

mse = np.abs(test_normal_dataset[21].T[0] - predictions[0])

ax[0].plot(test_normal_dataset[21], label='true')
ax[0].plot(predictions[0], label='reconstructed')
ax[0].grid(True)
ax[0].legend()
ax[0].set_xlim(0, len(test_normal_dataset[21])-1)

cmap = LinearSegmentedColormap.from_list('RedGreenRed', ['lime', 'crimson'])
# ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Wistia', vmin=0, vmax=0.1)
ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Reds', vmin=0, vmax=0.3)
ax[1].set_xticks([])
ax[1].set_yticks([])

# plt.tight_layout();
# Out:
# []

# %%
# [test_normal_dataset[0]]

# %%
def plot_prediction(data, model, title, ax):
    predictions, pred_losses = predict(model, [data])

    ax.plot(data, label='true')
    ax.plot(predictions[0], label='reconstructed')
    ax.set_title(f'{title} (loss: {np.around(pred_losses[0], 2)})')
    
    # ax[1].imshow(np.atleast_2d(pred_losses), aspect=5, cmap='Wistia')
    # ax[1].set_xticks([])
    # ax[1].set_yticks([])
    
    ax.legend()

# %%
# def plot_prediction(data, model, title, ax):
#     predictions, pred_losses = predict(model, [data])
#     pos = int(len(data)-1)
#     se = np.square(data - predictions[0])
#     se = se[:, pos]

#     ax.plot(data, label='true')
#     ax.plot(predictions[0], label='reconstructed')
#     ax.set_title(f'{title} (loss: {np.around(pred_losses[0], 2)})')

#     ax.imshow(np.atleast_3d(se).T, aspect=5, cmap='Wistia')
#     ax.set_xticks([])
#     ax.set_yticks([])
#     ax.legend()

# %%
# from matplotlib.colors import LinearSegmentedColormap
# def plot_prediction(data, model, title, ax):
#     predictions, pred_losses = predict(model, [data])
#     pos = int(len(data)-1)
#     se = np.square(data - predictions[0])
#     se = se[:, pos]

#     ax1 = ax[0]
#     ax1.plot(data, label='true')
#     ax1.plot(predictions[0], label='reconstructed')
#     ax1.set_title(f'{title} (loss: {np.around(pred_losses[0], 2)})')
#     ax1.legend()
#     ax1.set_xlim(0, len(data))
    
#     # rdgn = sns.diverging_palette(h_neg=130, h_pos=10, s=99, l=55, sep=3, as_cmap=True)
#     ax2 = ax[1]
#     im = ax2.imshow(np.atleast_3d(se).T, aspect=5, cmap='Wistia')
#     ax2.set_xticks([])
#     ax2.set_yticks([])
#     # fig.colorbar(im, ax=ax2)
#     return ax1, ax2

# %%
# fig, axs = plt.subplots(2, 1, figsize=(8, 6))
# plot_prediction(data, model, title='Prediction', ax=axs)
# plt.tight_layout()
# plt.show()

# %%
fig, axs = plt.subplots(
  nrows=4,
  ncols=3,
  # sharey=True,
  # sharex=True,
  figsize=(22, 8)
)

for i, data in enumerate(test_normal_dataset[20:23]):
    plot_prediction(data, model, title='Normal', ax=axs[0, i])
    
for i, data in enumerate(test_normal_dataset[23:26]):
    plot_prediction(data, model, title='Normal', ax=axs[1, i])
    
for i, data in enumerate(test_normal_dataset[26:29]):
    plot_prediction(data, model, title='Normal', ax=axs[2, i])
    
for i, data in enumerate(test_normal_dataset[29:32]):
    plot_prediction(data, model, title='Normal', ax=axs[3, i])

plt.tight_layout()

# %% [markdown]
# ### Test

# %%
df_test
# Out:
#              MeterID            DATE-Time  KWH  user user_1
# 11025816  6200028570  2021-01-01 00:00:00  0.0   510      0
# 11025817  6200028570  2021-01-01 00:15:00  0.0   510      0
# 11025818  6200028570  2021-01-01 00:30:00  0.0   510      0
# 11025819  6200028570  2021-01-01 00:45:00  0.0   510      0
# 11025820  6200028570  2021-01-01 01:00:00  0.0   510      0
# ...              ...                  ...  ...   ...    ...
# 11045667  6200028570  2021-07-31 22:45:00  0.0   510      0
# 11045668  6200028570  2021-07-31 23:00:00  0.0   510      0
# 11045669  6200028570  2021-07-31 23:15:00  0.0   510      0
# 11045670  6200028570  2021-07-31 23:30:00  0.0   510      0
# 11045671  6200028570  2021-07-31 23:45:00  0.0   510      0
#
# [19856 rows x 5 columns]

# %%
plt.figure(figsize=(12,4))
plt.title('(Energy Consumptions)', size=15)
plt.ylabel('KWH')
plt.grid(True)
plt.autoscale(axis='x',tight=True)
plt.plot(df_test['KWH'])
plt.show()

# %% [markdown]
# ## 5. Evaluate the model using the test set

# %% [markdown]
# # Task
#
# ### VAE autocoder
# * https://www.google.com/search?q=variational+autoencoder+based+anomaly+detection+using+reconstruction+probability+github&rlz=1C5CHFA_enTH999TH999&oq=Variational+Autoencoder+based+Anomaly+Detection+using+Reconstruction+Probability+&aqs=chrome.1.69i57j0i512j69i60.3070j0j7&sourceid=chrome&ie=UTF-8
# * https://github.com/Michedev/VAE_anomaly_detection
# * https://github.com/smile-yan/vae-anomaly-detection
# * https://github.com/tarekmuallim/Anomaly-Detection-using-Variational-Autoencoders/blob/master/anomaly_detection_using_vae.py
#
#
# ### CNN
# * https://github.com/khanmhmdi/Cifar-Image-Reconstruction-using-Autoencoder-Models/blob/main/Image_reconstruction.ipynb
# * https://github.com/ebrahimpichka/conv-autoencoder (test on this now!!)
