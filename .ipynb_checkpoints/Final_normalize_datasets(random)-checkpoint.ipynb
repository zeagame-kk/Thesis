# %%
import time
import copy
import random
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import torch
from torch import nn     # All neural network modules, nn.Linear, nn.Conv2d, BatchNorm, Loss function
import torch.optim as optim     # For all Optimization algorithms, SGD, Adam, etc.
import torch.nn.functional as F     # All functions that don't have any parameters
from torch.utils.data import TensorDataset, DataLoader     # Gives easier dataset management and creates mini batchs
import torchvision.transforms as transforms     # Transformations we can perform on our dataset

import warnings
warnings.simplefilter("ignore")

print("PyTorch version " + torch.__version__)
# Out:
# PyTorch version 1.13.1+cu117

# %%
from helper_train import train_autoencoder_v1
from helper_data import get_dataloaders_mnist
from helper_train import train_vae_v1, train_vae_v2
from helper_utils import set_deterministic, set_all_seeds
from helper_plotting import plot_training_loss
from helper_plotting import plot_accuracy
from helper_plotting import plot_generated_images
from helper_plotting import plot_latent_space_with_labels
from helper_plotting import plot_images_sampled_from_vae

# %%
##########################
### SETTINGS
##########################

# Device
CUDA_DEVICE_NUM = 0
device = torch.device(f'cuda:{CUDA_DEVICE_NUM}' if torch.cuda.is_available() else 'cpu')
print('Device:', device)

# Hyperparameters
RANDOM_SEED = 42
# Out:
# Device: cuda:0

# %%
set_deterministic
set_all_seeds(RANDOM_SEED)

# %% [markdown]
# # 1. Load Datasets

# %%
df = pd.read_csv('datasets/selected_2000user_v2.csv')
df
# Out:
#              MeterID            DATE-Time    KWH  user
# 0         6200093839  2021-01-01 00:00:00  0.602     0
# 1         6200093839  2021-01-01 00:15:00  0.589     0
# 2         6200093839  2021-01-01 00:30:00  0.410     0
# 3         6200093839  2021-01-01 00:45:00  0.495     0
# 4         6200093839  2021-01-01 01:00:00  0.450     0
# ...              ...                  ...    ...   ...
# 40181914  6200051044  2021-07-31 22:45:00  0.473  2000
# 40181915  6200051044  2021-07-31 23:00:00  0.461  2000
# 40181916  6200051044  2021-07-31 23:15:00  0.445  2000
# 40181917  6200051044  2021-07-31 23:30:00  0.460  2000
# 40181918  6200051044  2021-07-31 23:45:00  0.426  2000
#
# [40181919 rows x 4 columns]

# %%
users_100_list = pd.read_csv('datasets/users_100_list.csv')
users_100_list
# Out:
#     user
# 0     18
# 1     53
# 2     60
# 3     66
# 4     67
# ..   ...
# 95  1937
# 96  1944
# 97  1953
# 98  1961
# 99  1974
#
# [100 rows x 1 columns]

# %%
df = df[df['user'].isin(users_100_list['user'])]
print(df['user'].nunique())
df
# Out:
# 100
#              MeterID            DATE-Time    KWH  user
# 407116    6200026555  2021-01-01 00:00:00  0.114    18
# 407117    6200026555  2021-01-01 00:15:00  0.116    18
# 407118    6200026555  2021-01-01 00:30:00  0.086    18
# 407119    6200026555  2021-01-01 00:45:00  0.139    18
# 407120    6200026555  2021-01-01 01:00:00  0.122    18
# ...              ...                  ...    ...   ...
# 39676025  6200100995  2021-07-31 22:45:00  0.544  1974
# 39676026  6200100995  2021-07-31 23:00:00  0.544  1974
# 39676027  6200100995  2021-07-31 23:15:00  0.540  1974
# 39676028  6200100995  2021-07-31 23:30:00  0.542  1974
# 39676029  6200100995  2021-07-31 23:45:00  0.545  1974
#
# [2011407 rows x 4 columns]

# %%
users_100_list = users_100_list['user'].tolist()
users_100_list
# Out:
# [18,
#  53,
#  60,
#  66,
#  67,
#  86,
#  89,
#  168,
#  169,
#  177,
#  189,
#  227,
#  236,
#  238,
#  240,
#  257,
#  299,
#  347,
#  366,
#  380,
#  383,
#  398,
#  428,
#  433,
#  447,
#  453,
#  461,
#  467,
#  471,
#  477,
#  482,
#  503,
#  533,
#  534,
#  543,
#  548,
#  579,
#  594,
#  719,
#  763,
#  771,
#  791,
#  808,
#  848,
#  849,
#  854,
#  860,
#  867,
#  956,
#  964,
#  1100,
#  1111,
#  1122,
#  1196,
#  1255,
#  1271,
#  1278,
#  1313,
#  1346,
#  1383,
#  1395,
#  1413,
#  1417,
#  1422,
#  1439,
#  1471,
#  1481,
#  1493,
#  1511,
#  1515,
#  1530,
#  1543,
#  1559,
#  1580,
#  1609,
#  1611,
#  1612,
#  1640,
#  1656,
#  1673,
#  1681,
#  1719,
#  1723,
#  1726,
#  1737,
#  1801,
#  1802,
#  1805,
#  1845,
#  1866,
#  1880,
#  1892,
#  1902,
#  1919,
#  1925,
#  1937,
#  1944,
#  1953,
#  1961,
#  1974]

# %%
# Updated
def clean_data(df, user_id):
    # Select the data for the specified user
    user_data = df[df['user']==int(user_id)]

    # Drop not useful columns
    user_data['DATE-Time'] = pd.to_datetime(user_data['DATE-Time'], infer_datetime_format=True)
    user_data.drop(columns=["MeterID", "user"], inplace=True)

    # Resample `15min` in order to have completed `"DATE-Time"`
    # I have `'DATE-Time'` 32760 rows (32760/96=341.25 Days)
    # It should be (365day * 96point = 35040 rows)
    # I have to reset index in order to hava 35040 rows
    # Fill the missing value
    user_data = user_data.set_index('DATE-Time').resample("15T").mean()
    
    # Convert the index to a DatetimeIndex object
    user_data.index = pd.to_datetime(user_data.index)

    # Count the number of zero values in each day
    zero_counts = user_data.groupby(user_data.index.floor('D'))['KWH'].apply(lambda x: (x == 0).sum())

    # Get the dates where the number of zero values is less than or equal to 48
    valid_dates = zero_counts[zero_counts <= 48].index

    # Drop the dates where the number of zero values is greater than 48
    user_data = user_data[user_data.index.floor('D').isin(valid_dates)]

    # Drop the days that have NaN values
    # Check which rows have at least one missing value
    missing_days = user_data.isnull().any(axis=1)

    # Get the dates (i.e., indices) of the rows that have missing values
    missing_days_index = missing_days[missing_days].index

    # Get the unique dates that have missing values
    missing_dates = pd.Series(missing_days_index.date).unique().tolist()

    # Drop the entire dates that contain Nan values
    user_data_clean = user_data[~user_data.index.to_series().dt.date.isin(missing_dates)]
    
    if user_data_clean.empty:
        return None

    return user_data_clean

# %%
# def create_windowed_dataset(data, window_size=96):
#     # Calculate the number of windows that fit in the data
#     num_windows = len(data) // window_size
    
#     # Truncate data to fit into windowed data exactly
#     data = data[:num_windows*window_size]
    
#     # Reshape the data into a 3D tensor of (num_windows, window_size, num_features)
#     # Here we're adding an extra dimension to the data to represent the features, which is 1 in our case
#     windowed_data = np.reshape(data, (num_windows, window_size, 1))
    
#     return windowed_data

# %%
# def normalize_and_create_windowed_data(data, window_size=96, val_size=0.2, test_size=0.5, RANDOM_SEED=42):
#     # Split the data into train, validation, and test sets
#     train_data, val_data = train_test_split(data,
#                                             test_size=val_size,
#                                             shuffle=True,
#                                             random_state=RANDOM_SEED)
#     val_data, test_data = train_test_split(val_data,
#                                            test_size=test_size,
#                                            shuffle=True,
#                                            random_state=RANDOM_SEED)

#     # Initialize a MinMaxScaler object
#     scaler = MinMaxScaler()

#     # Fit the scaler to the train_data and transform it
#     train_data_normalized = scaler.fit_transform(train_data)

#     # Use the same scaler to transform the validation and test sets
#     val_data_normalized = scaler.transform(val_data)
#     test_data_normalized = scaler.transform(test_data)

#     # Create windowed datasets
#     train_data_windowed = create_windowed_dataset(train_data_normalized, window_size)
#     val_data_windowed = create_windowed_dataset(val_data_normalized, window_size)
#     test_data_windowed = create_windowed_dataset(test_data_normalized, window_size)

#     return train_data_windowed, val_data_windowed, test_data_windowed

# %%
def create_windowed_dataset(data, window_size=96):
    num_windows = len(data) // window_size
    data = data[:num_windows * window_size]
    windowed_data = np.reshape(data, (num_windows, window_size, 1))
    return windowed_data

def normalize_and_create_windowed_data(data, window_size=96, val_size=0.1, test_size=0.1, RANDOM_SEED=42):
    # Calculate the split indices
    train_split = int(len(data) * (1 - val_size - test_size))
    val_split = int(len(data) * (1 - test_size))
    
    # Split the data into train, validation, and test sets without shuffling
    train_data = data[:train_split]
    val_data = data[train_split:val_split]
    test_data = data[val_split:]

    # Initialize a MinMaxScaler object
    scaler = MinMaxScaler()

    # Fit the scaler to the train_data and transform it
    train_data_normalized = scaler.fit_transform(train_data)

    # Use the same scaler to transform the validation and test sets
    val_data_normalized = scaler.transform(val_data)
    test_data_normalized = scaler.transform(test_data)

    # Create windowed datasets
    train_data_windowed = create_windowed_dataset(train_data_normalized, window_size)
    val_data_windowed = create_windowed_dataset(val_data_normalized, window_size)
    test_data_windowed = create_windowed_dataset(test_data_normalized, window_size)

    return train_data_windowed, val_data_windowed, test_data_windowed

# %%
# Create empty lists to store the normalized data for each user
train_data_list = []
val_data_list = []
test_data_list = []

# Iterate through the user IDs in the users_10_list
for user_id in users_100_list:
    # Clean the data for the current user
    user_clean_data = clean_data(df, user_id)
    print(f"User {user_id} clean data shape: {user_clean_data.shape}")

    # Normalize the cleaned data and split it into train, validation, and test sets
    train_data_windowed, val_data_windowed, test_data_windowed = normalize_and_create_windowed_data(user_clean_data)
    
    # Print the shape of the train_data_windowed for the current user
    print(f"User {user_id} train shape: {train_data_windowed.shape}, validation shape: {val_data_windowed.shape},test shape: {test_data_windowed.shape}")

    # Append the normalized data to the respective lists
    train_data_list.append(train_data_windowed)
    val_data_list.append(val_data_windowed)
    test_data_list.append(test_data_windowed)

# Concatenate the data for all users
train_data_all = np.concatenate(train_data_list, axis=0)
val_data_all = np.concatenate(val_data_list, axis=0)
test_data_all = np.concatenate(test_data_list, axis=0)

print(f"Train data shape: {train_data_all.shape}")
print(f"Validation data shape: {val_data_all.shape}")
print(f"Test data shape: {test_data_all.shape}")
# Out:
# User 18 clean data shape: (20736, 1)
# User 18 train shape: (172, 96, 1), validation shape: (21, 96, 1),test shape: (21, 96, 1)
# User 53 clean data shape: (20160, 1)
# User 53 train shape: (168, 96, 1), validation shape: (21, 96, 1),test shape: (21, 96, 1)
# User 60 clean data shape: (18336, 1)
# User 60 train shape: (152, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 66 clean data shape: (19200, 1)
# User 66 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 67 clean data shape: (21792, 1)
# User 67 train shape: (181, 96, 1), validation shape: (22, 96, 1),test shape: (22, 96, 1)
# User 86 clean data shape: (21120, 1)
# User 86 train shape: (176, 96, 1), validation shape: (22, 96, 1),test shape: (22, 96, 1)
# User 89 clean data shape: (20544, 1)
# User 89 train shape: (171, 96, 1), validation shape: (21, 96, 1),test shape: (21, 96, 1)
# User 168 clean data shape: (17760, 1)
# User 168 train shape: (148, 96, 1), validation shape: (18, 96, 1),test shape: (18, 96, 1)
# User 169 clean data shape: (18048, 1)
# User 169 train shape: (150, 96, 1), validation shape: (18, 96, 1),test shape: (18, 96, 1)
# User 177 clean data shape: (18336, 1)
# User 177 train shape: (152, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 189 clean data shape: (18912, 1)
# User 189 train shape: (157, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 227 clean data shape: (19680, 1)
# User 227 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 236 clean data shape: (19392, 1)
# User 236 train shape: (161, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 238 clean data shape: (8736, 1)
# User 238 train shape: (72, 96, 1), validation shape: (9, 96, 1),test shape: (9, 96, 1)
# User 240 clean data shape: (21696, 1)
# User 240 train shape: (180, 96, 1), validation shape: (22, 96, 1),test shape: (22, 96, 1)
# User 257 clean data shape: (22368, 1)
# User 257 train shape: (186, 96, 1), validation shape: (23, 96, 1),test shape: (23, 96, 1)
# User 299 clean data shape: (21792, 1)
# User 299 train shape: (181, 96, 1), validation shape: (22, 96, 1),test shape: (22, 96, 1)
# User 347 clean data shape: (19968, 1)
# User 347 train shape: (166, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 366 clean data shape: (21984, 1)
# User 366 train shape: (183, 96, 1), validation shape: (22, 96, 1),test shape: (22, 96, 1)
# User 380 clean data shape: (21024, 1)
# User 380 train shape: (175, 96, 1), validation shape: (21, 96, 1),test shape: (21, 96, 1)
# User 383 clean data shape: (21696, 1)
# User 383 train shape: (180, 96, 1), validation shape: (22, 96, 1),test shape: (22, 96, 1)
# User 398 clean data shape: (22464, 1)
# User 398 train shape: (187, 96, 1), validation shape: (23, 96, 1),test shape: (23, 96, 1)
# User 428 clean data shape: (19680, 1)
# User 428 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 433 clean data shape: (19968, 1)
# User 433 train shape: (166, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 447 clean data shape: (19200, 1)
# User 447 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 453 clean data shape: (14208, 1)
# User 453 train shape: (118, 96, 1), validation shape: (14, 96, 1),test shape: (14, 96, 1)
# User 461 clean data shape: (7968, 1)
# User 461 train shape: (66, 96, 1), validation shape: (8, 96, 1),test shape: (8, 96, 1)
# User 467 clean data shape: (19200, 1)
# User 467 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 471 clean data shape: (17664, 1)
# User 471 train shape: (147, 96, 1), validation shape: (18, 96, 1),test shape: (18, 96, 1)
# User 477 clean data shape: (19776, 1)
# User 477 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 482 clean data shape: (17856, 1)
# User 482 train shape: (148, 96, 1), validation shape: (18, 96, 1),test shape: (18, 96, 1)
# User 503 clean data shape: (12480, 1)
# User 503 train shape: (104, 96, 1), validation shape: (13, 96, 1),test shape: (13, 96, 1)
# User 533 clean data shape: (19488, 1)
# User 533 train shape: (162, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 534 clean data shape: (19584, 1)
# User 534 train shape: (163, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 543 clean data shape: (7680, 1)
# User 543 train shape: (64, 96, 1), validation shape: (8, 96, 1),test shape: (8, 96, 1)
# User 548 clean data shape: (19776, 1)
# User 548 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 579 clean data shape: (16896, 1)
# User 579 train shape: (140, 96, 1), validation shape: (17, 96, 1),test shape: (17, 96, 1)
# User 594 clean data shape: (19104, 1)
# User 594 train shape: (159, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 719 clean data shape: (17376, 1)
# User 719 train shape: (144, 96, 1), validation shape: (18, 96, 1),test shape: (18, 96, 1)
# User 763 clean data shape: (17664, 1)
# User 763 train shape: (147, 96, 1), validation shape: (18, 96, 1),test shape: (18, 96, 1)
# User 771 clean data shape: (18432, 1)
# User 771 train shape: (153, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 791 clean data shape: (17952, 1)
# User 791 train shape: (149, 96, 1), validation shape: (18, 96, 1),test shape: (18, 96, 1)
# User 808 clean data shape: (18720, 1)
# User 808 train shape: (156, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 848 clean data shape: (18144, 1)
# User 848 train shape: (151, 96, 1), validation shape: (18, 96, 1),test shape: (18, 96, 1)
# User 849 clean data shape: (13824, 1)
# User 849 train shape: (115, 96, 1), validation shape: (14, 96, 1),test shape: (14, 96, 1)
# User 854 clean data shape: (19680, 1)
# User 854 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 860 clean data shape: (18336, 1)
# User 860 train shape: (152, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 867 clean data shape: (8832, 1)
# User 867 train shape: (73, 96, 1), validation shape: (9, 96, 1),test shape: (9, 96, 1)
# User 956 clean data shape: (12960, 1)
# User 956 train shape: (108, 96, 1), validation shape: (13, 96, 1),test shape: (13, 96, 1)
# User 964 clean data shape: (15936, 1)
# User 964 train shape: (132, 96, 1), validation shape: (16, 96, 1),test shape: (16, 96, 1)
# User 1100 clean data shape: (16128, 1)
# User 1100 train shape: (134, 96, 1), validation shape: (16, 96, 1),test shape: (16, 96, 1)
# User 1111 clean data shape: (19008, 1)
# User 1111 train shape: (158, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 1122 clean data shape: (19584, 1)
# User 1122 train shape: (163, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1196 clean data shape: (16704, 1)
# User 1196 train shape: (139, 96, 1), validation shape: (17, 96, 1),test shape: (17, 96, 1)
# User 1255 clean data shape: (17472, 1)
# User 1255 train shape: (145, 96, 1), validation shape: (18, 96, 1),test shape: (18, 96, 1)
# User 1271 clean data shape: (19296, 1)
# User 1271 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1278 clean data shape: (19680, 1)
# User 1278 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1313 clean data shape: (15168, 1)
# User 1313 train shape: (126, 96, 1), validation shape: (15, 96, 1),test shape: (15, 96, 1)
# User 1346 clean data shape: (20160, 1)
# User 1346 train shape: (168, 96, 1), validation shape: (21, 96, 1),test shape: (21, 96, 1)
# User 1383 clean data shape: (19008, 1)
# User 1383 train shape: (158, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 1395 clean data shape: (19584, 1)
# User 1395 train shape: (163, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1413 clean data shape: (19776, 1)
# User 1413 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1417 clean data shape: (18048, 1)
# User 1417 train shape: (150, 96, 1), validation shape: (18, 96, 1),test shape: (18, 96, 1)
# User 1422 clean data shape: (18432, 1)
# User 1422 train shape: (153, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 1439 clean data shape: (19776, 1)
# User 1439 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1471 clean data shape: (19776, 1)
# User 1471 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1481 clean data shape: (18912, 1)
# User 1481 train shape: (157, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 1493 clean data shape: (19872, 1)
# User 1493 train shape: (165, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1511 clean data shape: (19200, 1)
# User 1511 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1515 clean data shape: (19296, 1)
# User 1515 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1530 clean data shape: (18624, 1)
# User 1530 train shape: (155, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 1543 clean data shape: (19488, 1)
# User 1543 train shape: (162, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1559 clean data shape: (18624, 1)
# User 1559 train shape: (155, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 1580 clean data shape: (19008, 1)
# User 1580 train shape: (158, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 1609 clean data shape: (19200, 1)
# User 1609 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1611 clean data shape: (19296, 1)
# User 1611 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1612 clean data shape: (19488, 1)
# User 1612 train shape: (162, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1640 clean data shape: (18144, 1)
# User 1640 train shape: (151, 96, 1), validation shape: (18, 96, 1),test shape: (18, 96, 1)
# User 1656 clean data shape: (13199, 1)
# User 1656 train shape: (109, 96, 1), validation shape: (13, 96, 1),test shape: (13, 96, 1)
# User 1673 clean data shape: (20160, 1)
# User 1673 train shape: (168, 96, 1), validation shape: (21, 96, 1),test shape: (21, 96, 1)
# User 1681 clean data shape: (19776, 1)
# User 1681 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1719 clean data shape: (19776, 1)
# User 1719 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1723 clean data shape: (19200, 1)
# User 1723 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1726 clean data shape: (19200, 1)
# User 1726 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1737 clean data shape: (19968, 1)
# User 1737 train shape: (166, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1801 clean data shape: (19296, 1)
# User 1801 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1802 clean data shape: (19296, 1)
# User 1802 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1805 clean data shape: (19488, 1)
# User 1805 train shape: (162, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1845 clean data shape: (18720, 1)
# User 1845 train shape: (156, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 1866 clean data shape: (19488, 1)
# User 1866 train shape: (162, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1880 clean data shape: (18912, 1)
# User 1880 train shape: (157, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 1892 clean data shape: (19488, 1)
# User 1892 train shape: (162, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1902 clean data shape: (19776, 1)
# User 1902 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1919 clean data shape: (18816, 1)
# User 1919 train shape: (156, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 1925 clean data shape: (18912, 1)
# User 1925 train shape: (157, 96, 1), validation shape: (19, 96, 1),test shape: (19, 96, 1)
# User 1937 clean data shape: (19776, 1)
# User 1937 train shape: (164, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1944 clean data shape: (19392, 1)
# User 1944 train shape: (161, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1953 clean data shape: (19392, 1)
# User 1953 train shape: (161, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# User 1961 clean data shape: (11040, 1)
# User 1961 train shape: (92, 96, 1), validation shape: (11, 96, 1),test shape: (11, 96, 1)
# User 1974 clean data shape: (19200, 1)
# User 1974 train shape: (160, 96, 1), validation shape: (20, 96, 1),test shape: (20, 96, 1)
# Train data shape: (15318, 96, 1)
# Validation data shape: (1877, 96, 1)
# Test data shape: (1877, 96, 1)

# %%
import matplotlib.pyplot as plt

# Number of windows to plot
num_windows_to_plot = 100

# Create a grid of subplots
fig, axes = plt.subplots(nrows=10, ncols=10, figsize=(12, 12))

# Iterate over the desired number of windows
for i in range(num_windows_to_plot):
    # Get the current axis from the subplot grid
    ax = axes[i // 10, i % 10]

    # Plot the windowed data on the current axis
    ax.plot(train_data_windowed[i])

    # Set the title for the current axis
    ax.set_title(f"Window {i+1}")

# Adjust the layout of the subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Save the data
np.save('datasets/Norm_datasets/train_data_100_users.npy', train_data_all)
np.save('datasets/Norm_datasets/val_data_100_users.npy', val_data_all)
np.save('datasets/Norm_datasets/test_data_100_users.npy', test_data_all)

# Load the data
train_data_all_loaded = np.load('datasets/Norm_datasets/train_data_100_users.npy')
val_data_all_loaded = np.load('datasets/Norm_datasets/val_data_100_users.npy')
test_data_all_loaded = np.load('datasets/Norm_datasets/test_data_100_users.npy')

# Check if the loaded data has the same shape as the original data
print(f"Loaded train data shape: {train_data_all_loaded.shape}")
print(f"Loaded validation data shape: {val_data_all_loaded.shape}")
print(f"Loaded test data shape: {test_data_all_loaded.shape}")
# Out:
# Loaded train data shape: (15318, 96, 1)
# Loaded validation data shape: (1877, 96, 1)
# Loaded test data shape: (1877, 96, 1)
