# %% [markdown]
# ## Imports

# %%
import time
import copy
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import torch
from torch import nn     # All neural network modules, nn.Linear, nn.Conv2d, BatchNorm, Loss function
import torch.optim as optim     # For all Optimization algorithms, SGD, Adam, etc.
import torch.nn.functional as F     # All functions that don't have any parameters
from torch.utils.data import TensorDataset, DataLoader     # Gives easier dataset management and creates mini batchs
import torchvision.transforms as transforms     # Transformations we can perform on our dataset

import warnings
warnings.simplefilter("ignore")

print("PyTorch version " + torch.__version__)
# Out:
# PyTorch version 1.13.1+cu117

# %% [markdown]
# ## Import utility functions

# %%
from helper_train import train_autoencoder_v1
from helper_data import get_dataloaders_mnist
from helper_train import train_vae_v1, train_vae_v2
from helper_utils import set_deterministic, set_all_seeds
from helper_plotting import plot_training_loss
from helper_plotting import plot_accuracy
from helper_plotting import plot_generated_images
from helper_plotting import plot_latent_space_with_labels
from helper_plotting import plot_images_sampled_from_vae

# %%
##########################
### SETTINGS
##########################

# Device
CUDA_DEVICE_NUM = 0
device = torch.device(f'cuda:{CUDA_DEVICE_NUM}' if torch.cuda.is_available() else 'cpu')
print('Device:', device)

# Hyperparameters
RANDOM_SEED = 42
LEARNING_RATE = 0.0001
BATCH_SIZE = 64
NUM_EPOCHS = 100
# Out:
# Device: cuda:0

# %%
set_deterministic
set_all_seeds(RANDOM_SEED)

# %% [markdown]
# ## 1. ETL (Extract, Transform, Load)

# %%
df = pd.read_csv('datasets/selected_2000user_v2.csv')
df
# Out:
#              MeterID            DATE-Time    KWH  user
# 0         6200093839  2021-01-01 00:00:00  0.602     0
# 1         6200093839  2021-01-01 00:15:00  0.589     0
# 2         6200093839  2021-01-01 00:30:00  0.410     0
# 3         6200093839  2021-01-01 00:45:00  0.495     0
# 4         6200093839  2021-01-01 01:00:00  0.450     0
# ...              ...                  ...    ...   ...
# 40181914  6200051044  2021-07-31 22:45:00  0.473  2000
# 40181915  6200051044  2021-07-31 23:00:00  0.461  2000
# 40181916  6200051044  2021-07-31 23:15:00  0.445  2000
# 40181917  6200051044  2021-07-31 23:30:00  0.460  2000
# 40181918  6200051044  2021-07-31 23:45:00  0.426  2000
#
# [40181919 rows x 4 columns]

# %%
noise = pd.read_csv('datasets/noise_users.csv')
noise
# Out:
#      Series     Cluster
# 0       442  Cluster 19
# 1      1856  Cluster 19
# 2      1634  Cluster 19
# 3      1280  Cluster 19
# 4      1310  Cluster 19
# ..      ...         ...
# 158     658  Cluster 44
# 159    1621  Cluster 44
# 160     922  Cluster 44
# 161     716  Cluster 44
# 162    1342  Cluster 44
#
# [163 rows x 2 columns]

# %%
df = df[~df['user'].isin(noise['Series'])]
df['user'].nunique()
# Out:
# 1838

# %%
df
# Out:
#              MeterID            DATE-Time    KWH  user
# 0         6200093839  2021-01-01 00:00:00  0.602     0
# 1         6200093839  2021-01-01 00:15:00  0.589     0
# 2         6200093839  2021-01-01 00:30:00  0.410     0
# 3         6200093839  2021-01-01 00:45:00  0.495     0
# 4         6200093839  2021-01-01 01:00:00  0.450     0
# ...              ...                  ...    ...   ...
# 40181914  6200051044  2021-07-31 22:45:00  0.473  2000
# 40181915  6200051044  2021-07-31 23:00:00  0.461  2000
# 40181916  6200051044  2021-07-31 23:15:00  0.445  2000
# 40181917  6200051044  2021-07-31 23:30:00  0.460  2000
# 40181918  6200051044  2021-07-31 23:45:00  0.426  2000
#
# [36923503 rows x 4 columns]

# %% [markdown]
# ## 2. EDA (Exploratory Data Analysis)

# %%
# Updated
def clean_data(df, user_id):
    # Select the data for the specified user
    user_data = df[df['user']==int(user_id)]

    # Drop not useful columns
    user_data['DATE-Time'] = pd.to_datetime(user_data['DATE-Time'], infer_datetime_format=True)
    user_data.drop(columns=["MeterID", "user"], inplace=True)

    # Resample `15min` in order to have completed `"DATE-Time"`
    # I have `'DATE-Time'` 32760 rows (32760/96=341.25 Days)
    # It should be (365day * 96point = 35040 rows)
    # I have to reset index in order to hava 35040 rows
    # Fill the missing value
    user_data = user_data.set_index('DATE-Time').resample("15T").mean()
    
    # Convert the index to a DatetimeIndex object
    user_data.index = pd.to_datetime(user_data.index)

    # Count the number of zero values in each day
    zero_counts = user_data.groupby(user_data.index.floor('D'))['KWH'].apply(lambda x: (x == 0).sum())

    # Get the dates where the number of zero values is less than or equal to 48
    valid_dates = zero_counts[zero_counts <= 48].index

    # Drop the dates where the number of zero values is greater than 48
    user_data = user_data[user_data.index.floor('D').isin(valid_dates)]

    # Drop the days that have NaN values
    # Check which rows have at least one missing value
    missing_days = user_data.isnull().any(axis=1)

    # Get the dates (i.e., indices) of the rows that have missing values
    missing_days_index = missing_days[missing_days].index

    # Get the unique dates that have missing values
    missing_dates = pd.Series(missing_days_index.date).unique().tolist()

    # Drop the entire dates that contain Nan values
    user_data_clean = user_data[~user_data.index.to_series().dt.date.isin(missing_dates)]
    
    if user_data_clean.empty:
        return None

    return user_data_clean

# %%
import random
random.seed(RANDOM_SEED)
# Get the list of unique user IDs in the DataFrame
unique_users = df['user'].unique().tolist()

def clean_multiple_users(df, num_users):

    # Randomly select `num_users` from the list of unique user IDs
    selected_users = random.sample(unique_users, num_users)

    # Call the clean_data() function for each selected user ID and concatenate the results
    all_users_clean = pd.concat([clean_data(df, user_id) for user_id in selected_users], axis=0)

    return all_users_clean

# %%
all_users_clean = clean_multiple_users(df, 100)
all_users_clean
# Out:
#                        KWH
# DATE-Time
# 2021-01-01 00:00:00  0.019
# 2021-01-01 00:15:00  0.020
# 2021-01-01 00:30:00  0.037
# 2021-01-01 00:45:00  0.019
# 2021-01-01 01:00:00  0.019
# ...                    ...
# 2021-07-31 22:45:00  1.030
# 2021-07-31 23:00:00  0.932
# 2021-07-31 23:15:00  1.021
# 2021-07-31 23:30:00  0.956
# 2021-07-31 23:45:00  1.253
#
# [1676928 rows x 1 columns]

# %%
# user_6 = clean_data(df, 6)
# user_6

# %%
# plt.figure(figsize=(12,4))
# plt.title('(Energy Consumptions)', size=15)
# plt.ylabel('KWH')
# plt.grid(True)
# plt.autoscale(axis='x',tight=True)
# plt.plot(user_6['KWH'])
# plt.show()

# %% [markdown]
# ## 3. Prepare the data

# %%
def create_windowed_dataset(data, window_size):
    # Calculate the number of windows that fit in the data
    num_windows = len(data) // window_size
    
    # Truncate data to fit into windowed data exactly
    data = data[:num_windows*window_size]
    
    # Reshape the data into a 3D tensor of (num_windows, window_size, num_features)
    windowed_data = np.reshape(data, (num_windows, window_size))
    
    return windowed_data

# Example usage
window_size = 96
data = all_users_clean.to_numpy()
windowed_data = create_windowed_dataset(data, window_size)
print(f" Window shape : {windowed_data.shape}")
print(f" Type of Window : {type(windowed_data)}")
# Out:
#  Window shape : (17468, 96)
#  Type of Window : <class 'numpy.ndarray'>

# %% [markdown]
# The shape of the dataset (for selected `User_1`) is `(329, 96)` which means:
# * we have `329` samples `(i.e., 329 non-overlapping windows)`,
# * each window has `96` time steps `(i.e., 96 data points)`,
# * and `1` feature `(i.e., KWH)`.

# %%
# Plot the first 10 windows
fig, axs = plt.subplots(2, 5, figsize=(20, 8))
for i, ax in enumerate(axs.flatten()):
    ax.plot(windowed_data[i])
    ax.set_title(f"Window {i}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Divide the data into train, validation, and test sets

# %% [markdown]
# `train_data_tensor[:-1]` and `train_data_tensor[1:]` are indexing operations on the `train_data_tensor` PyTorch tensor.
#
# `train_data_tensor[:-1]` means all elements of `train_data_tensor` except for the last one.
# * This is because in the context of the autoencoder model, we will be predicting the next time step based on the current time step, so the last element of train_data_tensor cannot be used as a predictor.
#
# `train_data_tensor[1:]` means all elements of `train_data_tensor` except for the first one.
# * This is because in the context of the autoencoder model, we will be training the model to predict the next time step given the current time step, so the first element of train_data_tensor cannot be used as a prediction target.
#
# In summary, `train_dataset` contains tuples of `input` and `target` data, where the input data is `train_data_tensor[:-1]` and the target data is `train_data_tensor[1:]`.

# %% [markdown]
# We'll split the examples into train, validation and test sets:

# %%
# Divide the data into training, validation, and test sets 
train_data, val_data = train_test_split(windowed_data, test_size=0.10, shuffle=True, random_state=RANDOM_SEED)
val_data, test_data = train_test_split(val_data, test_size=0.5, shuffle=True, random_state=RANDOM_SEED)

print(train_data.shape)
print(val_data.shape)
print(test_data.shape)
# Out:
# (15721, 96)
# (873, 96)
# (874, 96)

# %% [markdown]
# We need to convert our examples into tensors, so we can use them to train our Autoencoder. Let's write a helper function for that:

# %%
def create_dataset(df):
    sequences = df.astype(np.float32).tolist()
    dataset = [torch.tensor(s).unsqueeze(1).float() for s in sequences]
    n_seq, seq_len, n_features = torch.stack(dataset).shape
    return dataset, seq_len, n_features

# %% [markdown]
# Each Time Series will be converted to a 2D Tensor in the shape sequence length x number of features (96x1 in our case).
#
# Let's create some datasets:

# %%
train_dataset, seq_len, n_features = create_dataset(train_data)
val_dataset, _, _ = create_dataset(val_data)
test_normal_dataset, _, _ = create_dataset(test_data)

# %% [markdown]
# ### 4. Define the model

# %% [markdown]
# This model takes in a tensor of shape `(batch_size, sequence_length, num_features)` as input and outputs a tensor of the same shape.
#
# We use `Conv1d` layers for the encoder and `ConvTranspose1d` layers for the decoder.
#
# Note that the number of input channels for the first Conv1d layer is 1, because we are using a univariate time series as input.
#
# If you had a multivariate time series, you would set the number of input channels to the number of features in your data.
#
# You can adjust the number of channels and the kernel sizes of the convolutional layers to increase or decrease the complexity of the model.

# %% [markdown]
# The general Autoencoder architecture consists of two components. An Encoder that compresses the input and a Decoder that tries to reconstruct it.
#
# We'll use the LSTM Autoencoder from this GitHub repo with some small tweaks. Our model's job is to reconstruct Time Series data. Let's start with the Encoder:

# %%
class Encoder(nn.Module):

    def __init__(self, seq_len, n_features, embedding_dim=64):
        super(Encoder, self).__init__()

        self.seq_len, self.n_features = seq_len, n_features
        self.embedding_dim, self.hidden_dim = embedding_dim, 2 * embedding_dim

        self.rnn1 = nn.LSTM(
          input_size=n_features,
          hidden_size=self.hidden_dim,
          num_layers=1,
          batch_first=True
        )
    
        self.rnn2 = nn.LSTM(
          input_size=self.hidden_dim,
          hidden_size=embedding_dim,
          num_layers=1,
          batch_first=True
        )

    def forward(self, x):
        x = x.reshape((1, self.seq_len, self.n_features))

        x, (_, _) = self.rnn1(x)
        x, (hidden_n, _) = self.rnn2(x)

        return hidden_n.reshape((self.n_features, self.embedding_dim))

# %% [markdown]
# The Encoder uses two LSTM layers to compress the Time Series data input.
#
# Next, we'll decode the compressed representation using a Decoder:

# %%
class Decoder(nn.Module):

    def __init__(self, seq_len, input_dim=64, n_features=1):
        super(Decoder, self).__init__()

        self.seq_len, self.input_dim = seq_len, input_dim
        self.hidden_dim, self.n_features = 2 * input_dim, n_features

        self.rnn1 = nn.LSTM(
          input_size=input_dim,
          hidden_size=input_dim,
          num_layers=1,
          batch_first=True
        )

        self.rnn2 = nn.LSTM(
          input_size=input_dim,
          hidden_size=self.hidden_dim,
          num_layers=1,
          batch_first=True
        )

        self.output_layer = nn.Linear(self.hidden_dim, n_features)

    def forward(self, x):
        x = x.repeat(self.seq_len, self.n_features)
        x = x.reshape((self.n_features, self.seq_len, self.input_dim))

        x, (hidden_n, cell_n) = self.rnn1(x)
        x, (hidden_n, cell_n) = self.rnn2(x)
        x = x.reshape((self.seq_len, self.hidden_dim))

        return self.output_layer(x)

# %% [markdown]
# Our Decoder contains two LSTM layers and an output layer that gives the final reconstruction.
#
# Time to wrap everything into an easy to use module:

# %%
class AE_LSTM(nn.Module):

    def __init__(self, seq_len, n_features, embedding_dim=64):
        super(AE_LSTM, self).__init__()

        self.encoder = Encoder(seq_len, n_features, embedding_dim).to(device)
        self.decoder = Decoder(seq_len, embedding_dim, n_features).to(device)

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)

        return x

# %% [markdown]
# The input shape for `Conv1d` should be `(batch_size, num_features, sequence_length)`.
#
# In our case, the batch size is determined by the batch_size argument in the `DataLoader`, the number of features is `1`, and the sequence length is the window size which is `96`.
#
# So, the shape of each input should be `(batch_size, 1, 96)`.
#
# ---

# %% [markdown]
# If we use `Conv2d` instead of `Conv1d`, the input shape should be `(batch_size, 1, window_size, 1)` instead of `(batch_size, window_size, 1)`.
#
# This is because `Conv2d` expects a 4D tensor where the second dimension represents the number of channels.
#
# In our case, we only have one channel, so we set this dimension to `1`. The fourth dimension is set to 1 because we only have one feature.
#
# ---

# %% [markdown]
# If you want to use `Conv1d`, then the shape of the input tensor should be `(batch_size, in_channels, sequence_length)`, where `in_channels` is 1 in your case since you have a single feature.
#
# So for your specific case, the shape of the input tensor should be `(batch_size, 1, window_size)`, where `window_size` is 96.
#
# However, if you decide to use `Conv2d`, then the shape of the input tensor should be `(batch_size, in_channels, height, width)`.
#
# Since you only have one feature, the `in_channels` would still be 1.
#
# You can choose the `height` and `width` of the input tensor based on the window size and how you want to shape the data for the convolutional layers.
#
# For example, you could set `height=1` and `width=window_size`, or you could set `height=window_size` and `width=1`

# %% [markdown]
# ### Define loss and optimization functions

# %% [markdown]
# Our Autoencoder passes the input through the Encoder and Decoder. Let's create an instance of it:

# %%
model = AE_LSTM(seq_len, n_features, 128)
model = model.to(device)

# %%
model
# Out:
# AE_LSTM(
#   (encoder): Encoder(
#     (rnn1): LSTM(1, 256, batch_first=True)
#     (rnn2): LSTM(256, 128, batch_first=True)
#   )
#   (decoder): Decoder(
#     (rnn1): LSTM(128, 128, batch_first=True)
#     (rnn2): LSTM(128, 256, batch_first=True)
#     (output_layer): Linear(in_features=256, out_features=1, bias=True)
#   )
# )

# %%
## Not use in current Task
# set_all_seeds(RANDOM_SEED)

# model = VAE()
# model.to(DEVICE)

# optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)  

# model

# %%
def count_parameters(model):
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    for item in params:
        print(f'{item:>6}')
    print(f'______\n{sum(params):>6}')
    
count_parameters(model)
# Out:
#   1024
# 262144
#   1024
#   1024
# 131072
#  65536
#    512
#    512
#  65536
#  65536
#    512
#    512
# 131072
# 262144
#   1024
#   1024
#    256
#      1
# ______
# 990465

# %%
from pynvml import *
gb = pow(1024,3)
nvmlInit()
h = nvmlDeviceGetHandleByIndex(0)
info = nvmlDeviceGetMemoryInfo(h)
print(f'total    : {info.total/gb:.2f} GB')
print(f'free     : {info.free/gb:.2f} GB')
print(f'used     : {info.used/gb:.2f} GB')

h = nvmlDeviceGetHandleByIndex(1)
info = nvmlDeviceGetMemoryInfo(h)
print(f'\ntotal    : {info.total/gb:.2f} GB')
print(f'free     : {info.free/gb:.2f} GB')
print(f'used     : {info.used/gb:.2f} GB')
# Out:
# total    : 47.99 GB
# free     : 39.11 GB
# used     : 8.88 GB
#
# total    : 11.00 GB
# free     : 0.14 GB
# used     : 10.86 GB

# %%
# for seq, y_train in train_data:
#     print(seq)
#     print(y_train)
#     break

# %% [markdown]
# ### Train the model

# %% [markdown]
# Let's write a helper function for our training process:

# %%
# Modified AE train_model function!!!!!!
def train_model(model, train_dataset, val_dataset, n_epochs, patience=30):
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    criterion = nn.L1Loss(reduction='sum').to(device)
    history = dict(train=[], val=[])

    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 10000.0
    num_epochs_without_improvement = 0  # initialize early stopping counter
    
    start_time = time.time()
    for epoch in range(1, n_epochs + 1):
        model = model.train()

        train_losses = []
        for seq_true in train_dataset:
            optimizer.zero_grad()
            
            # FORWARD AND BACK PROP
            seq_true = seq_true.to(device)
            seq_pred = model(seq_true)

            loss = criterion(seq_pred, seq_true)
            loss.backward()
            
            # UPDATE MODEL PARAMETERS
            optimizer.step()
            
            # HISTORY
            train_losses.append(loss.item())

        val_losses = []
        model = model.eval()
        with torch.no_grad():
            for seq_true in val_dataset:

                seq_true = seq_true.to(device)
                seq_pred = model(seq_true)

                loss = criterion(seq_pred, seq_true)
                val_losses.append(loss.item())

        train_loss = np.mean(train_losses)
        val_loss = np.mean(val_losses)

        history['train'].append(train_loss)
        history['val'].append(val_loss)
        
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            num_epochs_without_improvement = 0  # reset early stopping counter
        else:
            num_epochs_without_improvement += 1
            if num_epochs_without_improvement >= patience:
                print(f"No improvement after {patience} epochs, stopping early")
                break
            else:
                print(f'Epoch {epoch}: train loss {train_loss} val loss {val_loss} (no improvement {num_epochs_without_improvement})')
     

        print(f'Epoch {epoch}: train loss {train_loss} val loss {val_loss}')
        
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
    model.load_state_dict(best_model_wts)
    return model.eval(), history

# %% [markdown]
# At each epoch, the training process feeds our model with all training examples and evaluates the performance on the validation set. Note that we're using a batch size of 1 (our model sees only 1 sequence at a time). We also record the training and validation set losses during the process.
#
# Note that we're minimizing the L1Loss, which measures the MAE (mean absolute error). Why? The reconstructions seem to be better than with MSE (mean squared error).
#
# We'll get the version of the model with the smallest validation error. Let's do some training:

# %% [markdown]
# ### Evaluation

# %%
model, history = train_model(
  model, 
  train_dataset, 
  val_dataset, 
  n_epochs=250
)
# Out:
# Time elapsed: 1.20 min
# Epoch 1: train loss 1.5259265597206146 val loss 1.760500234606135
# Time elapsed: 2.41 min
# Epoch 2: train loss 1.5188094084904333 val loss 1.7000118339048083
# Time elapsed: 3.62 min
# Epoch 3: train loss 1.51894184669886 val loss 1.717140749352904 (no improvement 1)
# Epoch 3: train loss 1.51894184669886 val loss 1.717140749352904
# Time elapsed: 4.83 min
# Epoch 4: train loss 1.514198404734388 val loss 1.7126648697750333 (no improvement 2)
# Epoch 4: train loss 1.514198404734388 val loss 1.7126648697750333
# Time elapsed: 6.04 min
# Epoch 5: train loss 1.5114258953205642 val loss 1.73833493937878 (no improvement 3)
# Epoch 5: train loss 1.5114258953205642 val loss 1.73833493937878
# Time elapsed: 7.24 min
# Epoch 6: train loss 1.5109569583701656 val loss 1.7305275236362034 (no improvement 4)
# Epoch 6: train loss 1.5109569583701656 val loss 1.7305275236362034
# Time elapsed: 8.45 min
# Epoch 7: train loss 1.5099943110327267 val loss 1.7236853623624042 (no improvement 5)
# Epoch 7: train loss 1.5099943110327267 val loss 1.7236853623624042
# Time elapsed: 9.66 min
# Epoch 8: train loss 1.5081101091548152 val loss 1.7254431260683556 (no improvement 6)
# Epoch 8: train loss 1.5081101091548152 val loss 1.7254431260683556
# Time elapsed: 10.87 min
# Epoch 9: train loss 1.506332373425102 val loss 1.7182231623965303 (no improvement 7)
# Epoch 9: train loss 1.506332373425102 val loss 1.7182231623965303
# Time elapsed: 12.08 min
# Epoch 10: train loss 1.5020288989657808 val loss 1.693538902329552
# Time elapsed: 13.29 min
# Epoch 11: train loss 1.497090154651321 val loss 1.6935742053951117 (no improvement 1)
# Epoch 11: train loss 1.497090154651321 val loss 1.6935742053951117
# Time elapsed: 14.50 min
# Epoch 12: train loss 1.4966590551775696 val loss 1.8063399308411252 (no improvement 2)
# Epoch 12: train loss 1.4966590551775696 val loss 1.8063399308411252
# Time elapsed: 15.71 min
# Epoch 13: train loss 1.4953987343324124 val loss 1.7018635744935184 (no improvement 3)
# Epoch 13: train loss 1.4953987343324124 val loss 1.7018635744935184
# Time elapsed: 16.92 min
# Epoch 14: train loss 1.4946246835120034 val loss 1.6849399174543318
# Time elapsed: 18.13 min
# Epoch 15: train loss 1.4922390569957107 val loss 1.6760442838166656
# Time elapsed: 19.34 min
# Epoch 16: train loss 1.484829381856612 val loss 1.7086944281030767 (no improvement 1)
# Epoch 16: train loss 1.484829381856612 val loss 1.7086944281030767
# Time elapsed: 20.56 min
# Epoch 17: train loss 1.489143672252839 val loss 1.6810317727409618 (no improvement 2)
# Epoch 17: train loss 1.489143672252839 val loss 1.6810317727409618
# Time elapsed: 21.77 min
# Epoch 18: train loss 1.4814892729707467 val loss 1.6941526354571115 (no improvement 3)
# Epoch 18: train loss 1.4814892729707467 val loss 1.6941526354571115
# Time elapsed: 22.98 min
# Epoch 19: train loss 1.478349893516969 val loss 1.6970977634703581 (no improvement 4)
# Epoch 19: train loss 1.478349893516969 val loss 1.6970977634703581
# Time elapsed: 24.19 min
# Epoch 20: train loss 1.4782875374940092 val loss 1.7397619655690788 (no improvement 5)
# Epoch 20: train loss 1.4782875374940092 val loss 1.7397619655690788
# Time elapsed: 25.41 min
# Epoch 21: train loss 1.4798813668545248 val loss 1.6842864071747623 (no improvement 6)
# Epoch 21: train loss 1.4798813668545248 val loss 1.6842864071747623
# Time elapsed: 26.62 min
# Epoch 22: train loss 1.4722242403248686 val loss 1.6918765583415893 (no improvement 7)
# Epoch 22: train loss 1.4722242403248686 val loss 1.6918765583415893
# Time elapsed: 27.83 min
# Epoch 23: train loss 1.4728075265870182 val loss 1.6789896027158353 (no improvement 8)
# Epoch 23: train loss 1.4728075265870182 val loss 1.6789896027158353
# Time elapsed: 29.04 min
# Epoch 24: train loss 1.4744134737716232 val loss 1.6776296845194536 (no improvement 9)
# Epoch 24: train loss 1.4744134737716232 val loss 1.6776296845194536
# Time elapsed: 30.25 min
# Epoch 25: train loss 1.4646012545955158 val loss 1.682024573410124 (no improvement 10)
# Epoch 25: train loss 1.4646012545955158 val loss 1.682024573410124
# Time elapsed: 31.47 min
# Epoch 26: train loss 1.46364120221767 val loss 1.6637524775947357
# Time elapsed: 32.67 min
# Epoch 27: train loss 1.461916571467732 val loss 1.7054359016071616 (no improvement 1)
# Epoch 27: train loss 1.461916571467732 val loss 1.7054359016071616
# Time elapsed: 33.88 min
# Epoch 28: train loss 1.4644827868351764 val loss 1.676474373868719 (no improvement 2)
# Epoch 28: train loss 1.4644827868351764 val loss 1.676474373868719
# Time elapsed: 52.01 min
# Epoch 43: train loss 1.4351412892601325 val loss 1.653137622275235 (no improvement 2)
# Epoch 43: train loss 1.4351412892601325 val loss 1.653137622275235
# Time elapsed: 53.22 min
# Epoch 44: train loss 1.4344905749864763 val loss 1.6826532436076036 (no improvement 3)
# Epoch 44: train loss 1.4344905749864763 val loss 1.6826532436076036
# Time elapsed: 54.43 min
# Epoch 45: train loss 1.4314502100552944 val loss 1.6496451118574793 (no improvement 4)
# Epoch 45: train loss 1.4314502100552944 val loss 1.6496451118574793
# Time elapsed: 55.64 min
# Epoch 46: train loss 1.4293301719656772 val loss 1.6296387570062043
# Time elapsed: 56.85 min
# Epoch 47: train loss 1.426901092502937 val loss 1.655154797731806 (no improvement 1)
# Epoch 47: train loss 1.426901092502937 val loss 1.655154797731806
# Time elapsed: 58.06 min
# Epoch 48: train loss 1.424177389066586 val loss 1.6325346465731405 (no improvement 2)
# Epoch 48: train loss 1.424177389066586 val loss 1.6325346465731405
# Time elapsed: 59.27 min
# Epoch 49: train loss 1.4204603786202368 val loss 1.6382929860931081 (no improvement 3)
# Epoch 49: train loss 1.4204603786202368 val loss 1.6382929860931081
# Time elapsed: 60.49 min
# Epoch 50: train loss 1.4212403174187136 val loss 1.6290188457172488
# Time elapsed: 61.69 min
# Epoch 51: train loss 1.419925804596204 val loss 1.6415790572745421 (no improvement 1)
# Epoch 51: train loss 1.419925804596204 val loss 1.6415790572745421
# Time elapsed: 62.90 min
# Epoch 52: train loss 1.4180910048661444 val loss 1.7034875201264061 (no improvement 2)
# Epoch 52: train loss 1.4180910048661444 val loss 1.7034875201264061
# Time elapsed: 64.11 min
# Epoch 53: train loss 1.420496202668116 val loss 1.6545218272051452 (no improvement 3)
# Epoch 53: train loss 1.420496202668116 val loss 1.6545218272051452
# Time elapsed: 65.32 min
# Epoch 54: train loss 1.4120798292733616 val loss 1.6304898320869003 (no improvement 4)
# Epoch 54: train loss 1.4120798292733616 val loss 1.6304898320869003
# Time elapsed: 66.53 min
# Epoch 55: train loss 1.4093316403477028 val loss 1.6489316627707542 (no improvement 5)
# Epoch 55: train loss 1.4093316403477028 val loss 1.6489316627707542
# Time elapsed: 67.73 min
# Epoch 56: train loss 1.4120846555965367 val loss 1.6245335340243845
# Time elapsed: 68.95 min
# Epoch 57: train loss 1.409408914748143 val loss 1.6351877962327632 (no improvement 1)
# Epoch 57: train loss 1.409408914748143 val loss 1.6351877962327632
# Time elapsed: 70.16 min
# Epoch 58: train loss 1.4064583879744503 val loss 1.638391780015188 (no improvement 2)
# Epoch 58: train loss 1.4064583879744503 val loss 1.638391780015188
# Time elapsed: 71.37 min
# Epoch 59: train loss 1.4045427075634191 val loss 1.6424929892381852 (no improvement 3)
# Epoch 59: train loss 1.4045427075634191 val loss 1.6424929892381852
# Time elapsed: 72.58 min
# Epoch 60: train loss 1.4043956693307122 val loss 1.6228203077470928
# Time elapsed: 73.79 min
# Epoch 61: train loss 1.4072938446199823 val loss 1.6470120642910298 (no improvement 1)
# Epoch 61: train loss 1.4072938446199823 val loss 1.6470120642910298
# Time elapsed: 75.00 min
# Epoch 62: train loss 1.398637934830368 val loss 1.6380122580479102 (no improvement 2)
# Epoch 62: train loss 1.398637934830368 val loss 1.6380122580479102
# Time elapsed: 76.21 min
# Epoch 63: train loss 1.39966821320799 val loss 1.6459260925667665 (no improvement 3)
# Epoch 63: train loss 1.39966821320799 val loss 1.6459260925667665
# Time elapsed: 77.42 min
# Epoch 64: train loss 1.4011089081220363 val loss 1.641208956545093 (no improvement 4)
# Epoch 64: train loss 1.4011089081220363 val loss 1.641208956545093
# Time elapsed: 78.62 min
# Epoch 65: train loss 1.3936873990008034 val loss 1.644771141839669 (no improvement 5)
# Epoch 65: train loss 1.3936873990008034 val loss 1.644771141839669
# Time elapsed: 79.83 min
# Epoch 66: train loss 1.3949653958960648 val loss 1.6470149122306572 (no improvement 6)
# Epoch 66: train loss 1.3949653958960648 val loss 1.6470149122306572
# Time elapsed: 81.04 min
# Epoch 67: train loss 1.3886328424556278 val loss 1.629114457635467 (no improvement 7)
# Epoch 67: train loss 1.3886328424556278 val loss 1.629114457635467
# Time elapsed: 82.25 min
# Epoch 68: train loss 1.39032484134001 val loss 1.6254211917758534 (no improvement 8)
# Epoch 68: train loss 1.39032484134001 val loss 1.6254211917758534
# Time elapsed: 83.46 min
# Epoch 69: train loss 1.3863572616943607 val loss 1.6045955344693221
# Time elapsed: 84.68 min
# Epoch 70: train loss 1.385511744217674 val loss 1.6913917391877813 (no improvement 1)
# Epoch 70: train loss 1.385511744217674 val loss 1.6913917391877813
# Time elapsed: 85.89 min
# Epoch 71: train loss 1.3819699141327058 val loss 1.6076405438949768 (no improvement 2)
# Epoch 71: train loss 1.3819699141327058 val loss 1.6076405438949768
# Time elapsed: 87.10 min
# Epoch 72: train loss 1.3799272817293846 val loss 1.7185479272989064 (no improvement 3)
# Epoch 72: train loss 1.3799272817293846 val loss 1.7185479272989064
# Time elapsed: 88.32 min
# Epoch 73: train loss 1.380788355729263 val loss 1.684381464169812 (no improvement 4)
# Epoch 73: train loss 1.380788355729263 val loss 1.684381464169812
# Time elapsed: 89.53 min
# Epoch 74: train loss 1.3777575846215266 val loss 1.596740663196691
# Time elapsed: 90.74 min
# Epoch 75: train loss 1.3751089759346362 val loss 1.6096353772792962 (no improvement 1)
# Epoch 75: train loss 1.3751089759346362 val loss 1.6096353772792962
# Time elapsed: 91.95 min
# Epoch 76: train loss 1.3733596110319668 val loss 1.6163870381214842 (no improvement 2)
# Epoch 76: train loss 1.3733596110319668 val loss 1.6163870381214842
# Time elapsed: 93.16 min
# Epoch 77: train loss 1.3736346249336102 val loss 1.6283121662382953 (no improvement 3)
# Epoch 77: train loss 1.3736346249336102 val loss 1.6283121662382953
# Time elapsed: 94.37 min
# Epoch 78: train loss 1.3673455613520085 val loss 1.6134615990270318 (no improvement 4)
# Epoch 78: train loss 1.3673455613520085 val loss 1.6134615990270318
# Time elapsed: 95.58 min
# Epoch 79: train loss 1.3648115544812205 val loss 1.6186464312150306 (no improvement 5)
# Epoch 79: train loss 1.3648115544812205 val loss 1.6186464312150306
# Time elapsed: 96.79 min
# Epoch 80: train loss 1.365689392511372 val loss 1.635076773202501 (no improvement 6)
# Epoch 80: train loss 1.365689392511372 val loss 1.635076773202501
# Time elapsed: 97.99 min
# Epoch 81: train loss 1.3619172650922362 val loss 1.6147764937062443 (no improvement 7)
# Epoch 81: train loss 1.3619172650922362 val loss 1.6147764937062443
# Time elapsed: 99.20 min
# Epoch 82: train loss 1.3634092575138772 val loss 1.611342142554766 (no improvement 8)
# Epoch 82: train loss 1.3634092575138772 val loss 1.611342142554766
# Time elapsed: 100.41 min
# Epoch 83: train loss 1.3627230759827844 val loss 1.6020385886436885 (no improvement 9)
# Epoch 83: train loss 1.3627230759827844 val loss 1.6020385886436885
# Time elapsed: 101.62 min
# Epoch 84: train loss 1.3572505750032196 val loss 1.5985957429086084 (no improvement 10)
# Epoch 84: train loss 1.3572505750032196 val loss 1.5985957429086084
# Time elapsed: 102.83 min
# Epoch 85: train loss 1.356058738444461 val loss 1.592002406720614
# Time elapsed: 104.05 min
# Epoch 86: train loss 1.3537683320417693 val loss 1.5929254657607035 (no improvement 1)
# Epoch 86: train loss 1.3537683320417693 val loss 1.5929254657607035
# Time elapsed: 105.26 min
# Epoch 87: train loss 1.3561657648112975 val loss 1.5922710565382878 (no improvement 2)
# Epoch 87: train loss 1.3561657648112975 val loss 1.5922710565382878
# Time elapsed: 106.47 min
# Epoch 88: train loss 1.3547233331939752 val loss 1.5942215249113065 (no improvement 3)
# Epoch 88: train loss 1.3547233331939752 val loss 1.5942215249113065
# Time elapsed: 107.69 min
# Epoch 89: train loss 1.356352249500095 val loss 1.5944918521422837 (no improvement 4)
# Epoch 89: train loss 1.356352249500095 val loss 1.5944918521422837
# Time elapsed: 108.90 min
# Epoch 90: train loss 1.3478772468724163 val loss 1.584930499305123
# Time elapsed: 110.11 min
# Epoch 91: train loss 1.3498097024912499 val loss 1.6010578288339326 (no improvement 1)
# Epoch 91: train loss 1.3498097024912499 val loss 1.6010578288339326
# Time elapsed: 111.32 min
# Epoch 92: train loss 1.3453813742100529 val loss 1.5882555439871953 (no improvement 2)
# Epoch 92: train loss 1.3453813742100529 val loss 1.5882555439871953
# Time elapsed: 112.53 min
# Epoch 93: train loss 1.3498899646624225 val loss 1.5993928718300618 (no improvement 3)
# Epoch 93: train loss 1.3498899646624225 val loss 1.5993928718300618
# Time elapsed: 113.74 min
# Epoch 94: train loss 1.340059951014348 val loss 1.5831628671344817
# Time elapsed: 114.95 min
# Epoch 95: train loss 1.3398050726003645 val loss 1.5937933019124493 (no improvement 1)
# Epoch 95: train loss 1.3398050726003645 val loss 1.5937933019124493
# Time elapsed: 116.16 min
# Epoch 96: train loss 1.3386288217040985 val loss 1.5922595598529021 (no improvement 2)
# Epoch 96: train loss 1.3386288217040985 val loss 1.5922595598529021
# Time elapsed: 117.38 min
# Epoch 97: train loss 1.3389032784922628 val loss 1.5971633016056075 (no improvement 3)
# Epoch 97: train loss 1.3389032784922628 val loss 1.5971633016056075
# Time elapsed: 118.59 min
# Epoch 98: train loss 1.335582842848824 val loss 1.587364864218788 (no improvement 4)
# Epoch 98: train loss 1.335582842848824 val loss 1.587364864218788
# Time elapsed: 119.80 min
# Epoch 99: train loss 1.3332896763455886 val loss 1.5850466660865052 (no improvement 5)
# Epoch 99: train loss 1.3332896763455886 val loss 1.5850466660865052
# Time elapsed: 121.02 min
# Epoch 100: train loss 1.3324127228928577 val loss 1.5824256121412448
# Time elapsed: 122.23 min
# Epoch 101: train loss 1.333056843599839 val loss 1.6057939454955812 (no improvement 1)
# Epoch 101: train loss 1.333056843599839 val loss 1.6057939454955812
# Time elapsed: 123.44 min
# Epoch 102: train loss 1.3293171398596153 val loss 1.591220885741376 (no improvement 2)
# Epoch 102: train loss 1.3293171398596153 val loss 1.591220885741376
# Time elapsed: 124.65 min
# Epoch 103: train loss 1.3375081447986927 val loss 1.561975182583481
# Time elapsed: 125.86 min
# Epoch 104: train loss 1.3238533850370413 val loss 1.5898494086988944 (no improvement 1)
# Epoch 104: train loss 1.3238533850370413 val loss 1.5898494086988944
# Time elapsed: 127.07 min
# Epoch 105: train loss 1.3250102140071014 val loss 1.5878177212608844 (no improvement 2)
# Epoch 105: train loss 1.3250102140071014 val loss 1.5878177212608844
# Time elapsed: 128.29 min
# Epoch 106: train loss 1.3246771063039275 val loss 1.5587886625907266
# Time elapsed: 129.50 min
# Epoch 107: train loss 1.3296618493537238 val loss 1.5592665582050367 (no improvement 1)
# Epoch 107: train loss 1.3296618493537238 val loss 1.5592665582050367
# Time elapsed: 130.70 min
# Epoch 108: train loss 1.3200799828989669 val loss 1.5775775413657245 (no improvement 2)
# Epoch 108: train loss 1.3200799828989669 val loss 1.5775775413657245
# Time elapsed: 131.91 min
# Epoch 109: train loss 1.3156546123982684 val loss 1.5837104451743393 (no improvement 3)
# Epoch 109: train loss 1.3156546123982684 val loss 1.5837104451743393
# Time elapsed: 133.12 min
# Epoch 110: train loss 1.3145673608552044 val loss 1.5714854447369517 (no improvement 4)
# Epoch 110: train loss 1.3145673608552044 val loss 1.5714854447369517
# Time elapsed: 134.33 min
# Epoch 111: train loss 1.312220521048247 val loss 1.5859073643046693 (no improvement 5)
# Epoch 111: train loss 1.312220521048247 val loss 1.5859073643046693
# Time elapsed: 135.54 min
# Epoch 112: train loss 1.3082738106992247 val loss 1.573466288226679 (no improvement 6)
# Epoch 112: train loss 1.3082738106992247 val loss 1.573466288226679
# Time elapsed: 136.75 min
# Epoch 113: train loss 1.3086919907669337 val loss 1.5412402120626874
# Time elapsed: 137.96 min
# Epoch 114: train loss 1.305379704801344 val loss 1.566716993366286 (no improvement 1)
# Epoch 114: train loss 1.305379704801344 val loss 1.566716993366286
# Time elapsed: 139.18 min
# Epoch 115: train loss 1.3068543461463442 val loss 1.5592305194394491 (no improvement 2)
# Epoch 115: train loss 1.3068543461463442 val loss 1.5592305194394491
# Time elapsed: 140.39 min
# Epoch 116: train loss 1.3069459108812203 val loss 1.560946701587373 (no improvement 3)
# Epoch 116: train loss 1.3069459108812203 val loss 1.560946701587373
# Time elapsed: 141.60 min
# Epoch 117: train loss 1.300666800003754 val loss 1.5454355418502874 (no improvement 4)
# Epoch 117: train loss 1.300666800003754 val loss 1.5454355418502874
# Time elapsed: 142.82 min
# Epoch 118: train loss 1.2986194976728636 val loss 1.5926067364558936 (no improvement 5)
# Epoch 118: train loss 1.2986194976728636 val loss 1.5926067364558936
# Time elapsed: 144.03 min
# Epoch 119: train loss 1.2995815622022486 val loss 1.5547471922680411 (no improvement 6)
# Epoch 119: train loss 1.2995815622022486 val loss 1.5547471922680411
# Time elapsed: 145.25 min
# Epoch 120: train loss 1.3036340018706494 val loss 1.6546272708301486 (no improvement 7)
# Epoch 120: train loss 1.3036340018706494 val loss 1.6546272708301486
# Time elapsed: 146.46 min
# Epoch 121: train loss 1.2922082858898396 val loss 1.566957626060795 (no improvement 8)
# Epoch 121: train loss 1.2922082858898396 val loss 1.566957626060795
# Time elapsed: 147.67 min
# Epoch 122: train loss 1.2928276571908015 val loss 1.5536789769031543 (no improvement 9)
# Epoch 122: train loss 1.2928276571908015 val loss 1.5536789769031543
# Time elapsed: 148.89 min
# Epoch 123: train loss 1.2878137597269543 val loss 1.5587443583916962 (no improvement 10)
# Epoch 123: train loss 1.2878137597269543 val loss 1.5587443583916962
# Time elapsed: 150.10 min
# Epoch 124: train loss 1.2899875109795491 val loss 1.5375989244787827
# Time elapsed: 151.31 min
# Epoch 125: train loss 1.2867992390626075 val loss 1.5599999859297535 (no improvement 1)
# Epoch 125: train loss 1.2867992390626075 val loss 1.5599999859297535
# Time elapsed: 152.52 min
# Epoch 126: train loss 1.2894726045700793 val loss 1.5524349724031123 (no improvement 2)
# Epoch 126: train loss 1.2894726045700793 val loss 1.5524349724031123
# Time elapsed: 153.73 min
# Epoch 127: train loss 1.2853577593492533 val loss 1.542821980987218 (no improvement 3)
# Epoch 127: train loss 1.2853577593492533 val loss 1.542821980987218
# Time elapsed: 154.94 min
# Epoch 128: train loss 1.2837805178109551 val loss 1.559224389523336 (no improvement 4)
# Epoch 128: train loss 1.2837805178109551 val loss 1.559224389523336
# Time elapsed: 156.15 min
# Epoch 129: train loss 1.2807714850476801 val loss 1.5413064972624473 (no improvement 5)
# Epoch 129: train loss 1.2807714850476801 val loss 1.5413064972624473
# Time elapsed: 157.36 min
# Epoch 130: train loss 1.2793843190851413 val loss 1.5348069240154543
# Time elapsed: 158.57 min
# Epoch 131: train loss 1.2827997108276041 val loss 1.5635888274643839 (no improvement 1)
# Epoch 131: train loss 1.2827997108276041 val loss 1.5635888274643839
# Time elapsed: 159.78 min
# Epoch 132: train loss 1.2801411568800496 val loss 1.5155799801953196
# Time elapsed: 160.99 min
# Epoch 133: train loss 1.27807574753408 val loss 1.543463935147446 (no improvement 1)
# Epoch 133: train loss 1.27807574753408 val loss 1.543463935147446
# Time elapsed: 162.20 min
# Epoch 134: train loss 1.2737963864710482 val loss 1.5248919287557796 (no improvement 2)
# Epoch 134: train loss 1.2737963864710482 val loss 1.5248919287557796
# Time elapsed: 163.41 min
# Epoch 135: train loss 1.274622947392774 val loss 1.5410290197997363 (no improvement 3)
# Epoch 135: train loss 1.274622947392774 val loss 1.5410290197997363
# Time elapsed: 164.62 min
# Epoch 136: train loss 1.2764299808539368 val loss 1.5392886365956935 (no improvement 4)
# Epoch 136: train loss 1.2764299808539368 val loss 1.5392886365956935
# Time elapsed: 165.83 min
# Epoch 137: train loss 1.2709787333678346 val loss 1.5543725880296029 (no improvement 5)
# Epoch 137: train loss 1.2709787333678346 val loss 1.5543725880296029
# Time elapsed: 167.04 min
# Epoch 138: train loss 1.2715809986902387 val loss 1.5543049076894235 (no improvement 6)
# Epoch 138: train loss 1.2715809986902387 val loss 1.5543049076894235
# Time elapsed: 168.25 min
# Epoch 139: train loss 1.2645876766413224 val loss 1.5274056231886797 (no improvement 7)
# Epoch 139: train loss 1.2645876766413224 val loss 1.5274056231886797
# Time elapsed: 169.46 min
# Epoch 140: train loss 1.2666799418827739 val loss 1.5254665050668406 (no improvement 8)
# Epoch 140: train loss 1.2666799418827739 val loss 1.5254665050668406
# Time elapsed: 170.67 min
# Epoch 141: train loss 1.2683607753152728 val loss 1.5528955160675384 (no improvement 9)
# Epoch 141: train loss 1.2683607753152728 val loss 1.5528955160675384
# Time elapsed: 171.87 min
# Epoch 142: train loss 1.2589730715996288 val loss 1.5216449233665976 (no improvement 10)
# Epoch 142: train loss 1.2589730715996288 val loss 1.5216449233665976
# Time elapsed: 173.08 min
# Epoch 143: train loss 1.2602599364440636 val loss 1.5212308566202277 (no improvement 11)
# Epoch 143: train loss 1.2602599364440636 val loss 1.5212308566202277
# Time elapsed: 174.29 min
# Epoch 144: train loss 1.2633860289688428 val loss 1.5322133173306236 (no improvement 12)
# Epoch 144: train loss 1.2633860289688428 val loss 1.5322133173306236
# Time elapsed: 175.50 min
# Epoch 145: train loss 1.255796234866583 val loss 1.5207514482948241 (no improvement 13)
# Epoch 145: train loss 1.255796234866583 val loss 1.5207514482948241
# Time elapsed: 176.71 min
# Epoch 146: train loss 1.2580558409020195 val loss 1.5179776718108173 (no improvement 14)
# Epoch 146: train loss 1.2580558409020195 val loss 1.5179776718108173
# Time elapsed: 177.92 min
# Epoch 147: train loss 1.2563877909265189 val loss 1.5332185865549492 (no improvement 15)
# Epoch 147: train loss 1.2563877909265189 val loss 1.5332185865549492
# Time elapsed: 179.13 min
# Epoch 148: train loss 1.2593634059877445 val loss 1.5265640525909019 (no improvement 16)
# Epoch 148: train loss 1.2593634059877445 val loss 1.5265640525909019
# Time elapsed: 180.34 min
# Epoch 149: train loss 1.2536307409970628 val loss 1.522048783397893 (no improvement 17)
# Epoch 149: train loss 1.2536307409970628 val loss 1.522048783397893
# Time elapsed: 181.55 min
# Epoch 150: train loss 1.2511534472967378 val loss 1.533775982637927 (no improvement 18)
# Epoch 150: train loss 1.2511534472967378 val loss 1.533775982637927
# Time elapsed: 182.76 min
# Epoch 151: train loss 1.251086477432195 val loss 1.5293907805261675 (no improvement 19)
# Epoch 151: train loss 1.251086477432195 val loss 1.5293907805261675
# Time elapsed: 183.97 min
# Epoch 152: train loss 1.2536966479972558 val loss 1.5099455518616025
# Time elapsed: 185.18 min
# Epoch 153: train loss 1.251207799367736 val loss 1.5263386732148687 (no improvement 1)
# Epoch 153: train loss 1.251207799367736 val loss 1.5263386732148687
# Time elapsed: 186.40 min
# Epoch 154: train loss 1.2505598692444397 val loss 1.5103464920803444 (no improvement 2)
# Epoch 154: train loss 1.2505598692444397 val loss 1.5103464920803444
# Time elapsed: 187.61 min
# Epoch 155: train loss 1.2446268192824705 val loss 1.518364138815889 (no improvement 3)
# Epoch 155: train loss 1.2446268192824705 val loss 1.518364138815889
# Time elapsed: 188.82 min
# Epoch 156: train loss 1.2450733986956823 val loss 1.5248204503989302 (no improvement 4)
# Epoch 156: train loss 1.2450733986956823 val loss 1.5248204503989302
# Time elapsed: 190.04 min
# Epoch 157: train loss 1.2521048721242864 val loss 1.515097412486632 (no improvement 5)
# Epoch 157: train loss 1.2521048721242864 val loss 1.515097412486632
# Time elapsed: 191.25 min
# Epoch 158: train loss 1.2423420442042783 val loss 1.5090014926176027
# Time elapsed: 192.46 min
# Epoch 159: train loss 1.2380807947425012 val loss 1.535635041309796 (no improvement 1)
# Epoch 159: train loss 1.2380807947425012 val loss 1.535635041309796
# Time elapsed: 193.67 min
# Epoch 160: train loss 1.2369966999402002 val loss 1.510514629793536 (no improvement 2)
# Epoch 160: train loss 1.2369966999402002 val loss 1.510514629793536
# Time elapsed: 194.88 min
# Epoch 161: train loss 1.235601449226639 val loss 1.5051354271192252
# Time elapsed: 196.10 min
# Epoch 162: train loss 1.234605433911163 val loss 1.5083660835918693 (no improvement 1)
# Epoch 162: train loss 1.234605433911163 val loss 1.5083660835918693
# Time elapsed: 197.31 min
# Epoch 163: train loss 1.2347321436685896 val loss 1.5025581558323535
# Time elapsed: 198.52 min
# Epoch 164: train loss 1.231302391246002 val loss 1.5130774129015678 (no improvement 1)
# Epoch 164: train loss 1.231302391246002 val loss 1.5130774129015678
# Time elapsed: 199.73 min
# Epoch 165: train loss 1.2278045977430085 val loss 1.5084811779121012 (no improvement 2)
# Epoch 165: train loss 1.2278045977430085 val loss 1.5084811779121012
# Time elapsed: 200.94 min
# Epoch 166: train loss 1.229747745960858 val loss 1.4987685115152345
# Time elapsed: 202.15 min
# Epoch 167: train loss 1.2326687726786776 val loss 1.527816200289632 (no improvement 1)
# Epoch 167: train loss 1.2326687726786776 val loss 1.527816200289632
# Time elapsed: 203.36 min
# Epoch 168: train loss 1.2246458615697047 val loss 1.531995565539817 (no improvement 2)
# Epoch 168: train loss 1.2246458615697047 val loss 1.531995565539817
# Time elapsed: 204.58 min
# Epoch 169: train loss 1.2236306774162504 val loss 1.519584324185279 (no improvement 3)
# Epoch 169: train loss 1.2236306774162504 val loss 1.519584324185279
# Time elapsed: 205.79 min
# Epoch 170: train loss 1.225564271282002 val loss 1.5366709987715075 (no improvement 4)
# Epoch 170: train loss 1.225564271282002 val loss 1.5366709987715075
# Time elapsed: 207.01 min
# Epoch 171: train loss 1.226801662673434 val loss 1.5592736932112998 (no improvement 5)
# Epoch 171: train loss 1.226801662673434 val loss 1.5592736932112998
# Time elapsed: 208.22 min
# Epoch 172: train loss 1.2248960005388514 val loss 1.4926123406059553
# Time elapsed: 209.43 min
# Epoch 173: train loss 1.218024721976127 val loss 1.5059267446902267 (no improvement 1)
# Epoch 173: train loss 1.218024721976127 val loss 1.5059267446902267
# Time elapsed: 210.64 min
# Epoch 174: train loss 1.2184037170291449 val loss 1.4905671860472238
# Time elapsed: 211.85 min
# Epoch 175: train loss 1.2155641081847977 val loss 1.4872236304232618
# Time elapsed: 213.06 min
# Epoch 176: train loss 1.2178944668608 val loss 1.4977738457728702 (no improvement 1)
# Epoch 176: train loss 1.2178944668608 val loss 1.4977738457728702
# Time elapsed: 214.27 min
# Epoch 177: train loss 1.2125012004566356 val loss 1.4966072145623304 (no improvement 2)
# Epoch 177: train loss 1.2125012004566356 val loss 1.4966072145623304
# Time elapsed: 215.48 min
# Epoch 178: train loss 1.2124914867210692 val loss 1.5051129248253532 (no improvement 3)
# Epoch 178: train loss 1.2124914867210692 val loss 1.5051129248253532
# Time elapsed: 216.69 min
# Epoch 179: train loss 1.2195383774255377 val loss 1.4887633339543522 (no improvement 4)
# Epoch 179: train loss 1.2195383774255377 val loss 1.4887633339543522
# Time elapsed: 217.90 min
# Epoch 180: train loss 1.2082842588230374 val loss 1.497634812395802 (no improvement 5)
# Epoch 180: train loss 1.2082842588230374 val loss 1.497634812395802
# Time elapsed: 219.11 min
# Epoch 181: train loss 1.2083114759375573 val loss 1.494012562082259 (no improvement 6)
# Epoch 181: train loss 1.2083114759375573 val loss 1.494012562082259
# Time elapsed: 220.32 min
# Epoch 182: train loss 1.209247607843702 val loss 1.4854421246741372
# Time elapsed: 221.54 min
# Epoch 183: train loss 1.2093007894349337 val loss 1.4883573970673147 (no improvement 1)
# Epoch 183: train loss 1.2093007894349337 val loss 1.4883573970673147
# Time elapsed: 222.75 min
# Epoch 184: train loss 1.2068374596325737 val loss 1.5079216809446185 (no improvement 2)
# Epoch 184: train loss 1.2068374596325737 val loss 1.5079216809446185
# Time elapsed: 223.96 min
# Epoch 185: train loss 1.201763888080379 val loss 1.4810640712792453
# Time elapsed: 225.17 min
# Epoch 186: train loss 1.202894252327026 val loss 1.5131098341371731 (no improvement 1)
# Epoch 186: train loss 1.202894252327026 val loss 1.5131098341371731
# Time elapsed: 226.38 min
# Epoch 187: train loss 1.202426033544162 val loss 1.4962934770995808 (no improvement 2)
# Epoch 187: train loss 1.202426033544162 val loss 1.4962934770995808
# Time elapsed: 227.59 min
# Epoch 188: train loss 1.2026771567911185 val loss 1.500815335272855 (no improvement 3)
# Epoch 188: train loss 1.2026771567911185 val loss 1.500815335272855
# Time elapsed: 228.80 min
# Epoch 189: train loss 1.1990030357396984 val loss 1.4936769021011436 (no improvement 4)
# Epoch 189: train loss 1.1990030357396984 val loss 1.4936769021011436
# Time elapsed: 230.01 min
# Epoch 190: train loss 1.2006586926885763 val loss 1.4940158408583235 (no improvement 5)
# Epoch 190: train loss 1.2006586926885763 val loss 1.4940158408583235
# Time elapsed: 231.22 min
# Epoch 191: train loss 1.2017189542354234 val loss 1.4767165823635844
# Time elapsed: 232.44 min
# Epoch 192: train loss 1.1953338314610562 val loss 1.4731460822338638
# Time elapsed: 233.65 min
# Epoch 193: train loss 1.1957122928748285 val loss 1.486586413219281 (no improvement 1)
# Epoch 193: train loss 1.1957122928748285 val loss 1.486586413219281
# Time elapsed: 234.86 min
# Epoch 194: train loss 1.1962252722848243 val loss 1.493784926473275 (no improvement 2)
# Epoch 194: train loss 1.1962252722848243 val loss 1.493784926473275
# Time elapsed: 236.07 min
# Epoch 195: train loss 1.1913197800269693 val loss 1.4885888299974106 (no improvement 3)
# Epoch 195: train loss 1.1913197800269693 val loss 1.4885888299974106
# Time elapsed: 237.28 min
# Epoch 196: train loss 1.1892647143124218 val loss 1.4819579102175753 (no improvement 4)
# Epoch 196: train loss 1.1892647143124218 val loss 1.4819579102175753
# Time elapsed: 238.49 min
# Epoch 197: train loss 1.1944662691943195 val loss 1.5054279376815616 (no improvement 5)
# Epoch 197: train loss 1.1944662691943195 val loss 1.5054279376815616
# Time elapsed: 239.70 min
# Epoch 198: train loss 1.1893620948093298 val loss 1.4895907592578852 (no improvement 6)
# Epoch 198: train loss 1.1893620948093298 val loss 1.4895907592578852
# Time elapsed: 240.91 min
# Epoch 199: train loss 1.1969962147328188 val loss 1.489490998407478 (no improvement 7)
# Epoch 199: train loss 1.1969962147328188 val loss 1.489490998407478
# Time elapsed: 242.12 min
# Epoch 200: train loss 1.1868267542322464 val loss 1.4726285800073222
# Time elapsed: 243.33 min
# Epoch 201: train loss 1.1831393571241493 val loss 1.4871629482478688 (no improvement 1)
# Epoch 201: train loss 1.1831393571241493 val loss 1.4871629482478688
# Time elapsed: 244.54 min
# Epoch 202: train loss 1.185011008805438 val loss 1.4777157042529712 (no improvement 2)
# Epoch 202: train loss 1.185011008805438 val loss 1.4777157042529712
# Time elapsed: 245.76 min
# Epoch 203: train loss 1.184681842389733 val loss 1.4895829432318575 (no improvement 3)
# Epoch 203: train loss 1.184681842389733 val loss 1.4895829432318575
# Time elapsed: 246.97 min
# Epoch 204: train loss 1.181729918470096 val loss 1.5050191436163476 (no improvement 4)
# Epoch 204: train loss 1.181729918470096 val loss 1.5050191436163476
# Time elapsed: 248.19 min
# Epoch 205: train loss 1.1820096326549387 val loss 1.5512122423702772 (no improvement 5)
# Epoch 205: train loss 1.1820096326549387 val loss 1.5512122423702772
# Time elapsed: 249.40 min
# Epoch 206: train loss 1.1810353840680252 val loss 1.475658951713389 (no improvement 6)
# Epoch 206: train loss 1.1810353840680252 val loss 1.475658951713389
# Time elapsed: 250.62 min
# Epoch 207: train loss 1.179348317904957 val loss 1.4727005304817755 (no improvement 7)
# Epoch 207: train loss 1.179348317904957 val loss 1.4727005304817755
# Time elapsed: 251.83 min
# Epoch 208: train loss 1.1795075249246068 val loss 1.4768273477087315 (no improvement 8)
# Epoch 208: train loss 1.1795075249246068 val loss 1.4768273477087315
# Time elapsed: 253.04 min
# Epoch 209: train loss 1.175423650955488 val loss 1.4876753838406396 (no improvement 9)
# Epoch 209: train loss 1.175423650955488 val loss 1.4876753838406396
# Time elapsed: 254.26 min
# Epoch 210: train loss 1.1787502204293296 val loss 1.4666690452436129
# Time elapsed: 255.47 min
# Epoch 211: train loss 1.174195125574401 val loss 1.47075555584514 (no improvement 1)
# Epoch 211: train loss 1.174195125574401 val loss 1.47075555584514
# Time elapsed: 256.68 min
# Epoch 212: train loss 1.1730764199793053 val loss 1.4739638778411988 (no improvement 2)
# Epoch 212: train loss 1.1730764199793053 val loss 1.4739638778411988
# Time elapsed: 257.89 min
# Epoch 213: train loss 1.1736831961939083 val loss 1.4598109441951241
# Time elapsed: 259.10 min
# Epoch 214: train loss 1.1727441231325666 val loss 1.4702414619519812 (no improvement 1)
# Epoch 214: train loss 1.1727441231325666 val loss 1.4702414619519812
# Time elapsed: 260.31 min
# Epoch 215: train loss 1.1700808109495087 val loss 1.483994724760248 (no improvement 2)
# Epoch 215: train loss 1.1700808109495087 val loss 1.483994724760248
# Time elapsed: 261.53 min
# Epoch 216: train loss 1.1701173334640822 val loss 1.5025649360057824 (no improvement 3)
# Epoch 216: train loss 1.1701173334640822 val loss 1.5025649360057824
# Time elapsed: 262.74 min
# Epoch 217: train loss 1.1686244754296178 val loss 1.4681253570717634 (no improvement 4)
# Epoch 217: train loss 1.1686244754296178 val loss 1.4681253570717634
# Time elapsed: 263.95 min
# Epoch 218: train loss 1.1682679305105093 val loss 1.4761208141348479 (no improvement 5)
# Epoch 218: train loss 1.1682679305105093 val loss 1.4761208141348479
# Time elapsed: 265.17 min
# Epoch 219: train loss 1.1674288821567027 val loss 1.469113301916767 (no improvement 6)
# Epoch 219: train loss 1.1674288821567027 val loss 1.469113301916767
# Time elapsed: 266.38 min
# Epoch 220: train loss 1.1639484556044803 val loss 1.4922261364152067 (no improvement 7)
# Epoch 220: train loss 1.1639484556044803 val loss 1.4922261364152067
# Time elapsed: 267.60 min
# Epoch 221: train loss 1.162892917533081 val loss 1.4791188495231522 (no improvement 8)
# Epoch 221: train loss 1.162892917533081 val loss 1.4791188495231522
# Time elapsed: 269.15 min
# Epoch 222: train loss 1.1623073801257047 val loss 1.4916895553469658 (no improvement 9)
# Epoch 222: train loss 1.1623073801257047 val loss 1.4916895553469658
# Time elapsed: 271.11 min
# Epoch 223: train loss 1.159955685600808 val loss 1.4786094120892463 (no improvement 10)
# Epoch 223: train loss 1.159955685600808 val loss 1.4786094120892463
# Time elapsed: 272.39 min
# Epoch 224: train loss 1.16007988303914 val loss 1.48106136336018 (no improvement 11)
# Epoch 224: train loss 1.16007988303914 val loss 1.48106136336018
# Time elapsed: 273.60 min
# Epoch 225: train loss 1.1599538448569346 val loss 1.4568879716738392
# Time elapsed: 274.81 min
# Epoch 226: train loss 1.1567986253650182 val loss 1.4554696610924986
# Time elapsed: 276.03 min
# Epoch 227: train loss 1.1554673871703274 val loss 1.4528824051784486
# Time elapsed: 277.24 min
# Epoch 228: train loss 1.158928817698611 val loss 1.455584430194461 (no improvement 1)
# Epoch 228: train loss 1.158928817698611 val loss 1.455584430194461
# Time elapsed: 278.45 min
# Epoch 229: train loss 1.156928961851197 val loss 1.4645006585725395 (no improvement 2)
# Epoch 229: train loss 1.156928961851197 val loss 1.4645006585725395
# Time elapsed: 279.66 min
# Epoch 230: train loss 1.15712416818912 val loss 1.4537218609421523 (no improvement 3)
# Epoch 230: train loss 1.15712416818912 val loss 1.4537218609421523
# Time elapsed: 280.87 min
# Epoch 231: train loss 1.158812697390108 val loss 1.4812238009951642 (no improvement 4)
# Epoch 231: train loss 1.158812697390108 val loss 1.4812238009951642
# Time elapsed: 282.08 min
# Epoch 232: train loss 1.1503583656762701 val loss 1.4647505374973104 (no improvement 5)
# Epoch 232: train loss 1.1503583656762701 val loss 1.4647505374973104
# Time elapsed: 283.29 min
# Epoch 233: train loss 1.1495432037113487 val loss 1.4539014884235524 (no improvement 6)
# Epoch 233: train loss 1.1495432037113487 val loss 1.4539014884235524
# Time elapsed: 284.50 min
# Epoch 234: train loss 1.1498152159230717 val loss 1.469124453669288 (no improvement 7)
# Epoch 234: train loss 1.1498152159230717 val loss 1.469124453669288
# Time elapsed: 285.71 min
# Epoch 235: train loss 1.1483515497915757 val loss 1.4623725522322344 (no improvement 8)
# Epoch 235: train loss 1.1483515497915757 val loss 1.4623725522322344
# Time elapsed: 286.92 min
# Epoch 236: train loss 1.1459783582559115 val loss 1.4939345012355985 (no improvement 9)
# Epoch 236: train loss 1.1459783582559115 val loss 1.4939345012355985
# Time elapsed: 288.12 min
# Epoch 237: train loss 1.1468625746121897 val loss 1.446490799293417
# Time elapsed: 289.34 min
# Epoch 238: train loss 1.1446113383807286 val loss 1.4701004241041642 (no improvement 1)
# Epoch 238: train loss 1.1446113383807286 val loss 1.4701004241041642
# Time elapsed: 290.55 min
# Epoch 239: train loss 1.1465781883777768 val loss 1.4500542072427778 (no improvement 2)
# Epoch 239: train loss 1.1465781883777768 val loss 1.4500542072427778
# Time elapsed: 291.76 min
# Epoch 240: train loss 1.147982295419388 val loss 1.482308424420373 (no improvement 3)
# Epoch 240: train loss 1.147982295419388 val loss 1.482308424420373
# Time elapsed: 292.97 min
# Epoch 241: train loss 1.1441902607564678 val loss 1.4629392368294392 (no improvement 4)
# Epoch 241: train loss 1.1441902607564678 val loss 1.4629392368294392
# Time elapsed: 294.19 min
# Epoch 242: train loss 1.1403058486098525 val loss 1.4601886773531039 (no improvement 5)
# Epoch 242: train loss 1.1403058486098525 val loss 1.4601886773531039
# Time elapsed: 295.40 min
# Epoch 243: train loss 1.1383216915895398 val loss 1.4543188467178012 (no improvement 6)
# Epoch 243: train loss 1.1383216915895398 val loss 1.4543188467178012
# Time elapsed: 296.62 min
# Epoch 244: train loss 1.139721455069201 val loss 1.4513660829603876 (no improvement 7)
# Epoch 244: train loss 1.139721455069201 val loss 1.4513660829603876
# Time elapsed: 297.83 min
# Epoch 245: train loss 1.1397709136016116 val loss 1.4563028370494286 (no improvement 8)
# Epoch 245: train loss 1.1397709136016116 val loss 1.4563028370494286
# Time elapsed: 299.04 min
# Epoch 246: train loss 1.1380423642403485 val loss 1.4587886221322817 (no improvement 9)
# Epoch 246: train loss 1.1380423642403485 val loss 1.4587886221322817
# Time elapsed: 300.26 min
# Epoch 247: train loss 1.1366557881885828 val loss 1.4539999833708162 (no improvement 10)
# Epoch 247: train loss 1.1366557881885828 val loss 1.4539999833708162
# Time elapsed: 301.47 min
# Epoch 248: train loss 1.1320073713927798 val loss 1.4586504808491585 (no improvement 11)
# Epoch 248: train loss 1.1320073713927798 val loss 1.4586504808491585
# Time elapsed: 302.69 min
# Epoch 249: train loss 1.1325430551978777 val loss 1.4712781533342867 (no improvement 12)
# Epoch 249: train loss 1.1325430551978777 val loss 1.4712781533342867
# Time elapsed: 303.90 min
# Epoch 250: train loss 1.1309813466265481 val loss 1.4525820001370924 (no improvement 13)
# Epoch 250: train loss 1.1309813466265481 val loss 1.4525820001370924
# Total Training Time: 303.90 min

# %%
ax = plt.figure().gca()

ax.plot(history['train'])
ax.plot(history['val'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'])
plt.title('Loss over training epochs')
plt.show();

# %% [markdown]
# Our model converged quite well. Seems like we might've needed a larger validation set to smoothen the results, but that'll do for now.

# %% [markdown]
# ### Saving the model

# %% [markdown]
# Let's store the model for later use:

# %%
# MODEL_PATH = 'model/model_AE_100u_v3.pth'

# torch.save(model, MODEL_PATH)

# %% [markdown]
# ### Saving a history to file

# %%
# import pickle

# # save dictionary to person_data.pkl file
# with open('history/model_AE_100u_v3.pkl', 'wb') as fp:
#     pickle.dump(history, fp)
#     print('History dictionary saved successfully to file')

# %% [markdown]
# ### Load Model

# %% [markdown]
# Uncomment the next lines, if you want to download and load the pre-trained model:

# %%
# model = torch.load('./model/model_AE_100u_v1.pth')
# model = model.to(device)

# %% [markdown]
# ### Load History

# %%
# import pickle

# # Read dictionary pkl file
# with open('history/model_AE_100u_v1.pkl', 'rb') as fp:
#     history = pickle.load(fp)
#     print('History dictionary')
#     print(history.keys())

# %%
# ax = plt.figure().gca()

# ax.plot(history['train'])
# ax.plot(history['val'])
# plt.ylabel('Loss')
# plt.xlabel('Epoch')
# plt.legend(['train', 'test'])
# plt.title('Loss over training epochs')
# plt.show();

# %% [markdown]
# ## Generate Attack Type

# %%
# Generate artificial samples for attack type 1: Consumption profile modification
def generate_attack_type_1(data):
    data_copy = data.copy()
    alpha = np.random.uniform(0.1, 0.8)
    return data_copy * alpha

# Generate artificial samples for attack type 2: Meter data modification
def generate_attack_type_2(data):
    data_copy = data.copy()
    gamma = np.random.uniform(0.2, 0.8, size=data_copy.shape)
    return data_copy * gamma


# Generate artificial samples for attack type 3: Meter tampering detection evasion
def generate_attack_type_3(data):
    start_time = np.random.randint(0, 96 - 6)
    duration = np.random.randint(6, 96)
    end_time = start_time + duration
    attack = data.copy()
    attack[start_time:end_time] = 0
    return attack

# Generate artificial samples for attack type 4: Magnetic field detection evasion
def generate_attack_type_4(data):
    data_copy = data.copy()
    mean_value = np.mean(data_copy)
    mean_value = np.full(data_copy.shape[0], mean_value)
    gamma = np.random.uniform(0.2, 0.8, size=data_copy.shape)
    return gamma * mean_value

# Generate artificial samples for attack type 5: Jamming attack
def generate_attack_type_5(data):
    data_copy = data.copy()
    mean_value = np.mean(data_copy)
    return np.full(data_copy.shape[0], mean_value)

# Generate artificial samples for attack type 6: False data injection
def generate_attack_type_6(data):
    data_copy = data.copy()
    inverted_data = data_copy[::-1]
    return inverted_data

# %%
# Seleted user
user_6 = clean_data(df, 6)
user_6
# Out:
#                        KWH
# DATE-Time
# 2021-01-01 00:00:00  0.154
# 2021-01-01 00:15:00  0.143
# 2021-01-01 00:30:00  0.157
# 2021-01-01 00:45:00  0.128
# 2021-01-01 01:00:00  0.115
# ...                    ...
# 2021-08-31 22:45:00  0.325
# 2021-08-31 23:00:00  0.279
# 2021-08-31 23:15:00  0.292
# 2021-08-31 23:30:00  0.236
# 2021-08-31 23:45:00  0.227
#
# [22944 rows x 1 columns]

# %%
# Example usage
window_size = 96
user_6 = user_6.to_numpy()
windowed_data_user_6 = create_windowed_dataset(user_6, window_size)
print(f" Window shape : {windowed_data_user_6.shape}")
print(f" Type of Window : {type(windowed_data_user_6)}")
# Out:
#  Window shape : (239, 96)
#  Type of Window : <class 'numpy.ndarray'>

# %%
user_6_normal_dataset, _, _ = create_dataset(windowed_data_user_6)   # We got list of tensor

# %% [markdown]
# 1. torch.Tensor().numpy()
# 2. torch.Tensor().cpu().data.numpy()
# 3. torch.Tensor().cpu().detach().numpy()

# %%
# Convert each tensor to numpy array and append to a new list
numpy_list = []
for tensor in user_6_normal_dataset:
    numpy_list.append(tensor.numpy())

# Convert list of numpy arrays to a 3D numpy array
user_6_normal_dataset = np.array(numpy_list)

# %%
day = 0
windowed_data_test = user_6_normal_dataset.copy()
attack_type_1 = generate_attack_type_1(windowed_data_test[day])
attack_type_2 = generate_attack_type_2(windowed_data_test[day])
attack_type_3 = generate_attack_type_3(windowed_data_test[day])
attack_type_4 = generate_attack_type_4(windowed_data_test[day])
attack_type_5 = generate_attack_type_5(windowed_data_test[day])
attack_type_6 = generate_attack_type_6(windowed_data_test[day])
# Plot the original data and the modified data
plt.plot(user_6_normal_dataset[day])
plt.plot(attack_type_1)
plt.plot(attack_type_2)
plt.plot(attack_type_3)
plt.plot(attack_type_4)
plt.plot(attack_type_5)
plt.plot(attack_type_6)
plt.title("Original & Attack Types: Consumption Profile")
plt.xlabel("Time (hours)")
plt.ylabel("Energy Consumption (KWH)")
plt.legend(["Original Data", "Type_1", "Type_2", "Type_3", "Type_4", "Type_5", "Type_6"])
plt.show()

# %% [markdown]
# ### Choosing a threshold

# %% [markdown]
# With our model at hand, we can have a look at the reconstruction error on the training set. Let's start by writing a helper function to get predictions from our model:

# %%
def predict(model, dataset):
    predictions, losses = [], []
    criterion = nn.L1Loss(reduction='sum').to(device)
    with torch.no_grad():
        model = model.eval()
        for seq_true in dataset:
            seq_true = seq_true.to(device)
            seq_pred = model(seq_true)

            loss = criterion(seq_pred, seq_true)

            predictions.append(seq_pred.cpu().numpy().flatten())
            losses.append(loss.item())
    return predictions, losses

# %% [markdown]
# Our function goes through each example in the dataset and records the predictions and losses. Let's get the losses and have a look at them:

# %%
_, losses = predict(model, train_dataset)

sns.distplot(losses, bins=50, kde=True);

# %%
THRESHOLD = 4

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Using the threshold, we can turn the problem into a simple binary classification task:
#
# * If the reconstruction loss for an example is below the threshold, we'll classify it as a normal heartbeat
# * Alternatively, if the loss is higher than the threshold, we'll classify it as an anomaly

# %% [markdown]
# ### Normal energy consumption

# %% [markdown]
# Let's check how well our model does on normal datasets. We'll use the normal datasets from the test set (our model haven't seen those):

# %%
predictions, pred_losses = predict(model, test_normal_dataset)
sns.distplot(pred_losses, bins=50, kde=True);

# %% [markdown]
# We'll count the correct predictions:

# %%
correct = sum(l <= THRESHOLD for l in pred_losses)
print(f'Correct normal predictions: {correct}/{len(test_normal_dataset)}')
# Out:
# Correct normal predictions: 847/874

# %% [markdown]
# ### Anomalies

# %% [markdown]
# We'll do the same with the anomaly examples, but their number is much higher. We'll get a subset that has the same size as the normal datasets:

# %% [markdown]
# We can add this type of theif attacks

# %%
type(test_normal_dataset[0])
# Out:
# torch.Tensor

# %%
attack_type_3 = generate_attack_type_3(windowed_data_test[day])  #It has the shape (96, 1)

# %%
attack_type_3 = create_windowed_dataset(attack_type_3, 96)     #Reshape, it should has shape (1, 96)

# %%
attack_type_3, _, _ = create_dataset(attack_type_3)            #List of Tensor

# %%
day = 0
windowed_data_test = user_6_normal_dataset.copy()

# %%
windowed_data_test = create_windowed_dataset(windowed_data_test[day], 96)
windowed_data_test, _, _ = create_dataset(windowed_data_test)

# %%
# anomaly_dataset = test_anomaly_dataset[:len(test_normal_dataset)]

# %% [markdown]
# Now we can take the predictions of our model for the subset of anomalies:

# %%
predictions, pred_losses = predict(model, attack_type_3)
sns.distplot(pred_losses, bins=50, kde=True);

# %% [markdown]
# Finally, we can count the number of examples above the threshold (considered as anomalies):

# %% [markdown]
# We have very good results. In the real world, you can tweak the threshold depending on what kind of errors you want to tolerate. In this case, you might want to have more false positives (normal heartbeats considered as anomalies) than false negatives (anomalies considered as normal).

# %% [markdown]
# ### Looking at Examples

# %% [markdown]
# We can overlay the real and reconstructed Time Series values to see how close they are. We'll do it for some normal and anomaly cases:

# %%
predictions, pred_losses = predict(model, [test_normal_dataset[21]])

# %%
print(len(test_normal_dataset[21]))
# Out:
# 96

# %%
mse = np.abs(test_normal_dataset[21] - predictions[0])
mse.shape
# Out:
# torch.Size([96, 96])

# %%
test_normal_dataset[21].T[0].shape
# Out:
# torch.Size([96])

# %%
mse = np.abs(test_normal_dataset[21].T[0] - predictions[0])
mse.shape
# Out:
# torch.Size([96])

# %%
def reconstructed_probability(self, x: torch.Tensor) -> torch.Tensor:
        """
        Computes the probability density of the input samples under the learned
        distribution of reconstructed data.
        Args:
            x: Input data tensor of shape (batch_size, num_features).
        Returns:
            A tensor of shape (batch_size,) containing the probability densities of
            the input samples under the learned distribution of reconstructed data.
        """
        with torch.no_grad():
            pred = self.predict(x)
        recon_dist = Normal(pred['recon_mu'], pred['recon_sigma'])
        x = x.unsqueeze(0)
        p = recon_dist.log_prob(x).exp().mean(dim=0).mean(dim=-1)  # vector of shape [batch_size]
        return p

# %%
from scipy.stats import norm
# Fit a normal distribution to the data:
mu, std = norm.fit(test_normal_dataset[21].T[0])

# %%
print(mu)
print(std)
# Out:
# 0.15803124
# 0.08255976

# %% [markdown]
# https://github.com/hupili/python-for-data-and-media-communication-gitbook/issues/118

# %% [markdown]
# ### Probability Reconstruction Loss
# https://github.com/Michedev/VAE_anomaly_detection/blob/master/model/VAE.py

# %%
from sklearn.metrics import mean_absolute_error
from matplotlib.colors import LinearSegmentedColormap

fig, ax = plt.subplots(
  nrows=2,
  ncols=1,
  # sharey=True,
  # sharex=True,
  figsize=(15, 8)
)

predictions, pred_losses = predict(model, [windowed_data_test[0]])

mse = np.abs(windowed_data_test[0].T[0] - predictions[0])

ax[0].plot(windowed_data_test[0], label='true')
ax[0].plot(predictions[0], label='reconstructed')
ax[0].grid(True)
ax[0].legend()
ax[0].set_xlim(0, len(windowed_data_test[0])-1)

cmap = LinearSegmentedColormap.from_list('RedGreenRed', ['lime', 'crimson'])
# ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Wistia', vmin=0, vmax=0.1)
ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Reds', vmin=0, vmax=0.3)
ax[1].set_xticks([])
ax[1].set_yticks([])

# plt.tight_layout();
# Out:
# []

# %%
from sklearn.metrics import mean_absolute_error
from matplotlib.colors import LinearSegmentedColormap

fig, ax = plt.subplots(
  nrows=2,
  ncols=1,
  # sharey=True,
  # sharex=True,
  figsize=(15, 8)
)

predictions, pred_losses = predict(model, [attack_type_3[0]])

mse = np.abs(attack_type_3[0].T[0] - predictions[0])

ax[0].plot(attack_type_3[0], label='true')
ax[0].plot(predictions[0], label='reconstructed')
ax[0].grid(True)
ax[0].legend()
ax[0].set_xlim(0, len(attack_type_3[0])-1)

cmap = LinearSegmentedColormap.from_list('RedGreenRed', ['lime', 'crimson'])
# ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Wistia', vmin=0, vmax=0.1)
ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Reds', vmin=0, vmax=0.3)
ax[1].set_xticks([])
ax[1].set_yticks([])

# plt.tight_layout();
# Out:
# []

# %%
attack_type_1[0][:5]
# Out:
# tensor([[0.0363],
#         [0.0337],
#         [0.0370],
#         [0.0302],
#         [0.0271]])

# %%
test_normal_dataset[21][:5]
# Out:
# tensor([[0.1570],
#         [0.0900],
#         [0.0880],
#         [0.1270],
#         [0.1230]])

# %%
from sklearn.metrics import mean_absolute_error
from matplotlib.colors import LinearSegmentedColormap

fig, ax = plt.subplots(
  nrows=2,
  ncols=1,
  # sharey=True,
  # sharex=True,
  figsize=(22, 8)
)

predictions, pred_losses = predict(model, [test_normal_dataset[21]])

mse = np.abs(test_normal_dataset[21].T[0] - predictions[0])

ax[0].plot(test_normal_dataset[21], label='true')
ax[0].plot(predictions[0], label='reconstructed')
ax[0].grid(True)
ax[0].legend()
ax[0].set_xlim(0, len(test_normal_dataset[21])-1)

cmap = LinearSegmentedColormap.from_list('RedGreenRed', ['lime', 'crimson'])
# ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Wistia', vmin=0, vmax=0.1)
ax[1].imshow(np.atleast_2d(mse), aspect=5, cmap='Reds', vmin=0, vmax=0.3)
ax[1].set_xticks([])
ax[1].set_yticks([])

# plt.tight_layout();
# Out:
# []

# %%
# [test_normal_dataset[0]]

# %%
def plot_prediction(data, model, title, ax):
    predictions, pred_losses = predict(model, [data])

    ax.plot(data, label='true')
    ax.plot(predictions[0], label='reconstructed')
    ax.set_title(f'{title} (loss: {np.around(pred_losses[0], 2)})')
    
    # ax[1].imshow(np.atleast_2d(pred_losses), aspect=5, cmap='Wistia')
    # ax[1].set_xticks([])
    # ax[1].set_yticks([])
    
    ax.legend()

# %%
# def plot_prediction(data, model, title, ax):
#     predictions, pred_losses = predict(model, [data])
#     pos = int(len(data)-1)
#     se = np.square(data - predictions[0])
#     se = se[:, pos]

#     ax.plot(data, label='true')
#     ax.plot(predictions[0], label='reconstructed')
#     ax.set_title(f'{title} (loss: {np.around(pred_losses[0], 2)})')

#     ax.imshow(np.atleast_3d(se).T, aspect=5, cmap='Wistia')
#     ax.set_xticks([])
#     ax.set_yticks([])
#     ax.legend()

# %%
# from matplotlib.colors import LinearSegmentedColormap
# def plot_prediction(data, model, title, ax):
#     predictions, pred_losses = predict(model, [data])
#     pos = int(len(data)-1)
#     se = np.square(data - predictions[0])
#     se = se[:, pos]

#     ax1 = ax[0]
#     ax1.plot(data, label='true')
#     ax1.plot(predictions[0], label='reconstructed')
#     ax1.set_title(f'{title} (loss: {np.around(pred_losses[0], 2)})')
#     ax1.legend()
#     ax1.set_xlim(0, len(data))
    
#     # rdgn = sns.diverging_palette(h_neg=130, h_pos=10, s=99, l=55, sep=3, as_cmap=True)
#     ax2 = ax[1]
#     im = ax2.imshow(np.atleast_3d(se).T, aspect=5, cmap='Wistia')
#     ax2.set_xticks([])
#     ax2.set_yticks([])
#     # fig.colorbar(im, ax=ax2)
#     return ax1, ax2

# %%
# fig, axs = plt.subplots(2, 1, figsize=(8, 6))
# plot_prediction(data, model, title='Prediction', ax=axs)
# plt.tight_layout()
# plt.show()

# %%
fig, axs = plt.subplots(
  nrows=4,
  ncols=3,
  # sharey=True,
  # sharex=True,
  figsize=(22, 8)
)

for i, data in enumerate(test_normal_dataset[20:23]):
    plot_prediction(data, model, title='Normal', ax=axs[0, i])
    
for i, data in enumerate(test_normal_dataset[23:26]):
    plot_prediction(data, model, title='Normal', ax=axs[1, i])
    
for i, data in enumerate(test_normal_dataset[26:29]):
    plot_prediction(data, model, title='Normal', ax=axs[2, i])
    
for i, data in enumerate(test_normal_dataset[29:32]):
    plot_prediction(data, model, title='Normal', ax=axs[3, i])

plt.tight_layout()

# %% [markdown]
# ### Test

# %%
df_test
# Out:
#              MeterID            DATE-Time  KWH  user user_1
# 11025816  6200028570  2021-01-01 00:00:00  0.0   510      0
# 11025817  6200028570  2021-01-01 00:15:00  0.0   510      0
# 11025818  6200028570  2021-01-01 00:30:00  0.0   510      0
# 11025819  6200028570  2021-01-01 00:45:00  0.0   510      0
# 11025820  6200028570  2021-01-01 01:00:00  0.0   510      0
# ...              ...                  ...  ...   ...    ...
# 11045667  6200028570  2021-07-31 22:45:00  0.0   510      0
# 11045668  6200028570  2021-07-31 23:00:00  0.0   510      0
# 11045669  6200028570  2021-07-31 23:15:00  0.0   510      0
# 11045670  6200028570  2021-07-31 23:30:00  0.0   510      0
# 11045671  6200028570  2021-07-31 23:45:00  0.0   510      0
#
# [19856 rows x 5 columns]

# %%
plt.figure(figsize=(12,4))
plt.title('(Energy Consumptions)', size=15)
plt.ylabel('KWH')
plt.grid(True)
plt.autoscale(axis='x',tight=True)
plt.plot(df_test['KWH'])
plt.show()

# %% [markdown]
# ## 5. Evaluate the model using the test set

# %% [markdown]
# # Task
#
# ### VAE autocoder
# * https://www.google.com/search?q=variational+autoencoder+based+anomaly+detection+using+reconstruction+probability+github&rlz=1C5CHFA_enTH999TH999&oq=Variational+Autoencoder+based+Anomaly+Detection+using+Reconstruction+Probability+&aqs=chrome.1.69i57j0i512j69i60.3070j0j7&sourceid=chrome&ie=UTF-8
# * https://github.com/Michedev/VAE_anomaly_detection
# * https://github.com/smile-yan/vae-anomaly-detection
# * https://github.com/tarekmuallim/Anomaly-Detection-using-Variational-Autoencoders/blob/master/anomaly_detection_using_vae.py
#
#
# ### CNN
# * https://github.com/khanmhmdi/Cifar-Image-Reconstruction-using-Autoencoder-Models/blob/main/Image_reconstruction.ipynb
# * https://github.com/ebrahimpichka/conv-autoencoder (test on this now!!)
